# %% [raw]
# NOTEBOOK FOR TRAINING THE MODEL WITH RESNET ARCHITECTURE

# %%
# IMPORT THE MODULES NEEDED
import os
import glob
import math
import datetime
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.python.keras.utils import losses_utils
#import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
from sklearn.preprocessing import normalize
# from classification_models.tfkeras import Classifiers

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
## Define the parameters of the network and the save/log/data directories
# Change parameters here...
sizex = 500
sizey = 500
sizez = 3
rand_seed = 666
num_datasets = -1
batch_size = 32 * 4
nb_epochs = 100
validation_ratio = 0.2
ds_size = 405
buf_size = ds_size*2

# Parameter to also use the images with the dust rendered
use_dust = False

log_dir = "logs/"
os.makedirs(log_dir, exist_ok=True)
data_dir = '../data/DNN/data/'


model_name = 'alexnet' + '_bs'+str(batch_size)
if use_dust: model_name += '_dust'

snapshot_weights = 'models/best_'+model_name+'.hdf5'
last_snapshot_weights = 'models/last_'+model_name+'.hdf5'
json_name = 'models/json_'+model_name+'.json'
trained_model = 'models/trained_'+model_name+'.h5'

# %%
# Define the custom loss function from the cosine similarity impleted in tensorflow
class myCosineSimilarity(tf.keras.losses.Loss):
    def __init__(self,
               axis=-1,
               reduction=losses_utils.ReductionV2.AUTO,
               name='myCosineSimilarity'):
        super(myCosineSimilarity, self).__init__(reduction=reduction, name=name)
        self._axis = axis
    
    def call(self, y_true, y_pred):
        cossim = lambda y, p_y: -1*tf.keras.backend.abs(tf.keras.losses.cosine_similarity(y, p_y, axis=self._axis))
        return cossim(y_true, y_pred)

# %%
strategy = tf.distribute.MirroredStrategy()
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

# Defining the model in all the devices (GPU's) available
with strategy.scope():
    # Build the model
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(sizex,sizey,sizez)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
        tf.keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
        tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(filters=384, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(4096, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(2, activation='softmax')])
    
    # Use existing best weights if available...
    if os.path.isfile(last_snapshot_weights):
        print('loaded weights')
        model.load_weights(last_snapshot_weights)
    
    # Compile the model specifying the optimazer (sgd) and the custom loss function and other metrics
    model.compile(optimizer= tf.keras.optimizers.SGD(),
                  loss= myCosineSimilarity(), metrics=[tf.keras.losses.cosine_similarity,
                                                       tf.keras.metrics.mean_absolute_error,])
# Out:
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Num GPUs Available:  0
# Number of devices: 1

# %%
# See a sumary of the model with all the layers and parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 123, 123, 96)      34944
# _________________________________________________________________
# batch_normalization (BatchNo (None, 123, 123, 96)      384
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 61, 61, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 256)       614656
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 61, 61, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 384)       885120
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 30, 384)       1536
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 384)       147840
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 30, 30, 384)       1536
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 256)       98560
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 256)       1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              205524992
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 224,101,122
# Trainable params: 224,098,370
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
# Collect all the .npz files
numpy_datasets = glob.glob(data_dir+'dataset*')

# load the data into a dictionary from npz files
data_dict = {}
for dataset in numpy_datasets[:num_datasets]:
    with np.load(dataset) as data:
        if 'y' in data_dict.keys():
            data_dict['x_dust']   = np.append( data_dict['x_dust'], data['x_dust'],axis=0)
            data_dict['x_nodust'] = np.append( data_dict['x_nodust'], data['x_nodust'],axis=0)
            data_dict['y']        = np.append( data_dict['y'], data['y'],axis=0)
            data_dict['ids']      = np.append( data_dict['ids'], data['id'],axis=0)
        else:
            data_dict['x_dust']   = data['x_dust']
            data_dict['x_nodust'] = data['x_nodust']
            data_dict['y']        = data['y']
            data_dict['ids']      = data['id']

# %%
# check the shape of the dictionary (100 images of 500x500x3 = 4 files of 25 images) before filtering
print(numpy_datasets)
print(data_dict['x_nodust'].shape)
# Out:
# ['../data/DNN/data/dataset_70.p.npz', '../data/DNN/data/dataset_80.p.npz', '../data/DNN/data/dataset_2_70.p.npz', '../data/DNN/data/dataset_2_15.p.npz', '../data/DNN/data/dataset_95.p.npz', '../data/DNN/data/dataset_2_20.p.npz', '../data/DNN/data/dataset_2_40.p.npz', '../data/DNN/data/dataset_85.p.npz', '../data/DNN/data/dataset_30.p.npz', '../data/DNN/data/dataset_65.p.npz', '../data/DNN/data/dataset_20.p.npz', '../data/DNN/data/dataset_25.p.npz', '../data/DNN/data/dataset_2_10.p.npz', '../data/DNN/data/dataset_2_75.p.npz', '../data/DNN/data/dataset_5.p.npz', '../data/DNN/data/dataset_40.p.npz', '../data/DNN/data/dataset_2_25.p.npz', '../data/DNN/data/dataset_15.p.npz', '../data/DNN/data/dataset_2_80.p.npz', '../data/DNN/data/dataset_2_5.p.npz', '../data/DNN/data/dataset_50.p.npz', '../data/DNN/data/dataset_45.p.npz', '../data/DNN/data/dataset_2_30.p.npz', '../data/DNN/data/dataset_2_90.p.npz', '../data/DNN/data/dataset_2_50.p.npz', '../data/DNN/data/dataset_2_60.p.npz', '../data/DNN/data/dataset_2_35.p.npz', '../data/DNN/data/dataset_35.p.npz', '../data/DNN/data/dataset_90.p.npz', '../data/DNN/data/dataset_2_55.p.npz', '../data/DNN/data/dataset_2_45.p.npz', '../data/DNN/data/dataset_2_95.p.npz', '../data/DNN/data/dataset_2_65.p.npz', '../data/DNN/data/dataset_75.p.npz', '../data/DNN/data/dataset_60.p.npz', '../data/DNN/data/dataset_55.p.npz', '../data/DNN/data/dataset_10.p.npz', '../data/DNN/data/dataset_2_85.p.npz']
# (895, 500, 500, 3)

# %%
#Filter the galaxies that have less than 1e10 solar masses
bad_ids = [[galaxy_id,i] for galaxy_id,i in zip(data_dict['ids'],range(len(data_dict['ids']))) if 'e09' in galaxy_id or 'e10' in galaxy_id ]
bad_ids = np.array(bad_ids)
remove_galaxies = np.array(bad_ids[:,1],dtype=int)
print('there are ', len(bad_ids), ' galaxies to remove')
#print(remove_galaxies)
filtered_dict = {}

for key in data_dict.keys():
    data_dict[key] = np.delete(data_dict[key],remove_galaxies, axis=0)
    
print('Still have ', len(data_dict['ids']), ' galaxies left')
# check that we have filtered the correct galaxies
print(data_dict['ids'][:5])
# check the shape of the dictionary after filtering
print("shape of image's array",data_dict['x_dust'].shape)
# check the shape of our dictionary in te labels entry
print("shape of the label's array",data_dict['y'].shape)
# Out:
# there are  485  galaxies to remove
# Still have  410  galaxies left
# ['g5.02e11_x110_y177_z94' 'g5.02e11_x349_y181_z358'
#  'g5.02e11_x353_y78_z41' 'g5.02e11_x298_y36_z206'
#  'g5.02e11_x185_y333_z230']
# shape of image's array (410, 500, 500, 3)
# shape of the label's array (410, 3)

# %%
# computing the normaliced vectors in 3D
data_dict['y_norm'] = normalize(data_dict['y'], axis=1)

# %%
# Functions to do the augmentation
def random_flip_lr(image, label, seed=None):
    img = tf.image.random_flip_left_right(image, seed=seed)
    if tf.reduce_all(tf.equal(img,image)):
        label_f = label
    else:
        label_f = tf.convert_to_tensor([-label[0],label[1]])
    return (img, label_f)

def random_flip_ud(image, label, seed=None):
    img = tf.image.random_flip_up_down(image, seed=seed)
    if tf.reduce_all(tf.equal(img,image)):
        label_f = label
    else:
        label_f = tf.convert_to_tensor([label[0],-label[1]])
    return (img,label_f)


def random_rot(image, label, seed=None):
    number_of_intervalls = 24 # 15 deg steps
    
    rad = tf.random.uniform(shape=[1], minval=0, maxval=2*math.pi, dtype=tf.float32)
    rad = rad//(2*math.pi/number_of_intervalls) * (2*math.pi/number_of_intervalls)
    #rad = tf.math.multiply(deg, tf.constant(math.pi/180, dtype=tf.float32))
    img = tfa.image.rotate(image, rad, interpolation = 'BILINEAR')
    
    x = tf.math.multiply(tf.math.cos(-rad), label[0]) - tf.math.multiply(tf.math.sin(-rad), label[1])
    y = tf.math.multiply(tf.math.sin(-rad), label[0]) + tf.math.multiply(tf.math.cos(-rad), label[1])
    label_f = tf.reshape(tf.convert_to_tensor([x, y]), [2])
    return (img,label_f)

def augment(img, label):
    img_f,label_f = random_flip_lr(img,label)
    img_f,label_f = random_flip_ud(img_f,label_f)
    img_f,label_f = random_rot(img_f,label_f)
    return (img_f, label_f)

# %%
# Import the autotune option from TF
AUTO = tf.data.experimental.AUTOTUNE

# Defining the train and validation dataset from the existing dictionary, shufling and batching
# First we do the ones without dust, then if duts is activated we make it also with dust and mix both
input_ds_nodust = (
    tf.data.Dataset.from_tensor_slices((data_dict['x_nodust'].astype(np.float32),
                                        data_dict['y_norm'][:,:2].astype(np.float32)))
                    # Use seed to ensure we always have the same validation data set!
                   .shuffle(ds_size, seed = rand_seed, reshuffle_each_iteration = False))

# take a part of the dataset (we take all but there's the option to take just a part of it with the ds_size parameter)
input_ds_nodust = input_ds_nodust.take(ds_size)
# compute the val_size dataset in terms of the ds_size and the validation_ratio that we have
val_size = math.floor(ds_size * validation_ratio)

# cache and augment the dataset (THE ORDER IS IMPORTANT!!)
validation_ds_nodust_aug =  (input_ds_nodust.take(val_size).cache()
                            .map(augment, num_parallel_calls=AUTO))
train_ds_nodust_aug      =  (input_ds_nodust.skip(val_size).cache()
                            .map(augment, num_parallel_calls=AUTO))

# if dust is activated compute the dust datasets
if use_dust:
    input_ds_dust = (
        tf.data.Dataset.from_tensor_slices((data_dict['x_dust'].astype(np.float32),
                                            data_dict['y_norm'][:,:2].astype(np.float32)))
                       .shuffle(ds_size, seed = rand_seed, reshuffle_each_iteration = False))
    
    input_ds_dust = input_ds_dust.take(ds_size)
    validation_ds_dust_aug = (input_ds_dust.take(val_size).cache()
                              .map(augment, num_parallel_calls=AUTO))
    train_ds_dust_aug =  (input_ds_dust.skip(val_size).cache()
                          .map(augment, num_parallel_calls=AUTO))
    
    # concatenate both datasets (dust and no dust) and repeat the data and batch it
    train_ds = (train_ds_dust_aug.concatenate(train_ds_nodust_aug)
                    .shuffle(buffer_size=buf_size, reshuffle_each_iteration=True)
                    .repeat(48).batch(batch_size).prefetch(AUTO))
    validation_ds = (validation_ds_dust_aug.concatenate(validation_ds_nodust_aug)
                    .repeat(48).batch(batch_size).prefetch(AUTO))

else:
    # if dust is not activated compute the dataset from the nodust dataset and reapeat the data and batch it
    train_ds = (train_ds_nodust_aug
                    .shuffle(buffer_size=buf_size, reshuffle_each_iteration=True)
                    .repeat(48).batch(batch_size).prefetch(AUTO))
    validation_ds = (validation_ds_nodust_aug
                    .repeat(48).batch(batch_size).prefetch(AUTO))

# check all the datasets to see if they are correct
print(validation_ds_nodust_aug)
print(train_ds_nodust_aug)
print(validation_ds)
print(train_ds)
# Out:
# <ParallelMapDataset shapes: ((500, 500, 3), (2,)), types: (tf.float32, tf.float32)>
# <ParallelMapDataset shapes: ((500, 500, 3), (2,)), types: (tf.float32, tf.float32)>
# <PrefetchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>
# <PrefetchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>

# %%
# function to visualice the data 
def viz(img, label, pred=np.array([0,0,0]), id=None):
    fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(img, cmap='gray', vmin=0, vmax=255,origin='lower')
    ax.arrow(250,250,100*label[0],100*label[1], head_width=7, head_length=10, fc='g', ec='g')
    if np.sum(np.abs(pred)) > 0: ax.arrow(250,250,100*pred[0],100*pred[1], head_width=7, head_length=10, fc='r', ec='r')
        
    display(Markdown("#### **cartesian label:** {}".format(label)))
    if np.sum(np.abs(pred)) > 0: display(Markdown("#### **cartesian prediction (x_y):** {}".format(pred)))
    if id: display(Markdown("#### **ID:** {}".format(id)))
    plt.show()

# visualice the data
for idx in range(1,5):
    elements = train_ds.take(idx)
    for elem in elements:
        viz(elem[0][idx], elem[1][idx])#, elem['y_revs'][idx], id=elem['ids'][idx])
# Out:
# #### **cartesian label:** [ 0.8745409  -0.20744197]
# #### **cartesian label:** [ 0.44190294 -0.7466393 ]
# #### **cartesian label:** [-0.5865226   0.06492329]
# #### **cartesian label:** [ 0.981251   -0.12824872]
# #### **cartesian label:** [-0.84231365 -0.1608567 ]
# #### **cartesian label:** [-0.61745167 -0.6279187 ]
# #### **cartesian label:** [-0.9648293   0.26176658]
# #### **cartesian label:** [0.5021254  0.36852473]
# #### **cartesian label:** [ 0.50498456 -0.36300856]
# #### **cartesian label:** [-0.912262    0.07897487]

# %%
# Launch tensorboard
# %reload_ext tensorboard
# %tensorboard --logdir {log_dir} --reload_multifile True --host 0.0.0.0 --port 6006
# Out:
#       <iframe id="tensorboard-frame-ab52064a6690aedc" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ab52064a6690aedc");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# serialize model to JSON for latter infernce
model_json = model.to_json()
with open(json_name, "w") as json_file:
    json_file.write(model_json)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-b18bbe678f77> in <module>
#       1 # serialize model to JSON for latter infernce
#       2 model_json = model.to_json()
# ----> 3 with open(json_name, "w") as json_file:
#       4     json_file.write(model_json)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/json_alexnet_bs128.json'

# %%
# For tensorboard to save the models
log_dir_s = log_dir + model_name
os.makedirs(log_dir_s, exist_ok=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir_s, histogram_freq=1, update_freq='batch', profile_batch=0)

#define the learning rate scheduler
def scheduler(epoch, lr):
    if epoch == 200:
        return lr #/ 100
    else:
        return lr

# Checkpointing
checkpointer_1 = tf.keras.callbacks.ModelCheckpoint(filepath=snapshot_weights,
                               monitor='val_loss',
                               verbose=1,
                               save_best_only=True)
checkpointer_2 = tf.keras.callbacks.ModelCheckpoint(filepath=last_snapshot_weights,
                               monitor='val_loss',
                               verbose=1,
                               save_best_only=False)
LearningRateScheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

callbacks = [
    tensorboard_callback,
    checkpointer_1,
    checkpointer_2,
    LearningRateScheduler,
]

# Fit the model with the training and validation data, number of epochs and callbacks
model.fit(
    train_ds,
    validation_data = validation_ds,
    epochs = nb_epochs,
    callbacks = callbacks,)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From /opt/conda/lib/python3.8/site-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# INFO:tensorflow:batch_all_reduce: 26 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 26 all-reduces with algorithm = nccl, num_packs = 1
# 122/122 [==============================] - ETA: 0s - loss: -0.7385 - cosine_similarity: 0.0061 - mean_absolute_error: 0.6849
# Epoch 00001: val_loss improved from inf to -0.64261, saving model to models/best_alexnet_bs128.hdf5
#
# Epoch 00001: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 236s 2s/step - loss: -0.7385 - cosine_similarity: 0.0061 - mean_absolute_error: 0.6849 - val_loss: -0.6426 - val_cosine_similarity: -0.0098 - val_mean_absolute_error: 0.6419
# Epoch 2/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7660 - cosine_similarity: 0.0067 - mean_absolute_error: 0.6818
# Epoch 00002: val_loss improved from -0.64261 to -0.71364, saving model to models/best_alexnet_bs128.hdf5
#
# Epoch 00002: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 58s 473ms/step - loss: -0.7660 - cosine_similarity: 0.0067 - mean_absolute_error: 0.6818 - val_loss: -0.7136 - val_cosine_similarity: -0.0271 - val_mean_absolute_error: 0.5988
# Epoch 3/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7786 - cosine_similarity: -0.0076 - mean_absolute_error: 0.6719
# Epoch 00003: val_loss improved from -0.71364 to -0.72481, saving model to models/best_alexnet_bs128.hdf5
#
# Epoch 00003: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 58s 476ms/step - loss: -0.7786 - cosine_similarity: -0.0074 - mean_absolute_error: 0.6719 - val_loss: -0.7248 - val_cosine_similarity: -0.0011 - val_mean_absolute_error: 0.6810
# Epoch 4/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7831 - cosine_similarity: -0.0023 - mean_absolute_error: 0.6724
# Epoch 00004: val_loss improved from -0.72481 to -0.78470, saving model to models/best_alexnet_bs128.hdf5
#
# Epoch 00004: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 57s 470ms/step - loss: -0.7832 - cosine_similarity: -0.0030 - mean_absolute_error: 0.6720 - val_loss: -0.7847 - val_cosine_similarity: -0.0038 - val_mean_absolute_error: 0.6510
# Epoch 5/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7804 - cosine_similarity: 0.0070 - mean_absolute_error: 0.6781
# Epoch 00005: val_loss did not improve from -0.78470
#
# Epoch 00005: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 56s 459ms/step - loss: -0.7804 - cosine_similarity: 0.0070 - mean_absolute_error: 0.6781 - val_loss: -0.7639 - val_cosine_similarity: -0.0054 - val_mean_absolute_error: 0.6748
# Epoch 6/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7813 - cosine_similarity: 5.2704e-04 - mean_absolute_error: 0.6770
# Epoch 00006: val_loss did not improve from -0.78470
#
# Epoch 00006: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 454ms/step - loss: -0.7813 - cosine_similarity: 5.2704e-04 - mean_absolute_error: 0.6770 - val_loss: -0.7752 - val_cosine_similarity: -0.0045 - val_mean_absolute_error: 0.6690
# Epoch 7/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7799 - cosine_similarity: 0.0042 - mean_absolute_error: 0.6780
# Epoch 00007: val_loss improved from -0.78470 to -0.79051, saving model to models/best_alexnet_bs128.hdf5
#
# Epoch 00007: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 57s 468ms/step - loss: -0.7801 - cosine_similarity: 0.0044 - mean_absolute_error: 0.6780 - val_loss: -0.7905 - val_cosine_similarity: -0.0024 - val_mean_absolute_error: 0.6575
# Epoch 8/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7864 - cosine_similarity: -0.0104 - mean_absolute_error: 0.6716
# Epoch 00008: val_loss improved from -0.79051 to -0.79438, saving model to models/best_alexnet_bs128.hdf5
#
# Epoch 00008: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 57s 466ms/step - loss: -0.7865 - cosine_similarity: -0.0108 - mean_absolute_error: 0.6714 - val_loss: -0.7944 - val_cosine_similarity: -0.0098 - val_mean_absolute_error: 0.6567
# Epoch 9/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7834 - cosine_similarity: -6.3614e-04 - mean_absolute_error: 0.6761
# Epoch 00009: val_loss did not improve from -0.79438
#
# Epoch 00009: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 454ms/step - loss: -0.7833 - cosine_similarity: -6.9951e-04 - mean_absolute_error: 0.6762 - val_loss: -0.7557 - val_cosine_similarity: -0.0144 - val_mean_absolute_error: 0.6750
# Epoch 10/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7804 - cosine_similarity: -0.0041 - mean_absolute_error: 0.6755
# Epoch 00010: val_loss did not improve from -0.79438
#
# Epoch 00010: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 56s 456ms/step - loss: -0.7805 - cosine_similarity: -0.0039 - mean_absolute_error: 0.6757 - val_loss: -0.7777 - val_cosine_similarity: 0.0119 - val_mean_absolute_error: 0.6726
# Epoch 11/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7935 - cosine_similarity: -0.0079 - mean_absolute_error: 0.6705
# Epoch 00011: val_loss did not improve from -0.79438
#
# Epoch 00011: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 451ms/step - loss: -0.7936 - cosine_similarity: -0.0082 - mean_absolute_error: 0.6702 - val_loss: -0.7769 - val_cosine_similarity: -4.4781e-04 - val_mean_absolute_error: 0.6694
# Epoch 12/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7868 - cosine_similarity: -0.0037 - mean_absolute_error: 0.6738
# Epoch 00012: val_loss did not improve from -0.79438
#
# Epoch 00012: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 454ms/step - loss: -0.7868 - cosine_similarity: -0.0035 - mean_absolute_error: 0.6739 - val_loss: -0.7594 - val_cosine_similarity: -0.0135 - val_mean_absolute_error: 0.6733
# Epoch 13/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7880 - cosine_similarity: 0.0040 - mean_absolute_error: 0.6785
# Epoch 00013: val_loss did not improve from -0.79438
#
# Epoch 00013: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 452ms/step - loss: -0.7878 - cosine_similarity: 0.0037 - mean_absolute_error: 0.6785 - val_loss: -0.7843 - val_cosine_similarity: -0.0013 - val_mean_absolute_error: 0.6663
# Epoch 14/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7822 - cosine_similarity: -0.0069 - mean_absolute_error: 0.6761
# Epoch 00014: val_loss improved from -0.79438 to -0.79698, saving model to models/best_alexnet_bs128.hdf5
#
# Epoch 00014: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 57s 467ms/step - loss: -0.7823 - cosine_similarity: -0.0061 - mean_absolute_error: 0.6764 - val_loss: -0.7970 - val_cosine_similarity: 0.0101 - val_mean_absolute_error: 0.6630
# Epoch 15/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7775 - cosine_similarity: 0.0012 - mean_absolute_error: 0.6823
# Epoch 00015: val_loss did not improve from -0.79698
#
# Epoch 00015: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 448ms/step - loss: -0.7775 - cosine_similarity: 0.0012 - mean_absolute_error: 0.6823 - val_loss: -0.7617 - val_cosine_similarity: 0.0244 - val_mean_absolute_error: 0.6858
# Epoch 16/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7808 - cosine_similarity: -0.0073 - mean_absolute_error: 0.6775
# Epoch 00016: val_loss did not improve from -0.79698
#
# Epoch 00016: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 447ms/step - loss: -0.7808 - cosine_similarity: -0.0060 - mean_absolute_error: 0.6782 - val_loss: -0.7747 - val_cosine_similarity: -0.0107 - val_mean_absolute_error: 0.6701
# Epoch 17/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7898 - cosine_similarity: -0.0061 - mean_absolute_error: 0.6736
# Epoch 00017: val_loss did not improve from -0.79698
#
# Epoch 00017: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 448ms/step - loss: -0.7900 - cosine_similarity: -0.0060 - mean_absolute_error: 0.6736 - val_loss: -0.7864 - val_cosine_similarity: -0.0329 - val_mean_absolute_error: 0.6519
# Epoch 18/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7955 - cosine_similarity: 0.0033 - mean_absolute_error: 0.6768
# Epoch 00018: val_loss did not improve from -0.79698
#
# Epoch 00018: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 447ms/step - loss: -0.7956 - cosine_similarity: 0.0028 - mean_absolute_error: 0.6766 - val_loss: -0.7719 - val_cosine_similarity: -0.0349 - val_mean_absolute_error: 0.6592
# Epoch 19/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7939 - cosine_similarity: -0.0040 - mean_absolute_error: 0.6735
# Epoch 00019: val_loss did not improve from -0.79698
#
# Epoch 00019: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 450ms/step - loss: -0.7940 - cosine_similarity: -0.0037 - mean_absolute_error: 0.6735 - val_loss: -0.7899 - val_cosine_similarity: 0.0051 - val_mean_absolute_error: 0.6654
# Epoch 20/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7966 - cosine_similarity: -0.0115 - mean_absolute_error: 0.6707
# Epoch 00020: val_loss did not improve from -0.79698
#
# Epoch 00020: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 450ms/step - loss: -0.7966 - cosine_similarity: -0.0113 - mean_absolute_error: 0.6708 - val_loss: -0.7908 - val_cosine_similarity: -0.0109 - val_mean_absolute_error: 0.6622
# Epoch 21/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7861 - cosine_similarity: 0.0085 - mean_absolute_error: 0.6818
# Epoch 00021: val_loss did not improve from -0.79698
#
# Epoch 00021: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 450ms/step - loss: -0.7862 - cosine_similarity: 0.0086 - mean_absolute_error: 0.6818 - val_loss: -0.7933 - val_cosine_similarity: -0.0175 - val_mean_absolute_error: 0.6552
# Epoch 22/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7921 - cosine_similarity: 0.0117 - mean_absolute_error: 0.6815
# Epoch 00022: val_loss did not improve from -0.79698
#
# Epoch 00022: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 452ms/step - loss: -0.7921 - cosine_similarity: 0.0123 - mean_absolute_error: 0.6817 - val_loss: -0.7841 - val_cosine_similarity: -0.0077 - val_mean_absolute_error: 0.6606
# Epoch 23/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7964 - cosine_similarity: -0.0127 - mean_absolute_error: 0.6708
# Epoch 00023: val_loss did not improve from -0.79698
#
# Epoch 00023: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 448ms/step - loss: -0.7965 - cosine_similarity: -0.0116 - mean_absolute_error: 0.6713 - val_loss: -0.7817 - val_cosine_similarity: 0.0096 - val_mean_absolute_error: 0.6737
# Epoch 24/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7841 - cosine_similarity: 0.0121 - mean_absolute_error: 0.6855
# Epoch 00024: val_loss did not improve from -0.79698
#
# Epoch 00024: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 448ms/step - loss: -0.7843 - cosine_similarity: 0.0125 - mean_absolute_error: 0.6856 - val_loss: -0.7629 - val_cosine_similarity: -0.0187 - val_mean_absolute_error: 0.6685
# Epoch 25/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7867 - cosine_similarity: 0.0048 - mean_absolute_error: 0.6811
# Epoch 00025: val_loss did not improve from -0.79698
#
# Epoch 00025: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 452ms/step - loss: -0.7867 - cosine_similarity: 0.0049 - mean_absolute_error: 0.6811 - val_loss: -0.7850 - val_cosine_similarity: 0.0042 - val_mean_absolute_error: 0.6679
# Epoch 26/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7836 - cosine_similarity: 0.0026 - mean_absolute_error: 0.6804
# Epoch 00026: val_loss did not improve from -0.79698
#
# Epoch 00026: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 453ms/step - loss: -0.7836 - cosine_similarity: 0.0026 - mean_absolute_error: 0.6804 - val_loss: -0.7625 - val_cosine_similarity: -0.0011 - val_mean_absolute_error: 0.6750
# Epoch 27/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7975 - cosine_similarity: -0.0031 - mean_absolute_error: 0.6732
# Epoch 00027: val_loss did not improve from -0.79698
#
# Epoch 00027: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 450ms/step - loss: -0.7975 - cosine_similarity: -0.0029 - mean_absolute_error: 0.6734 - val_loss: -0.7872 - val_cosine_similarity: -0.0214 - val_mean_absolute_error: 0.6591
# Epoch 28/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7907 - cosine_similarity: -0.0018 - mean_absolute_error: 0.6774
# Epoch 00028: val_loss did not improve from -0.79698
#
# Epoch 00028: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 451ms/step - loss: -0.7908 - cosine_similarity: -0.0022 - mean_absolute_error: 0.6772 - val_loss: -0.7881 - val_cosine_similarity: -0.0066 - val_mean_absolute_error: 0.6620
# Epoch 29/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7750 - cosine_similarity: 0.0030 - mean_absolute_error: 0.6862
# Epoch 00029: val_loss did not improve from -0.79698
#
# Epoch 00029: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 56s 462ms/step - loss: -0.7751 - cosine_similarity: 0.0030 - mean_absolute_error: 0.6861 - val_loss: -0.7877 - val_cosine_similarity: -0.0149 - val_mean_absolute_error: 0.6604
# Epoch 30/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7931 - cosine_similarity: -0.0038 - mean_absolute_error: 0.6749
# Epoch 00030: val_loss did not improve from -0.79698
#
# Epoch 00030: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 56s 455ms/step - loss: -0.7931 - cosine_similarity: -0.0038 - mean_absolute_error: 0.6749 - val_loss: -0.7598 - val_cosine_similarity: -0.0107 - val_mean_absolute_error: 0.6747
# Epoch 31/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7877 - cosine_similarity: 0.0120 - mean_absolute_error: 0.6837
# Epoch 00031: val_loss did not improve from -0.79698
#
# Epoch 00031: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 453ms/step - loss: -0.7877 - cosine_similarity: 0.0120 - mean_absolute_error: 0.6837 - val_loss: -0.7903 - val_cosine_similarity: -0.0047 - val_mean_absolute_error: 0.6624
# Epoch 32/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7923 - cosine_similarity: -0.0029 - mean_absolute_error: 0.6775
# Epoch 00032: val_loss did not improve from -0.79698
#
# Epoch 00032: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 449ms/step - loss: -0.7921 - cosine_similarity: -0.0034 - mean_absolute_error: 0.6774 - val_loss: -0.7696 - val_cosine_similarity: -0.0041 - val_mean_absolute_error: 0.6773
# Epoch 33/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7878 - cosine_similarity: -5.6569e-04 - mean_absolute_error: 0.6781
# Epoch 00033: val_loss did not improve from -0.79698
#
# Epoch 00033: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 454ms/step - loss: -0.7877 - cosine_similarity: -0.0015 - mean_absolute_error: 0.6778 - val_loss: -0.7945 - val_cosine_similarity: 0.0205 - val_mean_absolute_error: 0.6754
# Epoch 34/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7939 - cosine_similarity: 0.0028 - mean_absolute_error: 0.6787
# Epoch 00034: val_loss did not improve from -0.79698
#
# Epoch 00034: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 452ms/step - loss: -0.7939 - cosine_similarity: 0.0029 - mean_absolute_error: 0.6787 - val_loss: -0.7694 - val_cosine_similarity: -0.0048 - val_mean_absolute_error: 0.6749
# Epoch 35/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7922 - cosine_similarity: -7.1515e-05 - mean_absolute_error: 0.6782
# Epoch 00035: val_loss did not improve from -0.79698
#
# Epoch 00035: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 453ms/step - loss: -0.7924 - cosine_similarity: -3.0804e-05 - mean_absolute_error: 0.6781 - val_loss: -0.7844 - val_cosine_similarity: -0.0073 - val_mean_absolute_error: 0.6667
# Epoch 36/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7862 - cosine_similarity: 8.1517e-04 - mean_absolute_error: 0.6813
# Epoch 00036: val_loss improved from -0.79698 to -0.79772, saving model to models/best_alexnet_bs128.hdf5
#
# Epoch 00036: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 57s 467ms/step - loss: -0.7863 - cosine_similarity: 6.0468e-04 - mean_absolute_error: 0.6812 - val_loss: -0.7977 - val_cosine_similarity: -0.0065 - val_mean_absolute_error: 0.6604
# Epoch 37/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7917 - cosine_similarity: -0.0090 - mean_absolute_error: 0.6732
# Epoch 00037: val_loss did not improve from -0.79772
#
# Epoch 00037: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 454ms/step - loss: -0.7915 - cosine_similarity: -0.0084 - mean_absolute_error: 0.6734 - val_loss: -0.7889 - val_cosine_similarity: 0.0148 - val_mean_absolute_error: 0.6707
# Epoch 38/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7924 - cosine_similarity: -0.0137 - mean_absolute_error: 0.6734
# Epoch 00038: val_loss did not improve from -0.79772
#
# Epoch 00038: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 452ms/step - loss: -0.7922 - cosine_similarity: -0.0135 - mean_absolute_error: 0.6736 - val_loss: -0.7757 - val_cosine_similarity: 0.0035 - val_mean_absolute_error: 0.6765
# Epoch 39/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7943 - cosine_similarity: 6.0537e-04 - mean_absolute_error: 0.6768
# Epoch 00039: val_loss did not improve from -0.79772
#
# Epoch 00039: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 452ms/step - loss: -0.7945 - cosine_similarity: 0.0014 - mean_absolute_error: 0.6770 - val_loss: -0.7891 - val_cosine_similarity: 0.0092 - val_mean_absolute_error: 0.6700
# Epoch 40/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7868 - cosine_similarity: -0.0118 - mean_absolute_error: 0.6758
# Epoch 00040: val_loss did not improve from -0.79772
#
# Epoch 00040: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 454ms/step - loss: -0.7868 - cosine_similarity: -0.0117 - mean_absolute_error: 0.6758 - val_loss: -0.7653 - val_cosine_similarity: 2.7123e-04 - val_mean_absolute_error: 0.6757
# Epoch 41/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7818 - cosine_similarity: 3.9044e-04 - mean_absolute_error: 0.6814
# Epoch 00041: val_loss did not improve from -0.79772
#
# Epoch 00041: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 56s 458ms/step - loss: -0.7817 - cosine_similarity: 9.2721e-04 - mean_absolute_error: 0.6816 - val_loss: -0.7825 - val_cosine_similarity: 0.0205 - val_mean_absolute_error: 0.6777
# Epoch 42/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7884 - cosine_similarity: 0.0025 - mean_absolute_error: 0.6806
# Epoch 00042: val_loss did not improve from -0.79772
#
# Epoch 00042: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 453ms/step - loss: -0.7882 - cosine_similarity: 0.0022 - mean_absolute_error: 0.6805 - val_loss: -0.7834 - val_cosine_similarity: 0.0095 - val_mean_absolute_error: 0.6758
# Epoch 43/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7844 - cosine_similarity: 0.0027 - mean_absolute_error: 0.6803
# Epoch 00043: val_loss did not improve from -0.79772
#
# Epoch 00043: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 453ms/step - loss: -0.7845 - cosine_similarity: 0.0019 - mean_absolute_error: 0.6801 - val_loss: -0.7806 - val_cosine_similarity: -0.0313 - val_mean_absolute_error: 0.6587
# Epoch 44/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7827 - cosine_similarity: -0.0020 - mean_absolute_error: 0.6803
# Epoch 00044: val_loss did not improve from -0.79772
#
# Epoch 00044: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 451ms/step - loss: -0.7825 - cosine_similarity: -0.0021 - mean_absolute_error: 0.6803 - val_loss: -0.7262 - val_cosine_similarity: -0.0105 - val_mean_absolute_error: 0.6893
# Epoch 45/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7899 - cosine_similarity: -0.0101 - mean_absolute_error: 0.6763
# Epoch 00045: val_loss did not improve from -0.79772
#
# Epoch 00045: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 452ms/step - loss: -0.7899 - cosine_similarity: -0.0103 - mean_absolute_error: 0.6762 - val_loss: -0.7882 - val_cosine_similarity: 0.0049 - val_mean_absolute_error: 0.6706
# Epoch 46/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7964 - cosine_similarity: 0.0078 - mean_absolute_error: 0.6792
# Epoch 00046: val_loss did not improve from -0.79772
#
# Epoch 00046: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 452ms/step - loss: -0.7964 - cosine_similarity: 0.0078 - mean_absolute_error: 0.6792 - val_loss: -0.7884 - val_cosine_similarity: -0.0295 - val_mean_absolute_error: 0.6586
# Epoch 47/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7991 - cosine_similarity: 8.8914e-04 - mean_absolute_error: 0.6745
# Epoch 00047: val_loss did not improve from -0.79772
#
# Epoch 00047: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 451ms/step - loss: -0.7989 - cosine_similarity: 0.0023 - mean_absolute_error: 0.6751 - val_loss: -0.7868 - val_cosine_similarity: 0.0155 - val_mean_absolute_error: 0.6712
# Epoch 48/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7997 - cosine_similarity: 0.0052 - mean_absolute_error: 0.6766
# Epoch 00048: val_loss did not improve from -0.79772
#
# Epoch 00048: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 452ms/step - loss: -0.7997 - cosine_similarity: 0.0052 - mean_absolute_error: 0.6766 - val_loss: -0.7832 - val_cosine_similarity: 8.6995e-04 - val_mean_absolute_error: 0.6689
# Epoch 49/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7947 - cosine_similarity: -0.0194 - mean_absolute_error: 0.6690
# Epoch 00049: val_loss did not improve from -0.79772
#
# Epoch 00049: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 455ms/step - loss: -0.7947 - cosine_similarity: -0.0194 - mean_absolute_error: 0.6690 - val_loss: -0.7805 - val_cosine_similarity: 0.0075 - val_mean_absolute_error: 0.6773
# Epoch 50/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7882 - cosine_similarity: -0.0084 - mean_absolute_error: 0.6756
# Epoch 00050: val_loss did not improve from -0.79772
#
# Epoch 00050: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 450ms/step - loss: -0.7882 - cosine_similarity: -0.0084 - mean_absolute_error: 0.6756 - val_loss: -0.7857 - val_cosine_similarity: -0.0075 - val_mean_absolute_error: 0.6642
# Epoch 51/100
# 122/122 [==============================] - ETA: 0s - loss: -0.7876 - cosine_similarity: -0.0052 - mean_absolute_error: 0.6790
# Epoch 00051: val_loss did not improve from -0.79772
#
# Epoch 00051: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 55s 454ms/step - loss: -0.7876 - cosine_similarity: -0.0052 - mean_absolute_error: 0.6790 - val_loss: -0.7800 - val_cosine_similarity: 0.0042 - val_mean_absolute_error: 0.6683
# Epoch 52/100
# 121/122 [============================>.] - ETA: 0s - loss: -0.7799 - cosine_similarity: -0.0093 - mean_absolute_error: 0.6804
# Epoch 00052: val_loss did not improve from -0.79772
#
# Epoch 00052: saving model to models/last_alexnet_bs128.hdf5
# 122/122 [==============================] - 56s 457ms/step - loss: -0.7799 - cosine_similarity: -0.0086 - mean_absolute_error: 0.6807 - val_loss: -0.7365 - val_cosine_similarity: -0.0141 - val_mean_absolute_error: 0.6876
# Epoch 53/100
# 108/122 [=========================>....] - ETA: 3s - loss: -0.7786 - cosine_similarity: 0.0076 - mean_absolute_error: 0.6865
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-c988678e9852> in <module>
#      30
#      31 # Fit the model with the training and validation data, number of epochs and callbacks
# ---> 32 model.fit(
#      33     train_ds,
#      34     validation_data = validation_ds,
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
#save the last weights of the model
model.save(trained_model)

# %%
# taking samples from the validation dataset and evaluating the model
model.load_weights(snapshot_weights)
val_ex, = validation_ds.take(1)
train_ex, = train_ds.take(1)

images_v, labels_v = val_ex[0], val_ex[1]
images_t, labels_t = train_ex[0], train_ex[1]

#making the predictions for the taken images
outputs_v = model.predict(images_v)
outputs_t = model.predict(images_t)

# %%
# visualicing the results
for img,label,pred,i in zip(images_t, labels_t, outputs_t,range(5)):
    viz(img, label, pred)
# Out:
# #### **cartesian label:** [0.16731377 0.98049647]
# #### **cartesian prediction (x_y):** [0. 1.]
# #### **cartesian label:** [0.4517703  0.36574158]
# #### **cartesian prediction (x_y):** [3.0176991e-25 1.0000000e+00]
# #### **cartesian label:** [-0.76116306 -0.3486144 ]
# #### **cartesian prediction (x_y):** [1. 0.]
# #### **cartesian label:** [-0.7861912  0.6173104]
# #### **cartesian prediction (x_y):** [1.0000000e+00 5.0416993e-25]
# #### **cartesian label:** [-0.9037964 -0.0258896]
# #### **cartesian prediction (x_y):** [1.0000000e+00 1.6880419e-26]

# %%
for img,label,pred,i in zip(images_v, labels_v, outputs_v,range(5)):
    viz(img, label, pred)
# Out:
# #### **cartesian label:** [-0.48939455 -0.856485  ]
# #### **cartesian prediction (x_y):** [0. 1.]
# #### **cartesian label:** [0.8455837 0.2973527]
# #### **cartesian prediction (x_y):** [1. 0.]
# #### **cartesian label:** [-0.40102902 -0.2700917 ]
# #### **cartesian prediction (x_y):** [1.0000000e+00 1.3049807e-10]
# #### **cartesian label:** [-0.2558252   0.56686693]
# #### **cartesian prediction (x_y):** [0. 1.]
# #### **cartesian label:** [0.71419954 0.01388513]
# #### **cartesian prediction (x_y):** [0.8631362  0.13686384]
