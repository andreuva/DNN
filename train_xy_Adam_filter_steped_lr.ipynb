# %%
import os
from classification_models.tfkeras import Classifiers

# Import the ResNet34 model
ResNet34, preprocess_input = Classifiers.get('resnet34')

# %%
# Run only for training!
import glob
import math
import datetime
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
from sklearn.preprocessing import normalize

tfd = tfp.distributions
tfpl = tfp.layers
tfk = tf.keras
tfkl = tf.keras.layers

# Change parameters here...
log_dir = "logs/"
os.makedirs(log_dir, exist_ok=True)
data_dir = 'data/'
snapshot_weights = 'models/best_weights_xy_Adam_filter_steped_lr.hdf5'
last_snapshot_weights = 'models/last_weights_xy_Adam_filter_steped_lr.hdf5'

sizex = 500
sizey = 500
sizez = 3
rand_seed = 666
num_datasets = -1
batch_size = 32
nb_epochs = 200
validation_ratio = 0.2
#ds_size = len(data_dict['y_revs'])
ds_size = 250
buf_size = ds_size

# %%
# Collect all the .npz files
numpy_datasets = glob.glob(data_dir+'dataset*')

# %%
# load the data into a dictionary from npz files
data_dict = {}
for dataset in numpy_datasets[:num_datasets]:
    with np.load(dataset) as data:
        if 'y' in data_dict.keys():
            #data_dict['x_dust']   = np.append( data_dict['x_dust'], data['x_dust'],axis=0)
            data_dict['x_nodust'] = np.append( data_dict['x_nodust'], data['x_nodust'],axis=0)
            data_dict['y']        = np.append( data_dict['y'], data['y'],axis=0)
            data_dict['ids']      = np.append( data_dict['ids'], data['id'],axis=0)
        else:
            #data_dict['x_dust']   = data['x_dust']
            data_dict['x_nodust'] = data['x_nodust']
            data_dict['y']        = data['y']
            data_dict['ids']      = data['id']

# %%
# check the shape of the dictionary (100 images of 500x500x3 = 4 files of 25 images) before filtering
data_dict['x_nodust'].shape
# Out:
# (895, 500, 500, 3)

# %%
#Filter the galaxies that have less than 1e10 solar masses
bad_ids = [[galaxy_id,i] for galaxy_id,i in zip(data_dict['ids'],range(len(data_dict['ids']))) if 'e09' in galaxy_id or 'e10' in galaxy_id ]
bad_ids = np.array(bad_ids)
remove_galaxies = np.array(bad_ids[:,1],dtype=int)
print('there are ', len(bad_ids), ' galaxies to remove')
#print(remove_galaxies)
filtered_dict = {}

for key in data_dict.keys():
    data_dict[key] = np.delete(data_dict[key],remove_galaxies, axis=0)
    
print('Still have ', len(data_dict['ids']), ' galaxies left')
# Out:
# there are  490  galaxies to remove
# Still have  405  galaxies left

# %%
# check that we hace filtered the correct galaxies
data_dict['ids'][:15]
# Out:
# array(['g5.38e11_x73_y33_z282', 'g5.38e11_x118_y115_z5',
#        'g5.38e11_x4_y285_z273', 'g5.38e11_x207_y331_z254',
#        'g5.38e11_x138_y82_z188', 'g5.46e11_x134_y99_z113',
#        'g5.46e11_x111_y17_z326', 'g5.46e11_x311_y196_z302',
#        'g5.46e11_x306_y325_z297', 'g5.46e11_x50_y326_z189',
#        'g5.55e11_x310_y321_z331', 'g5.55e11_x7_y92_z328',
#        'g5.55e11_x245_y211_z81', 'g5.55e11_x245_y339_z176',
#        'g5.55e11_x342_y14_z192'], dtype='<U23')

# %%
# check the shape of the dictionary after filtering
data_dict['x_nodust'].shape
# Out:
# (405, 500, 500, 3)

# %%
# Compute the angles from the x,y,z labels
# theta = np.arctan(np.sqrt(x**2 + y**2)/z)
# phi = np.arctan(y/x)
def cart_to_esf(xyz):
    angles = np.empty( (len(xyz),2) )
    angles[:,0] = np.arctan2(np.sqrt(xyz[:,0]**2 + xyz[:,1]**2),xyz[:,2]) *180/np.pi #theta angle in degrees
    angles[:,1] = np.arctan2(xyz[:,1],xyz[:,0]) * 180/np.pi #phi angle in degrees
    return angles

# Define the function to go back to cartisian cordinates
def esf_to_cart(angles):
    xyz = np.empty( (len(angles),3) )
    ang_rad = angles*np.pi/180
    xyz[:,0] = np.sin(ang_rad[:,0])*np.cos(ang_rad[:,1])
    xyz[:,1] = np.sin(ang_rad[:,0])*np.sin(ang_rad[:,1])
    xyz[:,2] = np.cos(ang_rad[:,0])
    return xyz

#break the degeneracy of the solutions restricting the solution to 1 sector
def break_degeneracy(angles):
    ang_norm = angles
    for i in range(len(angles)):
        if ang_norm[:,1][i] < 0:
            ang_norm[:,1][i] = (ang_norm[:,1][i] + 180)
    return ang_norm

#map the solution to be between [0,1]
def map_to_1(angles, max = 180 ):
    ang_norm = angles/max
    return ang_norm

#coming back the mapping from 1 to 180
def map_to_180(ang_norm):
  angle = ang_norm*180
  return angle

# computing the normaliced vectors in 3D
data_dict['y_norm'] = normalize(data_dict['y'], axis=1)
data_dict['y_ang'] = map_to_1(break_degeneracy(cart_to_esf(normalize(data_dict['y'], axis=1))))
data_dict['y_revs'] = esf_to_cart(map_to_180(data_dict['y_ang']))

# %%
# check the shape of our dictionary in te labels entry
print(data_dict['y_norm'].shape)
# Out:
# (405, 3)

# %%
# separate in batches and shuffle the data with a fixed seed
#dataset = dataset.batch(batch_size)
#dataset = dataset.shuffle(10, seed=123)
AUTO = tf.data.experimental.AUTOTUNE

# %%
# functions to visualice the data 
def viz(img, label, pred=np.array([0,0,0]), id=None):
    fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(img, cmap='gray', vmin=0, vmax=255,origin='lower')
    ax.arrow(250,250,100*label[0],100*label[1], head_width=7, head_length=10, fc='g', ec='g')
    if np.sum(np.abs(pred)) > 0: ax.arrow(250,250,100*pred[0],100*pred[1], head_width=7, head_length=10, fc='r', ec='r')
        
    display(Markdown("#### **cartesian label:** {}".format(label)))
    if np.sum(np.abs(pred)) > 0: display(Markdown("#### **cartesian prediction (x_y):** {}".format(pred)))
    if id: display(Markdown("#### **ID:** {}".format(id)))
    plt.show()

# create the dataset from the dictionary and see the size and type
dataset = tf.data.Dataset.from_tensor_slices(data_dict)
print(dataset)
# Out:
# <TensorSliceDataset shapes: {x_nodust: (500, 500, 3), y: (3,), ids: (), y_norm: (3,), y_ang: (2,), y_revs: (3,)}, types: {x_nodust: tf.float64, y: tf.float64, ids: tf.string, y_norm: tf.float64, y_ang: tf.float64, y_revs: tf.float64}>

# %%
# visualice the data
real_dataset = dataset.batch(batch_size).shuffle(10, seed=rand_seed)
for idx in range(1,5):
    elements = real_dataset.take(idx)
    for elem in elements:
        viz(elem['x_nodust'][idx], elem['y_norm'][idx], elem['y_revs'][idx], id=elem['ids'][idx])
# Out:
# #### **cartesian label:** [ 0.46680332  0.76074614 -0.45095452]
# #### **cartesian prediction (x_y):** [ 0.46680332  0.76074614 -0.45095452]
# #### **ID:** b'g3.23e11_x192_y238_z218'
# #### **cartesian label:** [0.25409979 0.44085076 0.8608623 ]
# #### **cartesian prediction (x_y):** [0.25409979 0.44085076 0.8608623 ]
# #### **ID:** b'g2.04e11_x32_y348_z247'
# #### **cartesian label:** [-0.47901533 -0.07426079 -0.87465973]
# #### **cartesian prediction (x_y):** [ 0.47901533  0.07426079 -0.87465973]
# #### **ID:** b'g2.79e12_x52_y248_z101'
# #### **cartesian label:** [-0.1562322   0.30773711  0.93855707]
# #### **cartesian prediction (x_y):** [-0.1562322   0.30773711  0.93855707]
# #### **ID:** b'g3.49e11_x261_y183_z222'
# #### **cartesian label:** [ 0.18716548 -0.48423022  0.85468718]
# #### **cartesian prediction (x_y):** [-0.18716548  0.48423022  0.85468718]
# #### **ID:** b'g1.05e11_x241_y204_z49'
# #### **cartesian label:** [-0.48457038  0.83954677 -0.24566803]
# #### **cartesian prediction (x_y):** [-0.48457038  0.83954677 -0.24566803]
# #### **ID:** b'g2.19e11_x189_y233_z34'
# #### **cartesian label:** [ 0.30069015 -0.00199004  0.95371981]
# #### **cartesian prediction (x_y):** [-0.30069015  0.00199004  0.95371981]
# #### **ID:** b'g5.31e11_x50_y255_z112'
# #### **cartesian label:** [ 0.84659725 -0.32004032 -0.42526143]
# #### **cartesian prediction (x_y):** [-0.84659725  0.32004032 -0.42526143]
# #### **ID:** b'g3.49e11_x40_y55_z229'
# #### **cartesian label:** [-0.01737563 -0.14807151 -0.98882401]
# #### **cartesian prediction (x_y):** [ 0.01737563  0.14807151 -0.98882401]
# #### **ID:** b'g1.92e12_x342_y72_z264'
# #### **cartesian label:** [-0.62686766  0.70078731  0.34049095]
# #### **cartesian prediction (x_y):** [-0.62686766  0.70078731  0.34049095]
# #### **ID:** b'g1.05e11_x130_y269_z141'

# %%
# defining the train and validation dataset from the existing dictionary, shufling and batching
input_ds = (
    tf.data.Dataset.from_tensor_slices((data_dict['x_nodust'].astype(np.float32), data_dict['y_norm'][:,:2].astype(np.float32)))
                    # Use seed to ensure we always have the same validation data set!
                   .shuffle(ds_size, seed = rand_seed, reshuffle_each_iteration = False)
)

input_ds = input_ds.take(ds_size)
val_size = math.floor(ds_size * validation_ratio)

validation_ds = ( input_ds.take(val_size).batch(batch_size) )
train_ds = ( input_ds.skip(val_size).shuffle(buffer_size=buf_size, reshuffle_each_iteration=True).batch(batch_size) )

print(train_ds)
print(validation_ds)
# Out:
# <BatchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>

# %%
# %reload_ext tensorboard
# %tensorboard --logdir {log_dir} --reload_multifile True --host 0.0.0.0 --port 6006
# Out:
# Reusing TensorBoard on port 6006 (pid 23717), started 0:04:02 ago. (Use '!kill 23717' to kill it.)
#       <iframe id="tensorboard-frame-5eed5135cebf1c86" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5eed5135cebf1c86");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
# Build model
base_model = ResNet34(input_shape=(sizey,sizex,3), include_top=False)

# redefine the output to be 2 parameters from the last dense layer
x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tf.keras.layers.Dense(2, activation=None)(x)
model = tf.keras.models.Model(inputs=[base_model.input], outputs=[output])

# Use existing best weights if available...
if os.path.isfile(last_snapshot_weights):
    print('loaded weights')
    model.load_weights(last_snapshot_weights)
    
cossim = lambda y, p_y: -1*tf.keras.backend.abs(tf.keras.losses.cosine_similarity(y, p_y))
#define the learning rate schedule
def scheduler(epoch, lr):
    if epoch == 25:
        return lr / 10
    elif epoch == 100:
        return lr/10
    else:
        return lr


model.compile(optimizer= tf.keras.optimizers.Adam(),
              loss=cossim, metrics=[tf.keras.metrics.mean_squared_error, 
                                    tf.keras.metrics.mean_absolute_error, 
                                    tf.keras.metrics.mean_absolute_percentage_error])

# %%
# model.summary()

# For tensorboard
log_dir_s = log_dir + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
os.makedirs(log_dir_s, exist_ok=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir_s, histogram_freq=1, update_freq='batch', profile_batch=0)

# Checkpointing
checkpointer_1 = tf.keras.callbacks.ModelCheckpoint(filepath=snapshot_weights,
                               monitor='mean_absolute_error',
                               verbose=1,
                               save_best_only=True)
checkpointer_2 = tf.keras.callbacks.ModelCheckpoint(filepath=last_snapshot_weights,
                               monitor='mean_absolute_error',
                               verbose=1,
                               save_best_only=False)

LearningRateScheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

callbacks = [
    tensorboard_callback,
    checkpointer_1,
    checkpointer_2,
    LearningRateScheduler
]

model.fit(
    train_ds,
    validation_data = validation_ds,
    epochs = nb_epochs,
    callbacks = callbacks,)
    # class_weight=class_weight)
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6751 - mean_squared_error: 9.5180 - mean_absolute_error: 1.8752 - mean_absolute_percentage_error: 1225.4434
# Epoch 00001: mean_absolute_error improved from inf to 1.87518, saving model to models/best_weights_xy_Adam_filter_steped_lr.hdf5
#
# Epoch 00001: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.6751 - mean_squared_error: 9.5180 - mean_absolute_error: 1.8752 - mean_absolute_percentage_error: 1225.4434 - val_loss: -0.6581 - val_mean_squared_error: 3035292311224320.0000 - val_mean_absolute_error: 38564820.0000 - val_mean_absolute_percentage_error: 15550861312.0000 - lr: 0.0010
# Epoch 2/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7175 - mean_squared_error: 19.9294 - mean_absolute_error: 2.4522 - mean_absolute_percentage_error: 1314.3516
# Epoch 00002: mean_absolute_error did not improve from 1.87518
#
# Epoch 00002: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7175 - mean_squared_error: 19.9294 - mean_absolute_error: 2.4522 - mean_absolute_percentage_error: 1314.3516 - val_loss: -0.6866 - val_mean_squared_error: 651744979714048.0000 - val_mean_absolute_error: 15523494.0000 - val_mean_absolute_percentage_error: 5249332736.0000 - lr: 0.0010
# Epoch 3/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7380 - mean_squared_error: 13.3204 - mean_absolute_error: 2.0223 - mean_absolute_percentage_error: 1777.7894
# Epoch 00003: mean_absolute_error did not improve from 1.87518
#
# Epoch 00003: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7380 - mean_squared_error: 13.3204 - mean_absolute_error: 2.0223 - mean_absolute_percentage_error: 1777.7894 - val_loss: -0.7062 - val_mean_squared_error: 513938456576.0000 - val_mean_absolute_error: 458658.9688 - val_mean_absolute_percentage_error: 169375424.0000 - lr: 0.0010
# Epoch 4/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7288 - mean_squared_error: 4.6022 - mean_absolute_error: 1.3765 - mean_absolute_percentage_error: 927.4944
# Epoch 00004: mean_absolute_error improved from 1.87518 to 1.37649, saving model to models/best_weights_xy_Adam_filter_steped_lr.hdf5
#
# Epoch 00004: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7288 - mean_squared_error: 4.6022 - mean_absolute_error: 1.3765 - mean_absolute_percentage_error: 927.4944 - val_loss: -0.7111 - val_mean_squared_error: 608620445696.0000 - val_mean_absolute_error: 536792.1875 - val_mean_absolute_percentage_error: 211182096.0000 - lr: 0.0010
# Epoch 5/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7258 - mean_squared_error: 4.1055 - mean_absolute_error: 1.3624 - mean_absolute_percentage_error: 807.5403
# Epoch 00005: mean_absolute_error improved from 1.37649 to 1.36244, saving model to models/best_weights_xy_Adam_filter_steped_lr.hdf5
#
# Epoch 00005: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7258 - mean_squared_error: 4.1055 - mean_absolute_error: 1.3624 - mean_absolute_percentage_error: 807.5403 - val_loss: -0.7033 - val_mean_squared_error: 6721572962304.0000 - val_mean_absolute_error: 1628829.2500 - val_mean_absolute_percentage_error: 586193856.0000 - lr: 0.0010
# Epoch 6/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7177 - mean_squared_error: 5.0220 - mean_absolute_error: 1.5177 - mean_absolute_percentage_error: 744.0678
# Epoch 00006: mean_absolute_error did not improve from 1.36244
#
# Epoch 00006: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7177 - mean_squared_error: 5.0220 - mean_absolute_error: 1.5177 - mean_absolute_percentage_error: 744.0678 - val_loss: -0.7113 - val_mean_squared_error: 5477829705728.0000 - val_mean_absolute_error: 1529654.7500 - val_mean_absolute_percentage_error: 595881920.0000 - lr: 0.0010
# Epoch 7/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7416 - mean_squared_error: 3.2809 - mean_absolute_error: 1.3643 - mean_absolute_percentage_error: 679.5471
# Epoch 00007: mean_absolute_error did not improve from 1.36244
#
# Epoch 00007: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7416 - mean_squared_error: 3.2809 - mean_absolute_error: 1.3643 - mean_absolute_percentage_error: 679.5471 - val_loss: -0.7122 - val_mean_squared_error: 1416895922176.0000 - val_mean_absolute_error: 797058.8125 - val_mean_absolute_percentage_error: 316711904.0000 - lr: 0.0010
# Epoch 8/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7035 - mean_squared_error: 2.9117 - mean_absolute_error: 1.3086 - mean_absolute_percentage_error: 755.1209
# Epoch 00008: mean_absolute_error improved from 1.36244 to 1.30859, saving model to models/best_weights_xy_Adam_filter_steped_lr.hdf5
#
# Epoch 00008: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7035 - mean_squared_error: 2.9117 - mean_absolute_error: 1.3086 - mean_absolute_percentage_error: 755.1209 - val_loss: -0.7149 - val_mean_squared_error: 894781161472.0000 - val_mean_absolute_error: 637967.4375 - val_mean_absolute_percentage_error: 261750368.0000 - lr: 0.0010
# Epoch 9/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7308 - mean_squared_error: 2.9111 - mean_absolute_error: 1.3111 - mean_absolute_percentage_error: 792.3426
# Epoch 00009: mean_absolute_error did not improve from 1.30859
#
# Epoch 00009: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7308 - mean_squared_error: 2.9111 - mean_absolute_error: 1.3111 - mean_absolute_percentage_error: 792.3426 - val_loss: -0.7179 - val_mean_squared_error: 127560916992.0000 - val_mean_absolute_error: 251849.7188 - val_mean_absolute_percentage_error: 111248096.0000 - lr: 0.0010
# Epoch 10/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7374 - mean_squared_error: 3.1013 - mean_absolute_error: 1.3423 - mean_absolute_percentage_error: 795.2574
# Epoch 00010: mean_absolute_error did not improve from 1.30859
#
# Epoch 00010: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7374 - mean_squared_error: 3.1013 - mean_absolute_error: 1.3423 - mean_absolute_percentage_error: 795.2574 - val_loss: -0.7143 - val_mean_squared_error: 12685499392.0000 - val_mean_absolute_error: 74061.8672 - val_mean_absolute_percentage_error: 29881922.0000 - lr: 0.0010
# Epoch 11/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7390 - mean_squared_error: 3.1926 - mean_absolute_error: 1.3705 - mean_absolute_percentage_error: 772.5140
# Epoch 00011: mean_absolute_error did not improve from 1.30859
#
# Epoch 00011: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7390 - mean_squared_error: 3.1926 - mean_absolute_error: 1.3705 - mean_absolute_percentage_error: 772.5140 - val_loss: -0.7123 - val_mean_squared_error: 1102969728.0000 - val_mean_absolute_error: 21292.0430 - val_mean_absolute_percentage_error: 8342751.5000 - lr: 0.0010
# Epoch 12/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7347 - mean_squared_error: 3.1827 - mean_absolute_error: 1.3717 - mean_absolute_percentage_error: 771.6219
# Epoch 00012: mean_absolute_error did not improve from 1.30859
#
# Epoch 00012: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7347 - mean_squared_error: 3.1827 - mean_absolute_error: 1.3717 - mean_absolute_percentage_error: 771.6219 - val_loss: -0.7083 - val_mean_squared_error: 169682672.0000 - val_mean_absolute_error: 8039.7637 - val_mean_absolute_percentage_error: 3006294.7500 - lr: 0.0010
# Epoch 13/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7373 - mean_squared_error: 3.3585 - mean_absolute_error: 1.3648 - mean_absolute_percentage_error: 747.8441
# Epoch 00013: mean_absolute_error did not improve from 1.30859
#
# Epoch 00013: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7373 - mean_squared_error: 3.3585 - mean_absolute_error: 1.3648 - mean_absolute_percentage_error: 747.8441 - val_loss: -0.7151 - val_mean_squared_error: 19436222.0000 - val_mean_absolute_error: 2850.5300 - val_mean_absolute_percentage_error: 1155485.2500 - lr: 0.0010
# Epoch 14/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7309 - mean_squared_error: 3.3050 - mean_absolute_error: 1.3693 - mean_absolute_percentage_error: 767.6192
# Epoch 00014: mean_absolute_error did not improve from 1.30859
#
# Epoch 00014: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7309 - mean_squared_error: 3.3050 - mean_absolute_error: 1.3693 - mean_absolute_percentage_error: 767.6192 - val_loss: -0.7174 - val_mean_squared_error: 1999774.3750 - val_mean_absolute_error: 904.9358 - val_mean_absolute_percentage_error: 369206.7500 - lr: 0.0010
# Epoch 15/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7424 - mean_squared_error: 2.9146 - mean_absolute_error: 1.3316 - mean_absolute_percentage_error: 706.9779
# Epoch 00015: mean_absolute_error did not improve from 1.30859
#
# Epoch 00015: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7424 - mean_squared_error: 2.9146 - mean_absolute_error: 1.3316 - mean_absolute_percentage_error: 706.9779 - val_loss: -0.7007 - val_mean_squared_error: 183308.9531 - val_mean_absolute_error: 259.7859 - val_mean_absolute_percentage_error: 101131.4688 - lr: 0.0010
# Epoch 16/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7268 - mean_squared_error: 2.9871 - mean_absolute_error: 1.3144 - mean_absolute_percentage_error: 726.5771
# Epoch 00016: mean_absolute_error did not improve from 1.30859
#
# Epoch 00016: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7268 - mean_squared_error: 2.9871 - mean_absolute_error: 1.3144 - mean_absolute_percentage_error: 726.5771 - val_loss: -0.6788 - val_mean_squared_error: 9919.6270 - val_mean_absolute_error: 52.3375 - val_mean_absolute_percentage_error: 17902.5156 - lr: 0.0010
# Epoch 17/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7405 - mean_squared_error: 3.1387 - mean_absolute_error: 1.3276 - mean_absolute_percentage_error: 751.8947
# Epoch 00017: mean_absolute_error did not improve from 1.30859
#
# Epoch 00017: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7405 - mean_squared_error: 3.1387 - mean_absolute_error: 1.3276 - mean_absolute_percentage_error: 751.8947 - val_loss: -0.6893 - val_mean_squared_error: 49137.6016 - val_mean_absolute_error: 133.8438 - val_mean_absolute_percentage_error: 52505.2305 - lr: 0.0010
# Epoch 18/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7299 - mean_squared_error: 3.3961 - mean_absolute_error: 1.4251 - mean_absolute_percentage_error: 804.5318
# Epoch 00018: mean_absolute_error did not improve from 1.30859
#
# Epoch 00018: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7299 - mean_squared_error: 3.3961 - mean_absolute_error: 1.4251 - mean_absolute_percentage_error: 804.5318 - val_loss: -0.6846 - val_mean_squared_error: 18449.7129 - val_mean_absolute_error: 84.0150 - val_mean_absolute_percentage_error: 33522.1562 - lr: 0.0010
# Epoch 19/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7145 - mean_squared_error: 3.4000 - mean_absolute_error: 1.4945 - mean_absolute_percentage_error: 908.0209
# Epoch 00019: mean_absolute_error did not improve from 1.30859
#
# Epoch 00019: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7145 - mean_squared_error: 3.4000 - mean_absolute_error: 1.4945 - mean_absolute_percentage_error: 908.0209 - val_loss: -0.6915 - val_mean_squared_error: 4910.7905 - val_mean_absolute_error: 41.2793 - val_mean_absolute_percentage_error: 15630.3447 - lr: 0.0010
# Epoch 20/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7157 - mean_squared_error: 3.5463 - mean_absolute_error: 1.5167 - mean_absolute_percentage_error: 919.2793
# Epoch 00020: mean_absolute_error did not improve from 1.30859
#
# Epoch 00020: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7157 - mean_squared_error: 3.5463 - mean_absolute_error: 1.5167 - mean_absolute_percentage_error: 919.2793 - val_loss: -0.6954 - val_mean_squared_error: 823.3861 - val_mean_absolute_error: 15.4084 - val_mean_absolute_percentage_error: 5525.3188 - lr: 0.0010
# Epoch 21/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7282 - mean_squared_error: 3.6977 - mean_absolute_error: 1.4932 - mean_absolute_percentage_error: 917.5810
# Epoch 00021: mean_absolute_error did not improve from 1.30859
#
# Epoch 00021: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7282 - mean_squared_error: 3.6977 - mean_absolute_error: 1.4932 - mean_absolute_percentage_error: 917.5810 - val_loss: -0.6125 - val_mean_squared_error: 2.0217 - val_mean_absolute_error: 1.2219 - val_mean_absolute_percentage_error: 697.8257 - lr: 0.0010
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7366 - mean_squared_error: 3.2914 - mean_absolute_error: 1.4476 - mean_absolute_percentage_error: 810.2552
# Epoch 00022: mean_absolute_error did not improve from 1.30859
#
# Epoch 00022: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7366 - mean_squared_error: 3.2914 - mean_absolute_error: 1.4476 - mean_absolute_percentage_error: 810.2552 - val_loss: -0.6189 - val_mean_squared_error: 2.4173 - val_mean_absolute_error: 1.3466 - val_mean_absolute_percentage_error: 759.8159 - lr: 0.0010
# Epoch 23/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7353 - mean_squared_error: 3.2343 - mean_absolute_error: 1.4305 - mean_absolute_percentage_error: 802.1586
# Epoch 00023: mean_absolute_error did not improve from 1.30859
#
# Epoch 00023: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7353 - mean_squared_error: 3.2343 - mean_absolute_error: 1.4305 - mean_absolute_percentage_error: 802.1586 - val_loss: -0.6190 - val_mean_squared_error: 2.4888 - val_mean_absolute_error: 1.3680 - val_mean_absolute_percentage_error: 771.0919 - lr: 0.0010
# Epoch 24/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7397 - mean_squared_error: 3.1257 - mean_absolute_error: 1.4260 - mean_absolute_percentage_error: 806.5865
# Epoch 00024: mean_absolute_error did not improve from 1.30859
#
# Epoch 00024: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7397 - mean_squared_error: 3.1257 - mean_absolute_error: 1.4260 - mean_absolute_percentage_error: 806.5865 - val_loss: -0.6214 - val_mean_squared_error: 2.5619 - val_mean_absolute_error: 1.3828 - val_mean_absolute_percentage_error: 769.0339 - lr: 0.0010
# Epoch 25/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7348 - mean_squared_error: 3.4319 - mean_absolute_error: 1.4447 - mean_absolute_percentage_error: 818.4332
# Epoch 00025: mean_absolute_error did not improve from 1.30859
#
# Epoch 00025: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7348 - mean_squared_error: 3.4319 - mean_absolute_error: 1.4447 - mean_absolute_percentage_error: 818.4332 - val_loss: -0.6308 - val_mean_squared_error: 2.6368 - val_mean_absolute_error: 1.3826 - val_mean_absolute_percentage_error: 727.6685 - lr: 0.0010
# Epoch 26/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7341 - mean_squared_error: 3.3372 - mean_absolute_error: 1.4422 - mean_absolute_percentage_error: 793.8699
# Epoch 00026: mean_absolute_error did not improve from 1.30859
#
# Epoch 00026: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7341 - mean_squared_error: 3.3372 - mean_absolute_error: 1.4422 - mean_absolute_percentage_error: 793.8699 - val_loss: -0.6319 - val_mean_squared_error: 2.6682 - val_mean_absolute_error: 1.3885 - val_mean_absolute_percentage_error: 725.2188 - lr: 1.0000e-04
# Epoch 27/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7394 - mean_squared_error: 3.4205 - mean_absolute_error: 1.4456 - mean_absolute_percentage_error: 777.6040
# Epoch 00027: mean_absolute_error did not improve from 1.30859
#
# Epoch 00027: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7394 - mean_squared_error: 3.4205 - mean_absolute_error: 1.4456 - mean_absolute_percentage_error: 777.6040 - val_loss: -0.6329 - val_mean_squared_error: 2.7031 - val_mean_absolute_error: 1.3958 - val_mean_absolute_percentage_error: 724.7860 - lr: 1.0000e-04
# Epoch 28/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7390 - mean_squared_error: 3.4040 - mean_absolute_error: 1.4223 - mean_absolute_percentage_error: 764.4720
# Epoch 00028: mean_absolute_error did not improve from 1.30859
#
# Epoch 00028: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7390 - mean_squared_error: 3.4040 - mean_absolute_error: 1.4223 - mean_absolute_percentage_error: 764.4720 - val_loss: -0.6329 - val_mean_squared_error: 2.7469 - val_mean_absolute_error: 1.4072 - val_mean_absolute_percentage_error: 730.9542 - lr: 1.0000e-04
# Epoch 29/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7409 - mean_squared_error: 3.2491 - mean_absolute_error: 1.4398 - mean_absolute_percentage_error: 793.0151
# Epoch 00029: mean_absolute_error did not improve from 1.30859
#
# Epoch 00029: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7409 - mean_squared_error: 3.2491 - mean_absolute_error: 1.4398 - mean_absolute_percentage_error: 793.0151 - val_loss: -0.6331 - val_mean_squared_error: 2.8044 - val_mean_absolute_error: 1.4216 - val_mean_absolute_percentage_error: 737.8860 - lr: 1.0000e-04
# Epoch 30/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7375 - mean_squared_error: 3.3834 - mean_absolute_error: 1.4409 - mean_absolute_percentage_error: 795.9402
# Epoch 00030: mean_absolute_error did not improve from 1.30859
#
# Epoch 00030: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7375 - mean_squared_error: 3.3834 - mean_absolute_error: 1.4409 - mean_absolute_percentage_error: 795.9402 - val_loss: -0.6333 - val_mean_squared_error: 2.8374 - val_mean_absolute_error: 1.4296 - val_mean_absolute_percentage_error: 741.4185 - lr: 1.0000e-04
# Epoch 31/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7358 - mean_squared_error: 3.3854 - mean_absolute_error: 1.4691 - mean_absolute_percentage_error: 806.9778
# Epoch 00031: mean_absolute_error did not improve from 1.30859
#
# Epoch 00031: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7358 - mean_squared_error: 3.3854 - mean_absolute_error: 1.4691 - mean_absolute_percentage_error: 806.9778 - val_loss: -0.6325 - val_mean_squared_error: 2.8781 - val_mean_absolute_error: 1.4417 - val_mean_absolute_percentage_error: 751.8038 - lr: 1.0000e-04
# Epoch 32/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7382 - mean_squared_error: 3.4899 - mean_absolute_error: 1.4617 - mean_absolute_percentage_error: 824.1738
# Epoch 00032: mean_absolute_error did not improve from 1.30859
#
# Epoch 00032: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7382 - mean_squared_error: 3.4899 - mean_absolute_error: 1.4617 - mean_absolute_percentage_error: 824.1738 - val_loss: -0.6324 - val_mean_squared_error: 2.9081 - val_mean_absolute_error: 1.4495 - val_mean_absolute_percentage_error: 756.9172 - lr: 1.0000e-04
# Epoch 33/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7254 - mean_squared_error: 3.4394 - mean_absolute_error: 1.4745 - mean_absolute_percentage_error: 802.4940
# Epoch 00033: mean_absolute_error did not improve from 1.30859
#
# Epoch 00033: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7254 - mean_squared_error: 3.4394 - mean_absolute_error: 1.4745 - mean_absolute_percentage_error: 802.4940 - val_loss: -0.6325 - val_mean_squared_error: 2.9595 - val_mean_absolute_error: 1.4617 - val_mean_absolute_percentage_error: 763.4308 - lr: 1.0000e-04
# Epoch 34/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7376 - mean_squared_error: 3.4608 - mean_absolute_error: 1.4637 - mean_absolute_percentage_error: 804.0224
# Epoch 00034: mean_absolute_error did not improve from 1.30859
#
# Epoch 00034: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7376 - mean_squared_error: 3.4608 - mean_absolute_error: 1.4637 - mean_absolute_percentage_error: 804.0224 - val_loss: -0.6319 - val_mean_squared_error: 3.0189 - val_mean_absolute_error: 1.4787 - val_mean_absolute_percentage_error: 774.8541 - lr: 1.0000e-04
# Epoch 35/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7392 - mean_squared_error: 3.3911 - mean_absolute_error: 1.4353 - mean_absolute_percentage_error: 801.7145
# Epoch 00035: mean_absolute_error did not improve from 1.30859
#
# Epoch 00035: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7392 - mean_squared_error: 3.3911 - mean_absolute_error: 1.4353 - mean_absolute_percentage_error: 801.7145 - val_loss: -0.6313 - val_mean_squared_error: 3.0670 - val_mean_absolute_error: 1.4924 - val_mean_absolute_percentage_error: 784.9391 - lr: 1.0000e-04
# Epoch 36/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7393 - mean_squared_error: 3.3575 - mean_absolute_error: 1.4489 - mean_absolute_percentage_error: 783.2379
# Epoch 00036: mean_absolute_error did not improve from 1.30859
#
# Epoch 00036: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7393 - mean_squared_error: 3.3575 - mean_absolute_error: 1.4489 - mean_absolute_percentage_error: 783.2379 - val_loss: -0.6311 - val_mean_squared_error: 3.0968 - val_mean_absolute_error: 1.5009 - val_mean_absolute_percentage_error: 790.9766 - lr: 1.0000e-04
# Epoch 37/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7425 - mean_squared_error: 3.3453 - mean_absolute_error: 1.4560 - mean_absolute_percentage_error: 834.0051
# Epoch 00037: mean_absolute_error did not improve from 1.30859
#
# Epoch 00037: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7425 - mean_squared_error: 3.3453 - mean_absolute_error: 1.4560 - mean_absolute_percentage_error: 834.0051 - val_loss: -0.6304 - val_mean_squared_error: 3.1240 - val_mean_absolute_error: 1.5098 - val_mean_absolute_percentage_error: 799.0411 - lr: 1.0000e-04
# Epoch 38/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7338 - mean_squared_error: 3.2864 - mean_absolute_error: 1.4565 - mean_absolute_percentage_error: 822.2587
# Epoch 00038: mean_absolute_error did not improve from 1.30859
#
# Epoch 00038: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7338 - mean_squared_error: 3.2864 - mean_absolute_error: 1.4565 - mean_absolute_percentage_error: 822.2587 - val_loss: -0.6294 - val_mean_squared_error: 3.1443 - val_mean_absolute_error: 1.5181 - val_mean_absolute_percentage_error: 808.8915 - lr: 1.0000e-04
# Epoch 39/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7298 - mean_squared_error: 3.3222 - mean_absolute_error: 1.4585 - mean_absolute_percentage_error: 793.6688
# Epoch 00039: mean_absolute_error did not improve from 1.30859
#
# Epoch 00039: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7298 - mean_squared_error: 3.3222 - mean_absolute_error: 1.4585 - mean_absolute_percentage_error: 793.6688 - val_loss: -0.6294 - val_mean_squared_error: 3.1693 - val_mean_absolute_error: 1.5245 - val_mean_absolute_percentage_error: 812.6774 - lr: 1.0000e-04
# Epoch 40/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7398 - mean_squared_error: 3.3485 - mean_absolute_error: 1.4440 - mean_absolute_percentage_error: 779.6830
# Epoch 00040: mean_absolute_error did not improve from 1.30859
#
# Epoch 00040: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7398 - mean_squared_error: 3.3485 - mean_absolute_error: 1.4440 - mean_absolute_percentage_error: 779.6830 - val_loss: -0.6296 - val_mean_squared_error: 3.1918 - val_mean_absolute_error: 1.5294 - val_mean_absolute_percentage_error: 814.3898 - lr: 1.0000e-04
# Epoch 41/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7524 - mean_squared_error: 3.2971 - mean_absolute_error: 1.4306 - mean_absolute_percentage_error: 798.1548
# Epoch 00041: mean_absolute_error did not improve from 1.30859
#
# Epoch 00041: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7524 - mean_squared_error: 3.2971 - mean_absolute_error: 1.4306 - mean_absolute_percentage_error: 798.1548 - val_loss: -0.6298 - val_mean_squared_error: 3.2177 - val_mean_absolute_error: 1.5351 - val_mean_absolute_percentage_error: 817.1292 - lr: 1.0000e-04
# Epoch 42/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7431 - mean_squared_error: 3.4200 - mean_absolute_error: 1.4638 - mean_absolute_percentage_error: 815.0040
# Epoch 00042: mean_absolute_error did not improve from 1.30859
#
# Epoch 00042: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7431 - mean_squared_error: 3.4200 - mean_absolute_error: 1.4638 - mean_absolute_percentage_error: 815.0040 - val_loss: -0.6315 - val_mean_squared_error: 3.2342 - val_mean_absolute_error: 1.5304 - val_mean_absolute_percentage_error: 807.6110 - lr: 1.0000e-04
# Epoch 43/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7347 - mean_squared_error: 3.3557 - mean_absolute_error: 1.4215 - mean_absolute_percentage_error: 755.8815
# Epoch 00043: mean_absolute_error did not improve from 1.30859
#
# Epoch 00043: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.7347 - mean_squared_error: 3.3557 - mean_absolute_error: 1.4215 - mean_absolute_percentage_error: 755.8815 - val_loss: -0.6333 - val_mean_squared_error: 3.2437 - val_mean_absolute_error: 1.5248 - val_mean_absolute_percentage_error: 796.8610 - lr: 1.0000e-04
# Epoch 44/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7344 - mean_squared_error: 3.4102 - mean_absolute_error: 1.4533 - mean_absolute_percentage_error: 789.8175
# Epoch 00044: mean_absolute_error did not improve from 1.30859
#
# Epoch 00044: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.7344 - mean_squared_error: 3.4102 - mean_absolute_error: 1.4533 - mean_absolute_percentage_error: 789.8175 - val_loss: -0.6347 - val_mean_squared_error: 3.2464 - val_mean_absolute_error: 1.5219 - val_mean_absolute_percentage_error: 787.4547 - lr: 1.0000e-04
# Epoch 45/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7450 - mean_squared_error: 3.4852 - mean_absolute_error: 1.4471 - mean_absolute_percentage_error: 785.1024
# Epoch 00045: mean_absolute_error did not improve from 1.30859
#
# Epoch 00045: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7450 - mean_squared_error: 3.4852 - mean_absolute_error: 1.4471 - mean_absolute_percentage_error: 785.1024 - val_loss: -0.6357 - val_mean_squared_error: 3.2537 - val_mean_absolute_error: 1.5218 - val_mean_absolute_percentage_error: 781.3480 - lr: 1.0000e-04
# Epoch 46/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7365 - mean_squared_error: 3.1995 - mean_absolute_error: 1.4246 - mean_absolute_percentage_error: 767.9202
# Epoch 00046: mean_absolute_error did not improve from 1.30859
#
# Epoch 00046: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7365 - mean_squared_error: 3.1995 - mean_absolute_error: 1.4246 - mean_absolute_percentage_error: 767.9202 - val_loss: -0.6362 - val_mean_squared_error: 3.2443 - val_mean_absolute_error: 1.5193 - val_mean_absolute_percentage_error: 776.1053 - lr: 1.0000e-04
# Epoch 47/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7423 - mean_squared_error: 3.4358 - mean_absolute_error: 1.4107 - mean_absolute_percentage_error: 767.4723
# Epoch 00047: mean_absolute_error did not improve from 1.30859
#
# Epoch 00047: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7423 - mean_squared_error: 3.4358 - mean_absolute_error: 1.4107 - mean_absolute_percentage_error: 767.4723 - val_loss: -0.6359 - val_mean_squared_error: 3.2581 - val_mean_absolute_error: 1.5264 - val_mean_absolute_percentage_error: 780.8953 - lr: 1.0000e-04
# Epoch 48/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7371 - mean_squared_error: 3.1907 - mean_absolute_error: 1.3997 - mean_absolute_percentage_error: 775.2361
# Epoch 00048: mean_absolute_error did not improve from 1.30859
#
# Epoch 00048: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7371 - mean_squared_error: 3.1907 - mean_absolute_error: 1.3997 - mean_absolute_percentage_error: 775.2361 - val_loss: -0.6362 - val_mean_squared_error: 3.2629 - val_mean_absolute_error: 1.5271 - val_mean_absolute_percentage_error: 779.4861 - lr: 1.0000e-04
# Epoch 49/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7302 - mean_squared_error: 3.2308 - mean_absolute_error: 1.4084 - mean_absolute_percentage_error: 753.2363
# Epoch 00049: mean_absolute_error did not improve from 1.30859
#
# Epoch 00049: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7302 - mean_squared_error: 3.2308 - mean_absolute_error: 1.4084 - mean_absolute_percentage_error: 753.2363 - val_loss: -0.6372 - val_mean_squared_error: 3.2513 - val_mean_absolute_error: 1.5219 - val_mean_absolute_percentage_error: 771.5273 - lr: 1.0000e-04
# Epoch 50/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7376 - mean_squared_error: 3.1048 - mean_absolute_error: 1.3880 - mean_absolute_percentage_error: 760.6250
# Epoch 00050: mean_absolute_error did not improve from 1.30859
#
# Epoch 00050: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7376 - mean_squared_error: 3.1048 - mean_absolute_error: 1.3880 - mean_absolute_percentage_error: 760.6250 - val_loss: -0.6376 - val_mean_squared_error: 3.2344 - val_mean_absolute_error: 1.5169 - val_mean_absolute_percentage_error: 766.8644 - lr: 1.0000e-04
# Epoch 51/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7265 - mean_squared_error: 3.1943 - mean_absolute_error: 1.3667 - mean_absolute_percentage_error: 716.6854
# Epoch 00051: mean_absolute_error did not improve from 1.30859
#
# Epoch 00051: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7265 - mean_squared_error: 3.1943 - mean_absolute_error: 1.3667 - mean_absolute_percentage_error: 716.6854 - val_loss: -0.6375 - val_mean_squared_error: 3.1718 - val_mean_absolute_error: 1.5023 - val_mean_absolute_percentage_error: 759.3961 - lr: 1.0000e-04
# Epoch 52/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7377 - mean_squared_error: 3.1247 - mean_absolute_error: 1.3552 - mean_absolute_percentage_error: 712.2668
# Epoch 00052: mean_absolute_error did not improve from 1.30859
#
# Epoch 00052: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7377 - mean_squared_error: 3.1247 - mean_absolute_error: 1.3552 - mean_absolute_percentage_error: 712.2668 - val_loss: -0.6373 - val_mean_squared_error: 3.1167 - val_mean_absolute_error: 1.4898 - val_mean_absolute_percentage_error: 754.1799 - lr: 1.0000e-04
# Epoch 53/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7381 - mean_squared_error: 3.1024 - mean_absolute_error: 1.2992 - mean_absolute_percentage_error: 687.9474
# Epoch 00053: mean_absolute_error improved from 1.30859 to 1.29924, saving model to models/best_weights_xy_Adam_filter_steped_lr.hdf5
#
# Epoch 00053: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7381 - mean_squared_error: 3.1024 - mean_absolute_error: 1.2992 - mean_absolute_percentage_error: 687.9474 - val_loss: -0.6374 - val_mean_squared_error: 3.0390 - val_mean_absolute_error: 1.4706 - val_mean_absolute_percentage_error: 743.0918 - lr: 1.0000e-04
# Epoch 54/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7400 - mean_squared_error: 3.0736 - mean_absolute_error: 1.2899 - mean_absolute_percentage_error: 674.0274
# Epoch 00054: mean_absolute_error improved from 1.29924 to 1.28993, saving model to models/best_weights_xy_Adam_filter_steped_lr.hdf5
#
# Epoch 00054: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7400 - mean_squared_error: 3.0736 - mean_absolute_error: 1.2899 - mean_absolute_percentage_error: 674.0274 - val_loss: -0.6373 - val_mean_squared_error: 2.9604 - val_mean_absolute_error: 1.4516 - val_mean_absolute_percentage_error: 733.6477 - lr: 1.0000e-04
# Epoch 55/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7392 - mean_squared_error: 3.0640 - mean_absolute_error: 1.3384 - mean_absolute_percentage_error: 712.1450
# Epoch 00055: mean_absolute_error did not improve from 1.28993
#
# Epoch 00055: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7392 - mean_squared_error: 3.0640 - mean_absolute_error: 1.3384 - mean_absolute_percentage_error: 712.1450 - val_loss: -0.6371 - val_mean_squared_error: 2.9116 - val_mean_absolute_error: 1.4400 - val_mean_absolute_percentage_error: 728.5892 - lr: 1.0000e-04
# Epoch 56/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7379 - mean_squared_error: 3.0879 - mean_absolute_error: 1.3302 - mean_absolute_percentage_error: 668.9951
# Epoch 00056: mean_absolute_error did not improve from 1.28993
#
# Epoch 00056: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7379 - mean_squared_error: 3.0879 - mean_absolute_error: 1.3302 - mean_absolute_percentage_error: 668.9951 - val_loss: -0.6368 - val_mean_squared_error: 2.8685 - val_mean_absolute_error: 1.4300 - val_mean_absolute_percentage_error: 724.9710 - lr: 1.0000e-04
# Epoch 57/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7382 - mean_squared_error: 3.2475 - mean_absolute_error: 1.3799 - mean_absolute_percentage_error: 771.3260
# Epoch 00057: mean_absolute_error did not improve from 1.28993
#
# Epoch 00057: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7382 - mean_squared_error: 3.2475 - mean_absolute_error: 1.3799 - mean_absolute_percentage_error: 771.3260 - val_loss: -0.6367 - val_mean_squared_error: 2.8492 - val_mean_absolute_error: 1.4253 - val_mean_absolute_percentage_error: 722.6941 - lr: 1.0000e-04
# Epoch 58/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7414 - mean_squared_error: 3.3894 - mean_absolute_error: 1.4134 - mean_absolute_percentage_error: 794.2065
# Epoch 00058: mean_absolute_error did not improve from 1.28993
#
# Epoch 00058: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.7414 - mean_squared_error: 3.3894 - mean_absolute_error: 1.4134 - mean_absolute_percentage_error: 794.2065 - val_loss: -0.6365 - val_mean_squared_error: 2.8341 - val_mean_absolute_error: 1.4221 - val_mean_absolute_percentage_error: 722.3244 - lr: 1.0000e-04
# Epoch 59/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7411 - mean_squared_error: 3.4088 - mean_absolute_error: 1.4252 - mean_absolute_percentage_error: 752.3083
# Epoch 00059: mean_absolute_error did not improve from 1.28993
#
# Epoch 00059: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7411 - mean_squared_error: 3.4088 - mean_absolute_error: 1.4252 - mean_absolute_percentage_error: 752.3083 - val_loss: -0.6357 - val_mean_squared_error: 2.8351 - val_mean_absolute_error: 1.4199 - val_mean_absolute_percentage_error: 726.0438 - lr: 1.0000e-04
# Epoch 60/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7440 - mean_squared_error: 3.3666 - mean_absolute_error: 1.4233 - mean_absolute_percentage_error: 771.7567
# Epoch 00060: mean_absolute_error did not improve from 1.28993
#
# Epoch 00060: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7440 - mean_squared_error: 3.3666 - mean_absolute_error: 1.4233 - mean_absolute_percentage_error: 771.7567 - val_loss: -0.6386 - val_mean_squared_error: 2.8356 - val_mean_absolute_error: 1.4096 - val_mean_absolute_percentage_error: 720.2803 - lr: 1.0000e-04
# Epoch 61/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7441 - mean_squared_error: 3.3766 - mean_absolute_error: 1.4434 - mean_absolute_percentage_error: 750.8817
# Epoch 00061: mean_absolute_error did not improve from 1.28993
#
# Epoch 00061: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7441 - mean_squared_error: 3.3766 - mean_absolute_error: 1.4434 - mean_absolute_percentage_error: 750.8817 - val_loss: -0.6404 - val_mean_squared_error: 2.7791 - val_mean_absolute_error: 1.3979 - val_mean_absolute_percentage_error: 722.4755 - lr: 1.0000e-04
# Epoch 62/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7365 - mean_squared_error: 3.4091 - mean_absolute_error: 1.4558 - mean_absolute_percentage_error: 812.5052
# Epoch 00062: mean_absolute_error did not improve from 1.28993
#
# Epoch 00062: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7365 - mean_squared_error: 3.4091 - mean_absolute_error: 1.4558 - mean_absolute_percentage_error: 812.5052 - val_loss: -0.6404 - val_mean_squared_error: 2.6566 - val_mean_absolute_error: 1.3632 - val_mean_absolute_percentage_error: 717.3890 - lr: 1.0000e-04
# Epoch 63/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7430 - mean_squared_error: 3.4395 - mean_absolute_error: 1.4564 - mean_absolute_percentage_error: 785.5598
# Epoch 00063: mean_absolute_error did not improve from 1.28993
#
# Epoch 00063: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7430 - mean_squared_error: 3.4395 - mean_absolute_error: 1.4564 - mean_absolute_percentage_error: 785.5598 - val_loss: -0.6351 - val_mean_squared_error: 2.7514 - val_mean_absolute_error: 1.3602 - val_mean_absolute_percentage_error: 702.3924 - lr: 1.0000e-04
# Epoch 64/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7464 - mean_squared_error: 3.4619 - mean_absolute_error: 1.4917 - mean_absolute_percentage_error: 831.0698
# Epoch 00064: mean_absolute_error did not improve from 1.28993
#
# Epoch 00064: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7464 - mean_squared_error: 3.4619 - mean_absolute_error: 1.4917 - mean_absolute_percentage_error: 831.0698 - val_loss: -0.6407 - val_mean_squared_error: 4.2038 - val_mean_absolute_error: 1.5371 - val_mean_absolute_percentage_error: 735.1719 - lr: 1.0000e-04
# Epoch 65/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7358 - mean_squared_error: 3.4504 - mean_absolute_error: 1.5022 - mean_absolute_percentage_error: 831.4970
# Epoch 00065: mean_absolute_error did not improve from 1.28993
#
# Epoch 00065: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7358 - mean_squared_error: 3.4504 - mean_absolute_error: 1.5022 - mean_absolute_percentage_error: 831.4970 - val_loss: -0.6444 - val_mean_squared_error: 4.1961 - val_mean_absolute_error: 1.5297 - val_mean_absolute_percentage_error: 728.3339 - lr: 1.0000e-04
# Epoch 66/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7381 - mean_squared_error: 3.4188 - mean_absolute_error: 1.4926 - mean_absolute_percentage_error: 856.2449
# Epoch 00066: mean_absolute_error did not improve from 1.28993
#
# Epoch 00066: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7381 - mean_squared_error: 3.4188 - mean_absolute_error: 1.4926 - mean_absolute_percentage_error: 856.2449 - val_loss: -0.6523 - val_mean_squared_error: 4.7145 - val_mean_absolute_error: 1.5667 - val_mean_absolute_percentage_error: 724.1792 - lr: 1.0000e-04
# Epoch 67/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7223 - mean_squared_error: 3.6177 - mean_absolute_error: 1.5014 - mean_absolute_percentage_error: 873.6566
# Epoch 00067: mean_absolute_error did not improve from 1.28993
#
# Epoch 00067: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7223 - mean_squared_error: 3.6177 - mean_absolute_error: 1.5014 - mean_absolute_percentage_error: 873.6566 - val_loss: -0.7030 - val_mean_squared_error: 5.7324 - val_mean_absolute_error: 1.6519 - val_mean_absolute_percentage_error: 730.8779 - lr: 1.0000e-04
# Epoch 68/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7506 - mean_squared_error: 3.6542 - mean_absolute_error: 1.5052 - mean_absolute_percentage_error: 863.0793
# Epoch 00068: mean_absolute_error did not improve from 1.28993
#
# Epoch 00068: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7506 - mean_squared_error: 3.6542 - mean_absolute_error: 1.5052 - mean_absolute_percentage_error: 863.0793 - val_loss: -0.7201 - val_mean_squared_error: 9.9655 - val_mean_absolute_error: 1.9442 - val_mean_absolute_percentage_error: 763.1975 - lr: 1.0000e-04
# Epoch 69/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7601 - mean_squared_error: 3.7393 - mean_absolute_error: 1.4973 - mean_absolute_percentage_error: 825.5944
# Epoch 00069: mean_absolute_error did not improve from 1.28993
#
# Epoch 00069: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7601 - mean_squared_error: 3.7393 - mean_absolute_error: 1.4973 - mean_absolute_percentage_error: 825.5944 - val_loss: -0.7192 - val_mean_squared_error: 11.1918 - val_mean_absolute_error: 2.0121 - val_mean_absolute_percentage_error: 769.0032 - lr: 1.0000e-04
# Epoch 70/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7415 - mean_squared_error: 3.7719 - mean_absolute_error: 1.5038 - mean_absolute_percentage_error: 822.0871
# Epoch 00070: mean_absolute_error did not improve from 1.28993
#
# Epoch 00070: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7415 - mean_squared_error: 3.7719 - mean_absolute_error: 1.5038 - mean_absolute_percentage_error: 822.0871 - val_loss: -0.7015 - val_mean_squared_error: 8.0016 - val_mean_absolute_error: 1.8047 - val_mean_absolute_percentage_error: 725.6269 - lr: 1.0000e-04
# Epoch 71/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7355 - mean_squared_error: 3.7614 - mean_absolute_error: 1.4965 - mean_absolute_percentage_error: 841.6044
# Epoch 00071: mean_absolute_error did not improve from 1.28993
#
# Epoch 00071: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7355 - mean_squared_error: 3.7614 - mean_absolute_error: 1.4965 - mean_absolute_percentage_error: 841.6044 - val_loss: -0.6531 - val_mean_squared_error: 3.4575 - val_mean_absolute_error: 1.4211 - val_mean_absolute_percentage_error: 682.5044 - lr: 1.0000e-04
# Epoch 72/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7416 - mean_squared_error: 3.7055 - mean_absolute_error: 1.5232 - mean_absolute_percentage_error: 868.4250
# Epoch 00072: mean_absolute_error did not improve from 1.28993
#
# Epoch 00072: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7416 - mean_squared_error: 3.7055 - mean_absolute_error: 1.5232 - mean_absolute_percentage_error: 868.4250 - val_loss: -0.6245 - val_mean_squared_error: 2.6866 - val_mean_absolute_error: 1.3197 - val_mean_absolute_percentage_error: 669.9885 - lr: 1.0000e-04
# Epoch 73/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7487 - mean_squared_error: 3.7886 - mean_absolute_error: 1.5171 - mean_absolute_percentage_error: 888.0228
# Epoch 00073: mean_absolute_error did not improve from 1.28993
#
# Epoch 00073: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7487 - mean_squared_error: 3.7886 - mean_absolute_error: 1.5171 - mean_absolute_percentage_error: 888.0228 - val_loss: -0.6395 - val_mean_squared_error: 2.5988 - val_mean_absolute_error: 1.3177 - val_mean_absolute_percentage_error: 677.0219 - lr: 1.0000e-04
# Epoch 74/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7494 - mean_squared_error: 3.6989 - mean_absolute_error: 1.5259 - mean_absolute_percentage_error: 848.0259
# Epoch 00074: mean_absolute_error did not improve from 1.28993
#
# Epoch 00074: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# ...
# Epoch 00176: mean_absolute_error did not improve from 1.28993
#
# Epoch 00176: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.8299 - mean_squared_error: 5.1007 - mean_absolute_error: 1.7420 - mean_absolute_percentage_error: 937.7735 - val_loss: -0.6961 - val_mean_squared_error: 2.7461 - val_mean_absolute_error: 1.3897 - val_mean_absolute_percentage_error: 833.6879 - lr: 1.0000e-05
# Epoch 177/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8242 - mean_squared_error: 5.0489 - mean_absolute_error: 1.7438 - mean_absolute_percentage_error: 962.5728
# Epoch 00177: mean_absolute_error did not improve from 1.28993
#
# Epoch 00177: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8242 - mean_squared_error: 5.0489 - mean_absolute_error: 1.7438 - mean_absolute_percentage_error: 962.5728 - val_loss: -0.6978 - val_mean_squared_error: 2.7599 - val_mean_absolute_error: 1.3837 - val_mean_absolute_percentage_error: 818.5887 - lr: 1.0000e-05
# Epoch 178/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8063 - mean_squared_error: 5.1799 - mean_absolute_error: 1.7697 - mean_absolute_percentage_error: 943.8959
# Epoch 00178: mean_absolute_error did not improve from 1.28993
#
# Epoch 00178: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.8063 - mean_squared_error: 5.1799 - mean_absolute_error: 1.7697 - mean_absolute_percentage_error: 943.8959 - val_loss: -0.7058 - val_mean_squared_error: 2.7582 - val_mean_absolute_error: 1.3780 - val_mean_absolute_percentage_error: 800.5907 - lr: 1.0000e-05
# Epoch 179/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8198 - mean_squared_error: 5.0845 - mean_absolute_error: 1.7414 - mean_absolute_percentage_error: 1020.9065
# Epoch 00179: mean_absolute_error did not improve from 1.28993
#
# Epoch 00179: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8198 - mean_squared_error: 5.0845 - mean_absolute_error: 1.7414 - mean_absolute_percentage_error: 1020.9065 - val_loss: -0.7136 - val_mean_squared_error: 2.8200 - val_mean_absolute_error: 1.3851 - val_mean_absolute_percentage_error: 762.1158 - lr: 1.0000e-05
# Epoch 180/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8203 - mean_squared_error: 5.0836 - mean_absolute_error: 1.7784 - mean_absolute_percentage_error: 998.4587
# Epoch 00180: mean_absolute_error did not improve from 1.28993
#
# Epoch 00180: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8203 - mean_squared_error: 5.0836 - mean_absolute_error: 1.7784 - mean_absolute_percentage_error: 998.4587 - val_loss: -0.7212 - val_mean_squared_error: 2.8373 - val_mean_absolute_error: 1.3870 - val_mean_absolute_percentage_error: 744.1371 - lr: 1.0000e-05
# Epoch 181/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8122 - mean_squared_error: 4.9555 - mean_absolute_error: 1.7164 - mean_absolute_percentage_error: 896.4662
# Epoch 00181: mean_absolute_error did not improve from 1.28993
#
# Epoch 00181: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8122 - mean_squared_error: 4.9555 - mean_absolute_error: 1.7164 - mean_absolute_percentage_error: 896.4662 - val_loss: -0.7240 - val_mean_squared_error: 2.8210 - val_mean_absolute_error: 1.3915 - val_mean_absolute_percentage_error: 760.8123 - lr: 1.0000e-05
# Epoch 182/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8221 - mean_squared_error: 5.1567 - mean_absolute_error: 1.7632 - mean_absolute_percentage_error: 1006.1607
# Epoch 00182: mean_absolute_error did not improve from 1.28993
#
# Epoch 00182: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8221 - mean_squared_error: 5.1567 - mean_absolute_error: 1.7632 - mean_absolute_percentage_error: 1006.1607 - val_loss: -0.6992 - val_mean_squared_error: 2.8036 - val_mean_absolute_error: 1.4234 - val_mean_absolute_percentage_error: 854.2544 - lr: 1.0000e-05
# Epoch 183/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8344 - mean_squared_error: 5.3030 - mean_absolute_error: 1.7814 - mean_absolute_percentage_error: 967.3678
# Epoch 00183: mean_absolute_error did not improve from 1.28993
#
# Epoch 00183: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.8344 - mean_squared_error: 5.3030 - mean_absolute_error: 1.7814 - mean_absolute_percentage_error: 967.3678 - val_loss: -0.6766 - val_mean_squared_error: 2.8707 - val_mean_absolute_error: 1.4681 - val_mean_absolute_percentage_error: 929.8217 - lr: 1.0000e-05
# Epoch 184/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8145 - mean_squared_error: 5.0333 - mean_absolute_error: 1.7853 - mean_absolute_percentage_error: 1033.0306
# Epoch 00184: mean_absolute_error did not improve from 1.28993
#
# Epoch 00184: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.8145 - mean_squared_error: 5.0333 - mean_absolute_error: 1.7853 - mean_absolute_percentage_error: 1033.0306 - val_loss: -0.6785 - val_mean_squared_error: 2.9387 - val_mean_absolute_error: 1.4819 - val_mean_absolute_percentage_error: 938.9032 - lr: 1.0000e-05
# Epoch 185/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8182 - mean_squared_error: 4.8654 - mean_absolute_error: 1.7676 - mean_absolute_percentage_error: 964.6505
# Epoch 00185: mean_absolute_error did not improve from 1.28993
#
# Epoch 00185: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8182 - mean_squared_error: 4.8654 - mean_absolute_error: 1.7676 - mean_absolute_percentage_error: 964.6505 - val_loss: -0.6814 - val_mean_squared_error: 2.9583 - val_mean_absolute_error: 1.4756 - val_mean_absolute_percentage_error: 919.4567 - lr: 1.0000e-05
# Epoch 186/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8208 - mean_squared_error: 5.2201 - mean_absolute_error: 1.7782 - mean_absolute_percentage_error: 962.7776
# Epoch 00186: mean_absolute_error did not improve from 1.28993
#
# Epoch 00186: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8208 - mean_squared_error: 5.2201 - mean_absolute_error: 1.7782 - mean_absolute_percentage_error: 962.7776 - val_loss: -0.6908 - val_mean_squared_error: 2.8685 - val_mean_absolute_error: 1.4582 - val_mean_absolute_percentage_error: 895.4469 - lr: 1.0000e-05
# Epoch 187/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8236 - mean_squared_error: 5.1982 - mean_absolute_error: 1.7341 - mean_absolute_percentage_error: 899.1839
# Epoch 00187: mean_absolute_error did not improve from 1.28993
#
# Epoch 00187: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8236 - mean_squared_error: 5.1982 - mean_absolute_error: 1.7341 - mean_absolute_percentage_error: 899.1839 - val_loss: -0.7243 - val_mean_squared_error: 2.9929 - val_mean_absolute_error: 1.4495 - val_mean_absolute_percentage_error: 757.3466 - lr: 1.0000e-05
# Epoch 188/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8241 - mean_squared_error: 4.8193 - mean_absolute_error: 1.7810 - mean_absolute_percentage_error: 910.5089
# Epoch 00188: mean_absolute_error did not improve from 1.28993
#
# Epoch 00188: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8241 - mean_squared_error: 4.8193 - mean_absolute_error: 1.7810 - mean_absolute_percentage_error: 910.5089 - val_loss: -0.7300 - val_mean_squared_error: 3.2939 - val_mean_absolute_error: 1.4866 - val_mean_absolute_percentage_error: 695.0753 - lr: 1.0000e-05
# Epoch 189/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8170 - mean_squared_error: 5.3166 - mean_absolute_error: 1.7925 - mean_absolute_percentage_error: 973.7429
# Epoch 00189: mean_absolute_error did not improve from 1.28993
#
# Epoch 00189: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8170 - mean_squared_error: 5.3166 - mean_absolute_error: 1.7925 - mean_absolute_percentage_error: 973.7429 - val_loss: -0.7307 - val_mean_squared_error: 3.4117 - val_mean_absolute_error: 1.5045 - val_mean_absolute_percentage_error: 665.1859 - lr: 1.0000e-05
# Epoch 190/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8193 - mean_squared_error: 5.2467 - mean_absolute_error: 1.7865 - mean_absolute_percentage_error: 1011.4222
# Epoch 00190: mean_absolute_error did not improve from 1.28993
#
# Epoch 00190: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8193 - mean_squared_error: 5.2467 - mean_absolute_error: 1.7865 - mean_absolute_percentage_error: 1011.4222 - val_loss: -0.7276 - val_mean_squared_error: 3.5662 - val_mean_absolute_error: 1.5320 - val_mean_absolute_percentage_error: 635.8387 - lr: 1.0000e-05
# Epoch 191/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8209 - mean_squared_error: 5.3316 - mean_absolute_error: 1.7886 - mean_absolute_percentage_error: 1049.7518
# Epoch 00191: mean_absolute_error did not improve from 1.28993
#
# Epoch 00191: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8209 - mean_squared_error: 5.3316 - mean_absolute_error: 1.7886 - mean_absolute_percentage_error: 1049.7518 - val_loss: -0.7295 - val_mean_squared_error: 3.8487 - val_mean_absolute_error: 1.6055 - val_mean_absolute_percentage_error: 753.1827 - lr: 1.0000e-05
# Epoch 192/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8163 - mean_squared_error: 5.2179 - mean_absolute_error: 1.7595 - mean_absolute_percentage_error: 912.3042
# Epoch 00192: mean_absolute_error did not improve from 1.28993
#
# Epoch 00192: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8163 - mean_squared_error: 5.2179 - mean_absolute_error: 1.7595 - mean_absolute_percentage_error: 912.3042 - val_loss: -0.7361 - val_mean_squared_error: 3.9309 - val_mean_absolute_error: 1.6281 - val_mean_absolute_percentage_error: 799.4119 - lr: 1.0000e-05
# Epoch 193/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8112 - mean_squared_error: 4.9917 - mean_absolute_error: 1.7806 - mean_absolute_percentage_error: 939.0056
# Epoch 00193: mean_absolute_error did not improve from 1.28993
#
# Epoch 00193: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.8112 - mean_squared_error: 4.9917 - mean_absolute_error: 1.7806 - mean_absolute_percentage_error: 939.0056 - val_loss: -0.7383 - val_mean_squared_error: 3.8861 - val_mean_absolute_error: 1.6113 - val_mean_absolute_percentage_error: 779.7952 - lr: 1.0000e-05
# Epoch 194/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8388 - mean_squared_error: 5.2654 - mean_absolute_error: 1.7839 - mean_absolute_percentage_error: 925.3830
# Epoch 00194: mean_absolute_error did not improve from 1.28993
#
# Epoch 00194: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 50s 7s/step - loss: -0.8388 - mean_squared_error: 5.2654 - mean_absolute_error: 1.7839 - mean_absolute_percentage_error: 925.3830 - val_loss: -0.7326 - val_mean_squared_error: 3.6694 - val_mean_absolute_error: 1.5537 - val_mean_absolute_percentage_error: 690.3303 - lr: 1.0000e-05
# Epoch 195/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8190 - mean_squared_error: 4.8277 - mean_absolute_error: 1.7919 - mean_absolute_percentage_error: 988.9547
# Epoch 00195: mean_absolute_error did not improve from 1.28993
#
# Epoch 00195: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 50s 7s/step - loss: -0.8190 - mean_squared_error: 4.8277 - mean_absolute_error: 1.7919 - mean_absolute_percentage_error: 988.9547 - val_loss: -0.7320 - val_mean_squared_error: 3.4819 - val_mean_absolute_error: 1.5099 - val_mean_absolute_percentage_error: 625.1779 - lr: 1.0000e-05
# Epoch 196/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8198 - mean_squared_error: 5.0739 - mean_absolute_error: 1.7925 - mean_absolute_percentage_error: 986.0696
# Epoch 00196: mean_absolute_error did not improve from 1.28993
#
# Epoch 00196: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 50s 7s/step - loss: -0.8198 - mean_squared_error: 5.0739 - mean_absolute_error: 1.7925 - mean_absolute_percentage_error: 986.0696 - val_loss: -0.7328 - val_mean_squared_error: 3.4967 - val_mean_absolute_error: 1.5123 - val_mean_absolute_percentage_error: 640.6730 - lr: 1.0000e-05
# Epoch 197/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8334 - mean_squared_error: 5.0215 - mean_absolute_error: 1.7981 - mean_absolute_percentage_error: 959.2781
# Epoch 00197: mean_absolute_error did not improve from 1.28993
#
# Epoch 00197: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 50s 7s/step - loss: -0.8334 - mean_squared_error: 5.0215 - mean_absolute_error: 1.7981 - mean_absolute_percentage_error: 959.2781 - val_loss: -0.7344 - val_mean_squared_error: 3.4088 - val_mean_absolute_error: 1.4943 - val_mean_absolute_percentage_error: 623.4838 - lr: 1.0000e-05
# Epoch 198/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8404 - mean_squared_error: 5.1665 - mean_absolute_error: 1.7734 - mean_absolute_percentage_error: 960.0759
# Epoch 00198: mean_absolute_error did not improve from 1.28993
#
# Epoch 00198: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 50s 7s/step - loss: -0.8404 - mean_squared_error: 5.1665 - mean_absolute_error: 1.7734 - mean_absolute_percentage_error: 960.0759 - val_loss: -0.7360 - val_mean_squared_error: 3.2886 - val_mean_absolute_error: 1.4711 - val_mean_absolute_percentage_error: 606.0073 - lr: 1.0000e-05
# Epoch 199/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8418 - mean_squared_error: 5.1990 - mean_absolute_error: 1.7817 - mean_absolute_percentage_error: 965.5121
# Epoch 00199: mean_absolute_error did not improve from 1.28993
#
# Epoch 00199: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 50s 7s/step - loss: -0.8418 - mean_squared_error: 5.1990 - mean_absolute_error: 1.7817 - mean_absolute_percentage_error: 965.5121 - val_loss: -0.7374 - val_mean_squared_error: 3.2479 - val_mean_absolute_error: 1.4638 - val_mean_absolute_percentage_error: 618.2364 - lr: 1.0000e-05
# Epoch 200/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8189 - mean_squared_error: 5.0394 - mean_absolute_error: 1.7744 - mean_absolute_percentage_error: 975.4501
# Epoch 00200: mean_absolute_error did not improve from 1.28993
#
# Epoch 00200: saving model to models/last_weights_xy_Adam_filter_steped_lr.hdf5
# 7/7 [==============================] - 50s 7s/step - loss: -0.8189 - mean_squared_error: 5.0394 - mean_absolute_error: 1.7744 - mean_absolute_percentage_error: 975.4501 - val_loss: -0.7369 - val_mean_squared_error: 3.1592 - val_mean_absolute_error: 1.4614 - val_mean_absolute_percentage_error: 677.2818 - lr: 1.0000e-05

# %%
model.save('models/trained_xy_Adam_filter_steped_lr.h5')

# %%
# taking samples from the validation dataset and evaluating the model
val_ex, = validation_ds.take(1)
images, labels = val_ex[0], val_ex[1]
outputs = model.predict(images)

# %%
#print(labels)
print(outputs[:20])
# Out:
# [[ 2.9753163   0.31884137]
#  [ 2.6058273  -0.31214422]
#  [ 1.9710059  -1.2182916 ]
#  [ 1.9543611  -1.5940616 ]
#  [ 2.0486078  -1.2389451 ]
#  [ 2.0531466  -0.70939785]
#  [ 3.5124612   1.3886527 ]
#  [ 2.0304582  -1.3078715 ]
#  [ 2.5555134  -0.39026982]
#  [-0.5173212  -0.41446674]
#  [ 0.7637322   0.85489327]
#  [ 3.4958231   1.0866944 ]
#  [ 3.177626    1.4781877 ]
#  [ 1.991899   -1.4066384 ]
#  [ 3.024229    0.33375725]
#  [ 2.266041   -1.0548359 ]
#  [ 2.3997517  -0.7321357 ]
#  [ 2.4697828  -0.5301953 ]
#  [ 2.4698308  -0.4882871 ]
#  [-0.76839757 -0.36452278]]

# %%
# visualicing the results
for img,label,pred,i in zip(images, labels, outputs,range(15)):
    viz(img, label, pred)
# Out:
# #### **cartesian label:** [-0.6349558 -0.7693941]
# #### **cartesian prediction (x_y):** [2.9753163  0.31884137]
# #### **cartesian label:** [-0.9220268  0.0066615]
# #### **cartesian prediction (x_y):** [ 2.6058273  -0.31214422]
# #### **cartesian label:** [-0.18631142 -0.93576944]
# #### **cartesian prediction (x_y):** [ 1.9710059 -1.2182916]
# #### **cartesian label:** [-0.7779883   0.62356985]
# #### **cartesian prediction (x_y):** [ 1.9543611 -1.5940616]
# #### **cartesian label:** [-0.09215847 -0.9903909 ]
# #### **cartesian prediction (x_y):** [ 2.0486078 -1.2389451]
# #### **cartesian label:** [0.06662744 0.643938  ]
# #### **cartesian prediction (x_y):** [ 2.0531466  -0.70939785]
# #### **cartesian label:** [ 0.9544602  -0.04354519]
# #### **cartesian prediction (x_y):** [3.5124612 1.3886527]
# #### **cartesian label:** [ 0.9895168  -0.14151087]
# #### **cartesian prediction (x_y):** [ 2.0304582 -1.3078715]
# #### **cartesian label:** [-0.86674064  0.02315868]
# #### **cartesian prediction (x_y):** [ 2.5555134  -0.39026982]
# #### **cartesian label:** [-0.6371739  0.5229839]
# #### **cartesian prediction (x_y):** [-0.5173212  -0.41446674]
# #### **cartesian label:** [0.47179195 0.18125378]
# #### **cartesian prediction (x_y):** [0.7637322  0.85489327]
# #### **cartesian label:** [ 0.4930079  -0.04662171]
# #### **cartesian prediction (x_y):** [3.4958231 1.0866944]
# #### **cartesian label:** [0.31511977 0.3610425 ]
# #### **cartesian prediction (x_y):** [3.177626  1.4781877]
# #### **cartesian label:** [ 0.5522041 -0.7947307]
# #### **cartesian prediction (x_y):** [ 1.991899  -1.4066384]
# #### **cartesian label:** [0.9125912  0.15694979]
# #### **cartesian prediction (x_y):** [3.024229   0.33375725]
