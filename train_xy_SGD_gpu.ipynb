# %%
import os
from classification_models.tfkeras import Classifiers

# Import the ResNet34 model
ResNet34, preprocess_input = Classifiers.get('resnet34')

# %%
# Run only for training!
import glob
import math
import datetime
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
from sklearn.preprocessing import normalize

tfd = tfp.distributions
tfpl = tfp.layers
tfk = tf.keras
tfkl = tf.keras.layers

# Change parameters here...
log_dir = "logs/"
os.makedirs(log_dir, exist_ok=True)
data_dir = 'data/'
snapshot_weights = 'models/best_weights_xy_SGD_filter_steped_lr.hdf5'
last_snapshot_weights = 'models/last_weights_xy_SGD_filter_steped_lr.hdf5'
json_name = 'models/model_xy_SGD_filter_steped_lr.json'

sizex = 500
sizey = 500
sizez = 3
rand_seed = 666
num_datasets = -1
batch_size = 32
nb_epochs = 200
validation_ratio = 0.2
#ds_size = len(data_dict['y_revs'])
ds_size = 250
buf_size = ds_size

# %%
# Collect all the .npz files
numpy_datasets = glob.glob(data_dir+'dataset*')

# %%
# load the data into a dictionary from npz files
data_dict = {}
for dataset in numpy_datasets[:num_datasets]:
    with np.load(dataset) as data:
        if 'y' in data_dict.keys():
            #data_dict['x_dust']   = np.append( data_dict['x_dust'], data['x_dust'],axis=0)
            data_dict['x_nodust'] = np.append( data_dict['x_nodust'], data['x_nodust'],axis=0)
            data_dict['y']        = np.append( data_dict['y'], data['y'],axis=0)
            data_dict['ids']      = np.append( data_dict['ids'], data['id'],axis=0)
        else:
            #data_dict['x_dust']   = data['x_dust']
            data_dict['x_nodust'] = data['x_nodust']
            data_dict['y']        = data['y']
            data_dict['ids']      = data['id']

# %%
# check the shape of the dictionary (100 images of 500x500x3 = 4 files of 25 images) before filtering
data_dict['x_nodust'].shape
# Out:
# (895, 500, 500, 3)

# %%
#Filter the galaxies that have less than 1e10 solar masses
bad_ids = [[galaxy_id,i] for galaxy_id,i in zip(data_dict['ids'],range(len(data_dict['ids']))) if 'e09' in galaxy_id or 'e10' in galaxy_id ]
bad_ids = np.array(bad_ids)
remove_galaxies = np.array(bad_ids[:,1],dtype=int)
print('there are ', len(bad_ids), ' galaxies to remove')
#print(remove_galaxies)
filtered_dict = {}

for key in data_dict.keys():
    data_dict[key] = np.delete(data_dict[key],remove_galaxies, axis=0)
    
print('Still have ', len(data_dict['ids']), ' galaxies left')
# Out:
# there are  490  galaxies to remove
# Still have  405  galaxies left

# %%
# check that we hace filtered the correct galaxies
data_dict['ids'][:15]
# Out:
# array(['g5.38e11_x73_y33_z282', 'g5.38e11_x118_y115_z5',
#        'g5.38e11_x4_y285_z273', 'g5.38e11_x207_y331_z254',
#        'g5.38e11_x138_y82_z188', 'g5.46e11_x134_y99_z113',
#        'g5.46e11_x111_y17_z326', 'g5.46e11_x311_y196_z302',
#        'g5.46e11_x306_y325_z297', 'g5.46e11_x50_y326_z189',
#        'g5.55e11_x310_y321_z331', 'g5.55e11_x7_y92_z328',
#        'g5.55e11_x245_y211_z81', 'g5.55e11_x245_y339_z176',
#        'g5.55e11_x342_y14_z192'], dtype='<U23')

# %%
# check the shape of the dictionary after filtering
data_dict['x_nodust'].shape
# Out:
# (405, 500, 500, 3)

# %%
# Compute the angles from the x,y,z labels
# theta = np.arctan(np.sqrt(x**2 + y**2)/z)
# phi = np.arctan(y/x)
def cart_to_esf(xyz):
    angles = np.empty( (len(xyz),2) )
    angles[:,0] = np.arctan2(np.sqrt(xyz[:,0]**2 + xyz[:,1]**2),xyz[:,2]) *180/np.pi #theta angle in degrees
    angles[:,1] = np.arctan2(xyz[:,1],xyz[:,0]) * 180/np.pi #phi angle in degrees
    return angles

# Define the function to go back to cartisian cordinates
def esf_to_cart(angles):
    xyz = np.empty( (len(angles),3) )
    ang_rad = angles*np.pi/180
    xyz[:,0] = np.sin(ang_rad[:,0])*np.cos(ang_rad[:,1])
    xyz[:,1] = np.sin(ang_rad[:,0])*np.sin(ang_rad[:,1])
    xyz[:,2] = np.cos(ang_rad[:,0])
    return xyz

#break the degeneracy of the solutions restricting the solution to 1 sector
def break_degeneracy(angles):
    ang_norm = angles
    for i in range(len(angles)):
        if ang_norm[:,1][i] < 0:
            ang_norm[:,1][i] = (ang_norm[:,1][i] + 180)
    return ang_norm

#map the solution to be between [0,1]
def map_to_1(angles, max = 180 ):
    ang_norm = angles/max
    return ang_norm

#coming back the mapping from 1 to 180
def map_to_180(ang_norm):
  angle = ang_norm*180
  return angle

# computing the normaliced vectors in 3D
data_dict['y_norm'] = normalize(data_dict['y'], axis=1)
data_dict['y_ang'] = map_to_1(break_degeneracy(cart_to_esf(normalize(data_dict['y'], axis=1))))
data_dict['y_revs'] = esf_to_cart(map_to_180(data_dict['y_ang']))

# %%
# check the shape of our dictionary in te labels entry
print(data_dict['y_norm'].shape)
# Out:
# (405, 3)

# %%
# separate in batches and shuffle the data with a fixed seed
#dataset = dataset.batch(batch_size)
#dataset = dataset.shuffle(10, seed=123)
AUTO = tf.data.experimental.AUTOTUNE

# %%
# functions to visualice the data 
def viz(img, label, pred=np.array([0,0,0]), id=None):
    fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(img, cmap='gray', vmin=0, vmax=255,origin='lower')
    ax.arrow(250,250,100*label[0],100*label[1], head_width=7, head_length=10, fc='g', ec='g')
    if np.sum(np.abs(pred)) > 0: ax.arrow(250,250,100*pred[0],100*pred[1], head_width=7, head_length=10, fc='r', ec='r')
        
    display(Markdown("#### **cartesian label:** {}".format(label)))
    if np.sum(np.abs(pred)) > 0: display(Markdown("#### **cartesian prediction (x_y):** {}".format(pred)))
    if id: display(Markdown("#### **ID:** {}".format(id)))
    plt.show()

# create the dataset from the dictionary and see the size and type
dataset = tf.data.Dataset.from_tensor_slices(data_dict)
print(dataset)
# Out:
# <TensorSliceDataset shapes: {x_nodust: (500, 500, 3), y: (3,), ids: (), y_norm: (3,), y_ang: (2,), y_revs: (3,)}, types: {x_nodust: tf.float64, y: tf.float64, ids: tf.string, y_norm: tf.float64, y_ang: tf.float64, y_revs: tf.float64}>

# %%
# visualice the data
real_dataset = dataset.batch(batch_size).shuffle(10, seed=rand_seed)
for idx in range(1,5):
    elements = real_dataset.take(idx)
    for elem in elements:
        viz(elem['x_nodust'][idx], elem['y_norm'][idx], elem['y_revs'][idx], id=elem['ids'][idx])
# Out:
# #### **cartesian label:** [ 0.46680332  0.76074614 -0.45095452]
# #### **cartesian prediction (x_y):** [ 0.46680332  0.76074614 -0.45095452]
# #### **ID:** b'g3.23e11_x192_y238_z218'
# #### **cartesian label:** [0.25409979 0.44085076 0.8608623 ]
# #### **cartesian prediction (x_y):** [0.25409979 0.44085076 0.8608623 ]
# #### **ID:** b'g2.04e11_x32_y348_z247'
# #### **cartesian label:** [-0.47901533 -0.07426079 -0.87465973]
# #### **cartesian prediction (x_y):** [ 0.47901533  0.07426079 -0.87465973]
# #### **ID:** b'g2.79e12_x52_y248_z101'
# #### **cartesian label:** [-0.1562322   0.30773711  0.93855707]
# #### **cartesian prediction (x_y):** [-0.1562322   0.30773711  0.93855707]
# #### **ID:** b'g3.49e11_x261_y183_z222'
# #### **cartesian label:** [ 0.18716548 -0.48423022  0.85468718]
# #### **cartesian prediction (x_y):** [-0.18716548  0.48423022  0.85468718]
# #### **ID:** b'g1.05e11_x241_y204_z49'
# #### **cartesian label:** [-0.48457038  0.83954677 -0.24566803]
# #### **cartesian prediction (x_y):** [-0.48457038  0.83954677 -0.24566803]
# #### **ID:** b'g2.19e11_x189_y233_z34'
# #### **cartesian label:** [ 0.30069015 -0.00199004  0.95371981]
# #### **cartesian prediction (x_y):** [-0.30069015  0.00199004  0.95371981]
# #### **ID:** b'g5.31e11_x50_y255_z112'
# #### **cartesian label:** [ 0.84659725 -0.32004032 -0.42526143]
# #### **cartesian prediction (x_y):** [-0.84659725  0.32004032 -0.42526143]
# #### **ID:** b'g3.49e11_x40_y55_z229'
# #### **cartesian label:** [-0.01737563 -0.14807151 -0.98882401]
# #### **cartesian prediction (x_y):** [ 0.01737563  0.14807151 -0.98882401]
# #### **ID:** b'g1.92e12_x342_y72_z264'
# #### **cartesian label:** [-0.62686766  0.70078731  0.34049095]
# #### **cartesian prediction (x_y):** [-0.62686766  0.70078731  0.34049095]
# #### **ID:** b'g1.05e11_x130_y269_z141'

# %%
# defining the train and validation dataset from the existing dictionary, shufling and batching
input_ds = (
    tf.data.Dataset.from_tensor_slices((data_dict['x_nodust'].astype(np.float32), data_dict['y_norm'][:,:2].astype(np.float32)))
                    # Use seed to ensure we always have the same validation data set!
                   .shuffle(ds_size, seed = rand_seed, reshuffle_each_iteration = False)
)

input_ds = input_ds.take(ds_size)
val_size = math.floor(ds_size * validation_ratio)

validation_ds = ( input_ds.take(val_size).batch(batch_size) )
train_ds = ( input_ds.skip(val_size).shuffle(buffer_size=buf_size, reshuffle_each_iteration=True).batch(batch_size) )

print(train_ds)
print(validation_ds)
# Out:
# <BatchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>

# %%
# %reload_ext tensorboard
# %tensorboard --logdir {log_dir} --reload_multifile True --host 0.0.0.0 --port 6006
# Out:
#       <iframe id="tensorboard-frame-5d7e6e749d3e0d4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5d7e6e749d3e0d4");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
# Build model
base_model = ResNet34(input_shape=(sizey,sizex,3), include_top=False)

# redefine the output to be 2 parameters from the last dense layer
x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tf.keras.layers.Dense(2, activation=None)(x)
model = tf.keras.models.Model(inputs=[base_model.input], outputs=[output])

# Use existing best weights if available...
if os.path.isfile(last_snapshot_weights):
    print('loaded weights')
    model.load_weights(last_snapshot_weights)
    
cossim = lambda y, p_y: -1*tf.keras.backend.abs(tf.keras.losses.cosine_similarity(y, p_y))
#define the learning rate schedule
def scheduler(epoch, lr):
    if epoch == 25:
        return lr / 10
    elif epoch == 100:
        return lr / 2
    else:
        return lr


model.compile(optimizer= tf.keras.optimizers.SGD(),
              loss=cossim, metrics=[tf.keras.metrics.mean_squared_error, 
                                    tf.keras.metrics.mean_absolute_error, 
                                    tf.keras.metrics.mean_absolute_percentage_error])

# serialize model to JSON
model_json = model.to_json()
with open(json_name, "w") as json_file:
    json_file.write(model_json)
# Out:
# loaded weights

# %%
# model.summary()

# For tensorboard
log_dir_s = log_dir + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
os.makedirs(log_dir_s, exist_ok=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir_s, histogram_freq=1, update_freq='batch', profile_batch=0)

# Checkpointing
checkpointer_1 = tf.keras.callbacks.ModelCheckpoint(filepath=snapshot_weights,
                               monitor='mean_absolute_error',
                               verbose=1,
                               save_best_only=True)
checkpointer_2 = tf.keras.callbacks.ModelCheckpoint(filepath=last_snapshot_weights,
                               monitor='mean_absolute_error',
                               verbose=1,
                               save_best_only=False)

LearningRateScheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

callbacks = [
    tensorboard_callback,
    checkpointer_1,
    checkpointer_2,
    LearningRateScheduler
]

model.fit(
    train_ds,
    validation_data = validation_ds,
    epochs = nb_epochs,
    callbacks = callbacks,)
    # class_weight=class_weight)
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6330 - mean_squared_error: 0.8063 - mean_absolute_error: 0.7437 - mean_absolute_percentage_error: 496.4187
# Epoch 00001: mean_absolute_error improved from inf to 0.74368, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00001: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 51s 7s/step - loss: -0.6330 - mean_squared_error: 0.8063 - mean_absolute_error: 0.7437 - mean_absolute_percentage_error: 496.4187 - val_loss: -0.6083 - val_mean_squared_error: 40.9429 - val_mean_absolute_error: 5.7051 - val_mean_absolute_percentage_error: 3623.2961 - lr: 0.0100
# Epoch 2/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7293 - mean_squared_error: 0.9397 - mean_absolute_error: 0.7715 - mean_absolute_percentage_error: 391.0941
# Epoch 00002: mean_absolute_error did not improve from 0.74368
#
# Epoch 00002: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 50s 7s/step - loss: -0.7293 - mean_squared_error: 0.9397 - mean_absolute_error: 0.7715 - mean_absolute_percentage_error: 391.0941 - val_loss: -0.6597 - val_mean_squared_error: 4.4894 - val_mean_absolute_error: 1.6147 - val_mean_absolute_percentage_error: 589.9856 - lr: 0.0100
# Epoch 3/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7360 - mean_squared_error: 0.9358 - mean_absolute_error: 0.7690 - mean_absolute_percentage_error: 351.4674
# Epoch 00003: mean_absolute_error did not improve from 0.74368
#
# Epoch 00003: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 50s 7s/step - loss: -0.7360 - mean_squared_error: 0.9358 - mean_absolute_error: 0.7690 - mean_absolute_percentage_error: 351.4674 - val_loss: -0.5913 - val_mean_squared_error: 2.5689 - val_mean_absolute_error: 1.3940 - val_mean_absolute_percentage_error: 775.1362 - lr: 0.0100
# Epoch 4/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7382 - mean_squared_error: 0.9632 - mean_absolute_error: 0.7803 - mean_absolute_percentage_error: 391.6219
# Epoch 00004: mean_absolute_error did not improve from 0.74368
#
# Epoch 00004: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 51s 7s/step - loss: -0.7382 - mean_squared_error: 0.9632 - mean_absolute_error: 0.7803 - mean_absolute_percentage_error: 391.6219 - val_loss: -0.6436 - val_mean_squared_error: 0.6392 - val_mean_absolute_error: 0.6401 - val_mean_absolute_percentage_error: 176.6680 - lr: 0.0100
# Epoch 5/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7520 - mean_squared_error: 0.9728 - mean_absolute_error: 0.7871 - mean_absolute_percentage_error: 372.2976
# Epoch 00005: mean_absolute_error did not improve from 0.74368
#
# Epoch 00005: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7520 - mean_squared_error: 0.9728 - mean_absolute_error: 0.7871 - mean_absolute_percentage_error: 372.2976 - val_loss: -0.5907 - val_mean_squared_error: 0.6174 - val_mean_absolute_error: 0.6507 - val_mean_absolute_percentage_error: 286.0866 - lr: 0.0100
# Epoch 6/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7439 - mean_squared_error: 0.9297 - mean_absolute_error: 0.7736 - mean_absolute_percentage_error: 363.7151
# Epoch 00006: mean_absolute_error did not improve from 0.74368
#
# Epoch 00006: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7439 - mean_squared_error: 0.9297 - mean_absolute_error: 0.7736 - mean_absolute_percentage_error: 363.7151 - val_loss: -0.6845 - val_mean_squared_error: 0.6353 - val_mean_absolute_error: 0.6405 - val_mean_absolute_percentage_error: 184.1828 - lr: 0.0100
# Epoch 7/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7512 - mean_squared_error: 0.9068 - mean_absolute_error: 0.7590 - mean_absolute_percentage_error: 405.6571
# Epoch 00007: mean_absolute_error did not improve from 0.74368
#
# Epoch 00007: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7512 - mean_squared_error: 0.9068 - mean_absolute_error: 0.7590 - mean_absolute_percentage_error: 405.6571 - val_loss: -0.7044 - val_mean_squared_error: 0.5708 - val_mean_absolute_error: 0.6115 - val_mean_absolute_percentage_error: 268.5824 - lr: 0.0100
# Epoch 8/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7530 - mean_squared_error: 0.8476 - mean_absolute_error: 0.7346 - mean_absolute_percentage_error: 369.4453
# Epoch 00008: mean_absolute_error improved from 0.74368 to 0.73456, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00008: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7530 - mean_squared_error: 0.8476 - mean_absolute_error: 0.7346 - mean_absolute_percentage_error: 369.4453 - val_loss: -0.7025 - val_mean_squared_error: 0.5069 - val_mean_absolute_error: 0.5791 - val_mean_absolute_percentage_error: 220.3264 - lr: 0.0100
# Epoch 9/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7564 - mean_squared_error: 0.8070 - mean_absolute_error: 0.7126 - mean_absolute_percentage_error: 360.7892
# Epoch 00009: mean_absolute_error improved from 0.73456 to 0.71257, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00009: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.7564 - mean_squared_error: 0.8070 - mean_absolute_error: 0.7126 - mean_absolute_percentage_error: 360.7892 - val_loss: -0.7112 - val_mean_squared_error: 0.4263 - val_mean_absolute_error: 0.5385 - val_mean_absolute_percentage_error: 175.0000 - lr: 0.0100
# Epoch 10/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7751 - mean_squared_error: 0.7383 - mean_absolute_error: 0.6696 - mean_absolute_percentage_error: 315.7500
# Epoch 00010: mean_absolute_error improved from 0.71257 to 0.66958, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00010: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7751 - mean_squared_error: 0.7383 - mean_absolute_error: 0.6696 - mean_absolute_percentage_error: 315.7500 - val_loss: -0.7001 - val_mean_squared_error: 0.4112 - val_mean_absolute_error: 0.5301 - val_mean_absolute_percentage_error: 130.8811 - lr: 0.0100
# Epoch 11/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7801 - mean_squared_error: 0.6622 - mean_absolute_error: 0.6387 - mean_absolute_percentage_error: 314.1271
# Epoch 00011: mean_absolute_error improved from 0.66958 to 0.63872, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00011: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7801 - mean_squared_error: 0.6622 - mean_absolute_error: 0.6387 - mean_absolute_percentage_error: 314.1271 - val_loss: -0.7188 - val_mean_squared_error: 0.4598 - val_mean_absolute_error: 0.5579 - val_mean_absolute_percentage_error: 222.9135 - lr: 0.0100
# Epoch 12/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7731 - mean_squared_error: 0.6126 - mean_absolute_error: 0.6146 - mean_absolute_percentage_error: 271.0010
# Epoch 00012: mean_absolute_error improved from 0.63872 to 0.61457, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00012: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7731 - mean_squared_error: 0.6126 - mean_absolute_error: 0.6146 - mean_absolute_percentage_error: 271.0010 - val_loss: -0.6962 - val_mean_squared_error: 0.4829 - val_mean_absolute_error: 0.5790 - val_mean_absolute_percentage_error: 263.9378 - lr: 0.0100
# Epoch 13/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7730 - mean_squared_error: 0.6370 - mean_absolute_error: 0.6254 - mean_absolute_percentage_error: 271.4121
# Epoch 00013: mean_absolute_error did not improve from 0.61457
#
# Epoch 00013: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7730 - mean_squared_error: 0.6370 - mean_absolute_error: 0.6254 - mean_absolute_percentage_error: 271.4121 - val_loss: -0.6866 - val_mean_squared_error: 0.4138 - val_mean_absolute_error: 0.5347 - val_mean_absolute_percentage_error: 127.8623 - lr: 0.0100
# Epoch 14/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7641 - mean_squared_error: 0.5453 - mean_absolute_error: 0.5964 - mean_absolute_percentage_error: 293.3866
# Epoch 00014: mean_absolute_error improved from 0.61457 to 0.59640, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00014: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7641 - mean_squared_error: 0.5453 - mean_absolute_error: 0.5964 - mean_absolute_percentage_error: 293.3866 - val_loss: -0.6820 - val_mean_squared_error: 0.5338 - val_mean_absolute_error: 0.5933 - val_mean_absolute_percentage_error: 160.4079 - lr: 0.0100
# Epoch 15/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7843 - mean_squared_error: 0.6121 - mean_absolute_error: 0.6196 - mean_absolute_percentage_error: 272.1639
# Epoch 00015: mean_absolute_error did not improve from 0.59640
#
# Epoch 00015: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7843 - mean_squared_error: 0.6121 - mean_absolute_error: 0.6196 - mean_absolute_percentage_error: 272.1639 - val_loss: -0.7224 - val_mean_squared_error: 0.4648 - val_mean_absolute_error: 0.5586 - val_mean_absolute_percentage_error: 178.4117 - lr: 0.0100
# Epoch 16/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7804 - mean_squared_error: 0.6084 - mean_absolute_error: 0.6157 - mean_absolute_percentage_error: 239.5197
# Epoch 00016: mean_absolute_error did not improve from 0.59640
#
# Epoch 00016: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7804 - mean_squared_error: 0.6084 - mean_absolute_error: 0.6157 - mean_absolute_percentage_error: 239.5197 - val_loss: -0.6248 - val_mean_squared_error: 0.4909 - val_mean_absolute_error: 0.5875 - val_mean_absolute_percentage_error: 201.1717 - lr: 0.0100
# Epoch 17/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7576 - mean_squared_error: 0.6425 - mean_absolute_error: 0.6289 - mean_absolute_percentage_error: 282.8904
# Epoch 00017: mean_absolute_error did not improve from 0.59640
#
# Epoch 00017: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7576 - mean_squared_error: 0.6425 - mean_absolute_error: 0.6289 - mean_absolute_percentage_error: 282.8904 - val_loss: -0.7066 - val_mean_squared_error: 0.4494 - val_mean_absolute_error: 0.5511 - val_mean_absolute_percentage_error: 180.7547 - lr: 0.0100
# Epoch 18/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7962 - mean_squared_error: 0.5579 - mean_absolute_error: 0.5896 - mean_absolute_percentage_error: 265.2031
# Epoch 00018: mean_absolute_error improved from 0.59640 to 0.58957, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00018: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7962 - mean_squared_error: 0.5579 - mean_absolute_error: 0.5896 - mean_absolute_percentage_error: 265.2031 - val_loss: -0.7260 - val_mean_squared_error: 0.5011 - val_mean_absolute_error: 0.5744 - val_mean_absolute_percentage_error: 230.2345 - lr: 0.0100
# Epoch 19/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7813 - mean_squared_error: 0.6045 - mean_absolute_error: 0.6129 - mean_absolute_percentage_error: 231.5025
# Epoch 00019: mean_absolute_error did not improve from 0.58957
#
# Epoch 00019: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7813 - mean_squared_error: 0.6045 - mean_absolute_error: 0.6129 - mean_absolute_percentage_error: 231.5025 - val_loss: -0.6778 - val_mean_squared_error: 0.7950 - val_mean_absolute_error: 0.7479 - val_mean_absolute_percentage_error: 491.0129 - lr: 0.0100
# Epoch 20/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8172 - mean_squared_error: 0.6293 - mean_absolute_error: 0.6186 - mean_absolute_percentage_error: 254.4675
# Epoch 00020: mean_absolute_error did not improve from 0.58957
#
# Epoch 00020: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.8172 - mean_squared_error: 0.6293 - mean_absolute_error: 0.6186 - mean_absolute_percentage_error: 254.4675 - val_loss: -0.7197 - val_mean_squared_error: 0.4963 - val_mean_absolute_error: 0.5797 - val_mean_absolute_percentage_error: 273.5984 - lr: 0.0100
# Epoch 21/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8007 - mean_squared_error: 0.6714 - mean_absolute_error: 0.6416 - mean_absolute_percentage_error: 293.9521
# Epoch 00021: mean_absolute_error did not improve from 0.58957
#
# Epoch 00021: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.8007 - mean_squared_error: 0.6714 - mean_absolute_error: 0.6416 - mean_absolute_percentage_error: 293.9521 - val_loss: -0.6014 - val_mean_squared_error: 0.4353 - val_mean_absolute_error: 0.5592 - val_mean_absolute_percentage_error: 173.3868 - lr: 0.0100
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8008 - mean_squared_error: 0.6797 - mean_absolute_error: 0.6424 - mean_absolute_percentage_error: 286.2911
# Epoch 00022: mean_absolute_error did not improve from 0.58957
#
# Epoch 00022: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.8008 - mean_squared_error: 0.6797 - mean_absolute_error: 0.6424 - mean_absolute_percentage_error: 286.2911 - val_loss: -0.6607 - val_mean_squared_error: 0.3943 - val_mean_absolute_error: 0.5283 - val_mean_absolute_percentage_error: 125.2019 - lr: 0.0100
# Epoch 23/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8101 - mean_squared_error: 0.6566 - mean_absolute_error: 0.6305 - mean_absolute_percentage_error: 272.8776
# Epoch 00023: mean_absolute_error did not improve from 0.58957
#
# Epoch 00023: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.8101 - mean_squared_error: 0.6566 - mean_absolute_error: 0.6305 - mean_absolute_percentage_error: 272.8776 - val_loss: -0.5970 - val_mean_squared_error: 0.3765 - val_mean_absolute_error: 0.5242 - val_mean_absolute_percentage_error: 241.2482 - lr: 0.0100
# Epoch 24/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8090 - mean_squared_error: 0.6900 - mean_absolute_error: 0.6469 - mean_absolute_percentage_error: 262.9055
# Epoch 00024: mean_absolute_error did not improve from 0.58957
#
# Epoch 00024: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.8090 - mean_squared_error: 0.6900 - mean_absolute_error: 0.6469 - mean_absolute_percentage_error: 262.9055 - val_loss: -0.6462 - val_mean_squared_error: 0.3958 - val_mean_absolute_error: 0.5350 - val_mean_absolute_percentage_error: 241.5646 - lr: 0.0100
# Epoch 25/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7926 - mean_squared_error: 0.7784 - mean_absolute_error: 0.6887 - mean_absolute_percentage_error: 320.1697
# Epoch 00025: mean_absolute_error did not improve from 0.58957
#
# Epoch 00025: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7926 - mean_squared_error: 0.7784 - mean_absolute_error: 0.6887 - mean_absolute_percentage_error: 320.1697 - val_loss: -0.7146 - val_mean_squared_error: 0.4103 - val_mean_absolute_error: 0.5384 - val_mean_absolute_percentage_error: 222.8753 - lr: 0.0100
# Epoch 26/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8432 - mean_squared_error: 0.6998 - mean_absolute_error: 0.6432 - mean_absolute_percentage_error: 248.6945
# Epoch 00026: mean_absolute_error did not improve from 0.58957
#
# Epoch 00026: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8432 - mean_squared_error: 0.6998 - mean_absolute_error: 0.6432 - mean_absolute_percentage_error: 248.6945 - val_loss: -0.6496 - val_mean_squared_error: 0.3553 - val_mean_absolute_error: 0.5071 - val_mean_absolute_percentage_error: 170.3227 - lr: 1.0000e-03
# Epoch 27/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8629 - mean_squared_error: 0.6782 - mean_absolute_error: 0.6303 - mean_absolute_percentage_error: 235.4139
# Epoch 00027: mean_absolute_error did not improve from 0.58957
#
# Epoch 00027: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8629 - mean_squared_error: 0.6782 - mean_absolute_error: 0.6303 - mean_absolute_percentage_error: 235.4139 - val_loss: -0.6160 - val_mean_squared_error: 0.3507 - val_mean_absolute_error: 0.5053 - val_mean_absolute_percentage_error: 161.0563 - lr: 1.0000e-03
# Epoch 28/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8601 - mean_squared_error: 0.6642 - mean_absolute_error: 0.6244 - mean_absolute_percentage_error: 224.8544
# Epoch 00028: mean_absolute_error did not improve from 0.58957
#
# Epoch 00028: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8601 - mean_squared_error: 0.6642 - mean_absolute_error: 0.6244 - mean_absolute_percentage_error: 224.8544 - val_loss: -0.6323 - val_mean_squared_error: 0.3613 - val_mean_absolute_error: 0.5120 - val_mean_absolute_percentage_error: 173.2819 - lr: 1.0000e-03
# Epoch 29/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8667 - mean_squared_error: 0.6595 - mean_absolute_error: 0.6189 - mean_absolute_percentage_error: 220.8579
# Epoch 00029: mean_absolute_error did not improve from 0.58957
#
# Epoch 00029: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8667 - mean_squared_error: 0.6595 - mean_absolute_error: 0.6189 - mean_absolute_percentage_error: 220.8579 - val_loss: -0.6489 - val_mean_squared_error: 0.3719 - val_mean_absolute_error: 0.5185 - val_mean_absolute_percentage_error: 184.8069 - lr: 1.0000e-03
# Epoch 30/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8731 - mean_squared_error: 0.6616 - mean_absolute_error: 0.6222 - mean_absolute_percentage_error: 227.8243
# Epoch 00030: mean_absolute_error did not improve from 0.58957
#
# Epoch 00030: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8731 - mean_squared_error: 0.6616 - mean_absolute_error: 0.6222 - mean_absolute_percentage_error: 227.8243 - val_loss: -0.6520 - val_mean_squared_error: 0.3722 - val_mean_absolute_error: 0.5188 - val_mean_absolute_percentage_error: 181.0435 - lr: 1.0000e-03
# Epoch 31/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8769 - mean_squared_error: 0.6520 - mean_absolute_error: 0.6196 - mean_absolute_percentage_error: 238.8100
# Epoch 00031: mean_absolute_error did not improve from 0.58957
#
# Epoch 00031: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8769 - mean_squared_error: 0.6520 - mean_absolute_error: 0.6196 - mean_absolute_percentage_error: 238.8100 - val_loss: -0.6872 - val_mean_squared_error: 0.4054 - val_mean_absolute_error: 0.5376 - val_mean_absolute_percentage_error: 198.6507 - lr: 1.0000e-03
# Epoch 32/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8559 - mean_squared_error: 0.7048 - mean_absolute_error: 0.6492 - mean_absolute_percentage_error: 246.2834
# Epoch 00032: mean_absolute_error did not improve from 0.58957
#
# Epoch 00032: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8559 - mean_squared_error: 0.7048 - mean_absolute_error: 0.6492 - mean_absolute_percentage_error: 246.2834 - val_loss: -0.6674 - val_mean_squared_error: 0.4019 - val_mean_absolute_error: 0.5377 - val_mean_absolute_percentage_error: 212.9781 - lr: 1.0000e-03
# Epoch 33/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8663 - mean_squared_error: 0.6791 - mean_absolute_error: 0.6344 - mean_absolute_percentage_error: 242.7268
# Epoch 00033: mean_absolute_error did not improve from 0.58957
#
# Epoch 00033: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8663 - mean_squared_error: 0.6791 - mean_absolute_error: 0.6344 - mean_absolute_percentage_error: 242.7268 - val_loss: -0.6470 - val_mean_squared_error: 0.4005 - val_mean_absolute_error: 0.5382 - val_mean_absolute_percentage_error: 218.2220 - lr: 1.0000e-03
# Epoch 34/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8736 - mean_squared_error: 0.6697 - mean_absolute_error: 0.6287 - mean_absolute_percentage_error: 229.7708
# Epoch 00034: mean_absolute_error did not improve from 0.58957
#
# Epoch 00034: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.8736 - mean_squared_error: 0.6697 - mean_absolute_error: 0.6287 - mean_absolute_percentage_error: 229.7708 - val_loss: -0.6409 - val_mean_squared_error: 0.4090 - val_mean_absolute_error: 0.5439 - val_mean_absolute_percentage_error: 233.4103 - lr: 1.0000e-03
# Epoch 35/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8741 - mean_squared_error: 0.6730 - mean_absolute_error: 0.6325 - mean_absolute_percentage_error: 233.0981
# Epoch 00035: mean_absolute_error did not improve from 0.58957
#
# Epoch 00035: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8741 - mean_squared_error: 0.6730 - mean_absolute_error: 0.6325 - mean_absolute_percentage_error: 233.0981 - val_loss: -0.6381 - val_mean_squared_error: 0.4117 - val_mean_absolute_error: 0.5462 - val_mean_absolute_percentage_error: 235.3884 - lr: 1.0000e-03
# Epoch 36/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8807 - mean_squared_error: 0.6537 - mean_absolute_error: 0.6211 - mean_absolute_percentage_error: 219.6908
# Epoch 00036: mean_absolute_error did not improve from 0.58957
#
# Epoch 00036: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8807 - mean_squared_error: 0.6537 - mean_absolute_error: 0.6211 - mean_absolute_percentage_error: 219.6908 - val_loss: -0.6588 - val_mean_squared_error: 0.4278 - val_mean_absolute_error: 0.5545 - val_mean_absolute_percentage_error: 247.5825 - lr: 1.0000e-03
# Epoch 37/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8829 - mean_squared_error: 0.6541 - mean_absolute_error: 0.6172 - mean_absolute_percentage_error: 218.6844
# Epoch 00037: mean_absolute_error did not improve from 0.58957
#
# Epoch 00037: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8829 - mean_squared_error: 0.6541 - mean_absolute_error: 0.6172 - mean_absolute_percentage_error: 218.6844 - val_loss: -0.6448 - val_mean_squared_error: 0.4161 - val_mean_absolute_error: 0.5481 - val_mean_absolute_percentage_error: 241.1933 - lr: 1.0000e-03
# Epoch 38/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8835 - mean_squared_error: 0.6330 - mean_absolute_error: 0.6080 - mean_absolute_percentage_error: 212.5454
# Epoch 00038: mean_absolute_error did not improve from 0.58957
#
# Epoch 00038: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.8835 - mean_squared_error: 0.6330 - mean_absolute_error: 0.6080 - mean_absolute_percentage_error: 212.5454 - val_loss: -0.6291 - val_mean_squared_error: 0.4019 - val_mean_absolute_error: 0.5408 - val_mean_absolute_percentage_error: 214.4690 - lr: 1.0000e-03
# Epoch 39/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8784 - mean_squared_error: 0.6306 - mean_absolute_error: 0.6167 - mean_absolute_percentage_error: 227.3500
# Epoch 00039: mean_absolute_error did not improve from 0.58957
#
# Epoch 00039: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.8784 - mean_squared_error: 0.6306 - mean_absolute_error: 0.6167 - mean_absolute_percentage_error: 227.3500 - val_loss: -0.6233 - val_mean_squared_error: 0.3941 - val_mean_absolute_error: 0.5373 - val_mean_absolute_percentage_error: 209.5390 - lr: 1.0000e-03
# Epoch 40/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8901 - mean_squared_error: 0.6235 - mean_absolute_error: 0.6066 - mean_absolute_percentage_error: 206.8236
# Epoch 00040: mean_absolute_error did not improve from 0.58957
#
# Epoch 00040: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.8901 - mean_squared_error: 0.6235 - mean_absolute_error: 0.6066 - mean_absolute_percentage_error: 206.8236 - val_loss: -0.6184 - val_mean_squared_error: 0.3794 - val_mean_absolute_error: 0.5272 - val_mean_absolute_percentage_error: 184.2808 - lr: 1.0000e-03
# Epoch 41/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8875 - mean_squared_error: 0.6243 - mean_absolute_error: 0.6113 - mean_absolute_percentage_error: 211.2384
# Epoch 00041: mean_absolute_error did not improve from 0.58957
#
# Epoch 00041: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.8875 - mean_squared_error: 0.6243 - mean_absolute_error: 0.6113 - mean_absolute_percentage_error: 211.2384 - val_loss: -0.5947 - val_mean_squared_error: 0.3726 - val_mean_absolute_error: 0.5233 - val_mean_absolute_percentage_error: 184.0307 - lr: 1.0000e-03
# Epoch 42/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8921 - mean_squared_error: 0.6048 - mean_absolute_error: 0.5986 - mean_absolute_percentage_error: 193.6490
# Epoch 00042: mean_absolute_error did not improve from 0.58957
#
# Epoch 00042: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8921 - mean_squared_error: 0.6048 - mean_absolute_error: 0.5986 - mean_absolute_percentage_error: 193.6490 - val_loss: -0.5807 - val_mean_squared_error: 0.3682 - val_mean_absolute_error: 0.5205 - val_mean_absolute_percentage_error: 170.9826 - lr: 1.0000e-03
# Epoch 43/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9008 - mean_squared_error: 0.6100 - mean_absolute_error: 0.5983 - mean_absolute_percentage_error: 192.7360
# Epoch 00043: mean_absolute_error did not improve from 0.58957
#
# Epoch 00043: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9008 - mean_squared_error: 0.6100 - mean_absolute_error: 0.5983 - mean_absolute_percentage_error: 192.7360 - val_loss: -0.5555 - val_mean_squared_error: 0.3596 - val_mean_absolute_error: 0.5141 - val_mean_absolute_percentage_error: 154.2835 - lr: 1.0000e-03
# Epoch 44/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8939 - mean_squared_error: 0.5865 - mean_absolute_error: 0.5916 - mean_absolute_percentage_error: 204.3105
# Epoch 00044: mean_absolute_error did not improve from 0.58957
#
# Epoch 00044: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.8939 - mean_squared_error: 0.5865 - mean_absolute_error: 0.5916 - mean_absolute_percentage_error: 204.3105 - val_loss: -0.5502 - val_mean_squared_error: 0.3629 - val_mean_absolute_error: 0.5194 - val_mean_absolute_percentage_error: 141.6354 - lr: 1.0000e-03
# Epoch 45/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8850 - mean_squared_error: 0.6008 - mean_absolute_error: 0.5973 - mean_absolute_percentage_error: 206.6830
# Epoch 00045: mean_absolute_error did not improve from 0.58957
#
# Epoch 00045: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.8850 - mean_squared_error: 0.6008 - mean_absolute_error: 0.5973 - mean_absolute_percentage_error: 206.6830 - val_loss: -0.5131 - val_mean_squared_error: 0.3689 - val_mean_absolute_error: 0.5233 - val_mean_absolute_percentage_error: 144.9781 - lr: 1.0000e-03
# Epoch 46/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8973 - mean_squared_error: 0.5971 - mean_absolute_error: 0.5964 - mean_absolute_percentage_error: 211.0335
# Epoch 00046: mean_absolute_error did not improve from 0.58957
#
# Epoch 00046: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 67s 10s/step - loss: -0.8973 - mean_squared_error: 0.5971 - mean_absolute_error: 0.5964 - mean_absolute_percentage_error: 211.0335 - val_loss: -0.5566 - val_mean_squared_error: 0.3776 - val_mean_absolute_error: 0.5282 - val_mean_absolute_percentage_error: 145.8953 - lr: 1.0000e-03
# Epoch 47/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8986 - mean_squared_error: 0.5858 - mean_absolute_error: 0.5896 - mean_absolute_percentage_error: 191.5096
# Epoch 00047: mean_absolute_error improved from 0.58957 to 0.58955, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00047: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 67s 10s/step - loss: -0.8986 - mean_squared_error: 0.5858 - mean_absolute_error: 0.5896 - mean_absolute_percentage_error: 191.5096 - val_loss: -0.6200 - val_mean_squared_error: 0.3838 - val_mean_absolute_error: 0.5312 - val_mean_absolute_percentage_error: 147.3973 - lr: 1.0000e-03
# Epoch 48/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9051 - mean_squared_error: 0.5912 - mean_absolute_error: 0.5952 - mean_absolute_percentage_error: 195.6623
# Epoch 00048: mean_absolute_error did not improve from 0.58955
#
# Epoch 00048: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 67s 10s/step - loss: -0.9051 - mean_squared_error: 0.5912 - mean_absolute_error: 0.5952 - mean_absolute_percentage_error: 195.6623 - val_loss: -0.6988 - val_mean_squared_error: 0.3949 - val_mean_absolute_error: 0.5327 - val_mean_absolute_percentage_error: 145.2689 - lr: 1.0000e-03
# Epoch 49/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9011 - mean_squared_error: 0.5791 - mean_absolute_error: 0.5903 - mean_absolute_percentage_error: 198.2058
# Epoch 00049: mean_absolute_error did not improve from 0.58955
#
# Epoch 00049: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9011 - mean_squared_error: 0.5791 - mean_absolute_error: 0.5903 - mean_absolute_percentage_error: 198.2058 - val_loss: -0.7037 - val_mean_squared_error: 0.4192 - val_mean_absolute_error: 0.5447 - val_mean_absolute_percentage_error: 142.6677 - lr: 1.0000e-03
# Epoch 50/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9003 - mean_squared_error: 0.5757 - mean_absolute_error: 0.5877 - mean_absolute_percentage_error: 197.4432
# Epoch 00050: mean_absolute_error improved from 0.58955 to 0.58770, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00050: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9003 - mean_squared_error: 0.5757 - mean_absolute_error: 0.5877 - mean_absolute_percentage_error: 197.4432 - val_loss: -0.7104 - val_mean_squared_error: 0.4357 - val_mean_absolute_error: 0.5514 - val_mean_absolute_percentage_error: 144.6382 - lr: 1.0000e-03
# Epoch 51/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9081 - mean_squared_error: 0.5878 - mean_absolute_error: 0.5925 - mean_absolute_percentage_error: 200.1013
# Epoch 00051: mean_absolute_error did not improve from 0.58770
#
# Epoch 00051: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9081 - mean_squared_error: 0.5878 - mean_absolute_error: 0.5925 - mean_absolute_percentage_error: 200.1013 - val_loss: -0.7143 - val_mean_squared_error: 0.4531 - val_mean_absolute_error: 0.5580 - val_mean_absolute_percentage_error: 149.3821 - lr: 1.0000e-03
# Epoch 52/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8972 - mean_squared_error: 0.5770 - mean_absolute_error: 0.5893 - mean_absolute_percentage_error: 200.4249
# Epoch 00052: mean_absolute_error did not improve from 0.58770
#
# Epoch 00052: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.8972 - mean_squared_error: 0.5770 - mean_absolute_error: 0.5893 - mean_absolute_percentage_error: 200.4249 - val_loss: -0.7099 - val_mean_squared_error: 0.4516 - val_mean_absolute_error: 0.5552 - val_mean_absolute_percentage_error: 152.5451 - lr: 1.0000e-03
# Epoch 53/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9106 - mean_squared_error: 0.5692 - mean_absolute_error: 0.5845 - mean_absolute_percentage_error: 199.9576
# Epoch 00053: mean_absolute_error improved from 0.58770 to 0.58454, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00053: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9106 - mean_squared_error: 0.5692 - mean_absolute_error: 0.5845 - mean_absolute_percentage_error: 199.9576 - val_loss: -0.7149 - val_mean_squared_error: 0.4586 - val_mean_absolute_error: 0.5559 - val_mean_absolute_percentage_error: 156.4511 - lr: 1.0000e-03
# Epoch 54/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9161 - mean_squared_error: 0.5729 - mean_absolute_error: 0.5867 - mean_absolute_percentage_error: 182.9964
# Epoch 00054: mean_absolute_error did not improve from 0.58454
#
# Epoch 00054: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9161 - mean_squared_error: 0.5729 - mean_absolute_error: 0.5867 - mean_absolute_percentage_error: 182.9964 - val_loss: -0.7050 - val_mean_squared_error: 0.4860 - val_mean_absolute_error: 0.5670 - val_mean_absolute_percentage_error: 163.4759 - lr: 1.0000e-03
# Epoch 55/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9134 - mean_squared_error: 0.5666 - mean_absolute_error: 0.5834 - mean_absolute_percentage_error: 187.7906
# Epoch 00055: mean_absolute_error improved from 0.58454 to 0.58341, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00055: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9134 - mean_squared_error: 0.5666 - mean_absolute_error: 0.5834 - mean_absolute_percentage_error: 187.7906 - val_loss: -0.6958 - val_mean_squared_error: 0.5049 - val_mean_absolute_error: 0.5742 - val_mean_absolute_percentage_error: 164.8606 - lr: 1.0000e-03
# Epoch 56/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9088 - mean_squared_error: 0.5679 - mean_absolute_error: 0.5829 - mean_absolute_percentage_error: 191.2858
# Epoch 00056: mean_absolute_error improved from 0.58341 to 0.58294, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00056: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9088 - mean_squared_error: 0.5679 - mean_absolute_error: 0.5829 - mean_absolute_percentage_error: 191.2858 - val_loss: -0.7322 - val_mean_squared_error: 0.4857 - val_mean_absolute_error: 0.5609 - val_mean_absolute_percentage_error: 172.8033 - lr: 1.0000e-03
# Epoch 57/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9113 - mean_squared_error: 0.5833 - mean_absolute_error: 0.5873 - mean_absolute_percentage_error: 188.5616
# Epoch 00057: mean_absolute_error did not improve from 0.58294
#
# Epoch 00057: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9113 - mean_squared_error: 0.5833 - mean_absolute_error: 0.5873 - mean_absolute_percentage_error: 188.5616 - val_loss: -0.7356 - val_mean_squared_error: 0.4700 - val_mean_absolute_error: 0.5532 - val_mean_absolute_percentage_error: 160.4368 - lr: 1.0000e-03
# Epoch 58/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9118 - mean_squared_error: 0.5707 - mean_absolute_error: 0.5818 - mean_absolute_percentage_error: 184.1533
# Epoch 00058: mean_absolute_error improved from 0.58294 to 0.58181, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00058: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 67s 10s/step - loss: -0.9118 - mean_squared_error: 0.5707 - mean_absolute_error: 0.5818 - mean_absolute_percentage_error: 184.1533 - val_loss: -0.7428 - val_mean_squared_error: 0.4651 - val_mean_absolute_error: 0.5518 - val_mean_absolute_percentage_error: 153.1814 - lr: 1.0000e-03
# Epoch 59/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9112 - mean_squared_error: 0.5699 - mean_absolute_error: 0.5834 - mean_absolute_percentage_error: 185.6334
# Epoch 00059: mean_absolute_error did not improve from 0.58181
#
# Epoch 00059: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9112 - mean_squared_error: 0.5699 - mean_absolute_error: 0.5834 - mean_absolute_percentage_error: 185.6334 - val_loss: -0.7405 - val_mean_squared_error: 0.4769 - val_mean_absolute_error: 0.5562 - val_mean_absolute_percentage_error: 151.0560 - lr: 1.0000e-03
# Epoch 60/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9180 - mean_squared_error: 0.5483 - mean_absolute_error: 0.5725 - mean_absolute_percentage_error: 179.1410
# Epoch 00060: mean_absolute_error improved from 0.58181 to 0.57245, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00060: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9180 - mean_squared_error: 0.5483 - mean_absolute_error: 0.5725 - mean_absolute_percentage_error: 179.1410 - val_loss: -0.7407 - val_mean_squared_error: 0.4880 - val_mean_absolute_error: 0.5591 - val_mean_absolute_percentage_error: 160.3731 - lr: 1.0000e-03
# Epoch 61/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9177 - mean_squared_error: 0.5468 - mean_absolute_error: 0.5707 - mean_absolute_percentage_error: 177.6945
# Epoch 00061: mean_absolute_error improved from 0.57245 to 0.57071, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00061: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9177 - mean_squared_error: 0.5468 - mean_absolute_error: 0.5707 - mean_absolute_percentage_error: 177.6945 - val_loss: -0.7285 - val_mean_squared_error: 0.5081 - val_mean_absolute_error: 0.5672 - val_mean_absolute_percentage_error: 153.7023 - lr: 1.0000e-03
# Epoch 62/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9192 - mean_squared_error: 0.5464 - mean_absolute_error: 0.5748 - mean_absolute_percentage_error: 179.8833
# Epoch 00062: mean_absolute_error did not improve from 0.57071
#
# Epoch 00062: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9192 - mean_squared_error: 0.5464 - mean_absolute_error: 0.5748 - mean_absolute_percentage_error: 179.8833 - val_loss: -0.7244 - val_mean_squared_error: 0.5090 - val_mean_absolute_error: 0.5678 - val_mean_absolute_percentage_error: 157.3346 - lr: 1.0000e-03
# Epoch 63/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9131 - mean_squared_error: 0.5310 - mean_absolute_error: 0.5682 - mean_absolute_percentage_error: 181.6035
# Epoch 00063: mean_absolute_error improved from 0.57071 to 0.56824, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00063: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.9131 - mean_squared_error: 0.5310 - mean_absolute_error: 0.5682 - mean_absolute_percentage_error: 181.6035 - val_loss: -0.7354 - val_mean_squared_error: 0.5215 - val_mean_absolute_error: 0.5715 - val_mean_absolute_percentage_error: 156.5647 - lr: 1.0000e-03
# Epoch 64/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9128 - mean_squared_error: 0.5593 - mean_absolute_error: 0.5796 - mean_absolute_percentage_error: 187.2148
# Epoch 00064: mean_absolute_error did not improve from 0.56824
#
# Epoch 00064: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9128 - mean_squared_error: 0.5593 - mean_absolute_error: 0.5796 - mean_absolute_percentage_error: 187.2148 - val_loss: -0.7212 - val_mean_squared_error: 0.5342 - val_mean_absolute_error: 0.5758 - val_mean_absolute_percentage_error: 160.9576 - lr: 1.0000e-03
# Epoch 65/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9223 - mean_squared_error: 0.5467 - mean_absolute_error: 0.5721 - mean_absolute_percentage_error: 181.0123
# Epoch 00065: mean_absolute_error did not improve from 0.56824
#
# Epoch 00065: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9223 - mean_squared_error: 0.5467 - mean_absolute_error: 0.5721 - mean_absolute_percentage_error: 181.0123 - val_loss: -0.6758 - val_mean_squared_error: 0.5253 - val_mean_absolute_error: 0.5789 - val_mean_absolute_percentage_error: 179.5393 - lr: 1.0000e-03
# Epoch 66/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9208 - mean_squared_error: 0.5421 - mean_absolute_error: 0.5701 - mean_absolute_percentage_error: 187.0244
# Epoch 00066: mean_absolute_error did not improve from 0.56824
#
# Epoch 00066: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9208 - mean_squared_error: 0.5421 - mean_absolute_error: 0.5701 - mean_absolute_percentage_error: 187.0244 - val_loss: -0.6795 - val_mean_squared_error: 0.5215 - val_mean_absolute_error: 0.5799 - val_mean_absolute_percentage_error: 187.3911 - lr: 1.0000e-03
# Epoch 67/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9133 - mean_squared_error: 0.5326 - mean_absolute_error: 0.5633 - mean_absolute_percentage_error: 175.3164
# Epoch 00067: mean_absolute_error improved from 0.56824 to 0.56333, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00067: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9133 - mean_squared_error: 0.5326 - mean_absolute_error: 0.5633 - mean_absolute_percentage_error: 175.3164 - val_loss: -0.6796 - val_mean_squared_error: 0.4914 - val_mean_absolute_error: 0.5639 - val_mean_absolute_percentage_error: 169.6250 - lr: 1.0000e-03
# Epoch 68/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9262 - mean_squared_error: 0.5354 - mean_absolute_error: 0.5639 - mean_absolute_percentage_error: 174.2865
# Epoch 00068: mean_absolute_error did not improve from 0.56333
#
# Epoch 00068: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9262 - mean_squared_error: 0.5354 - mean_absolute_error: 0.5639 - mean_absolute_percentage_error: 174.2865 - val_loss: -0.6936 - val_mean_squared_error: 0.4989 - val_mean_absolute_error: 0.5671 - val_mean_absolute_percentage_error: 172.8988 - lr: 1.0000e-03
# Epoch 69/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9283 - mean_squared_error: 0.5344 - mean_absolute_error: 0.5699 - mean_absolute_percentage_error: 170.1227
# Epoch 00069: mean_absolute_error did not improve from 0.56333
#
# Epoch 00069: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9283 - mean_squared_error: 0.5344 - mean_absolute_error: 0.5699 - mean_absolute_percentage_error: 170.1227 - val_loss: -0.7018 - val_mean_squared_error: 0.4867 - val_mean_absolute_error: 0.5609 - val_mean_absolute_percentage_error: 168.7116 - lr: 1.0000e-03
# Epoch 70/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9318 - mean_squared_error: 0.5324 - mean_absolute_error: 0.5642 - mean_absolute_percentage_error: 168.7912
# Epoch 00070: mean_absolute_error did not improve from 0.56333
#
# Epoch 00070: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9318 - mean_squared_error: 0.5324 - mean_absolute_error: 0.5642 - mean_absolute_percentage_error: 168.7912 - val_loss: -0.6967 - val_mean_squared_error: 0.5021 - val_mean_absolute_error: 0.5711 - val_mean_absolute_percentage_error: 184.3955 - lr: 1.0000e-03
# Epoch 71/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9278 - mean_squared_error: 0.5300 - mean_absolute_error: 0.5646 - mean_absolute_percentage_error: 173.7066
# Epoch 00071: mean_absolute_error did not improve from 0.56333
#
# Epoch 00071: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9278 - mean_squared_error: 0.5300 - mean_absolute_error: 0.5646 - mean_absolute_percentage_error: 173.7066 - val_loss: -0.6909 - val_mean_squared_error: 0.4969 - val_mean_absolute_error: 0.5683 - val_mean_absolute_percentage_error: 187.5115 - lr: 1.0000e-03
# Epoch 72/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9135 - mean_squared_error: 0.5098 - mean_absolute_error: 0.5576 - mean_absolute_percentage_error: 173.4162
# Epoch 00072: mean_absolute_error improved from 0.56333 to 0.55763, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00072: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9135 - mean_squared_error: 0.5098 - mean_absolute_error: 0.5576 - mean_absolute_percentage_error: 173.4162 - val_loss: -0.7014 - val_mean_squared_error: 0.4993 - val_mean_absolute_error: 0.5665 - val_mean_absolute_percentage_error: 180.3349 - lr: 1.0000e-03
# Epoch 73/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9204 - mean_squared_error: 0.5160 - mean_absolute_error: 0.5592 - mean_absolute_percentage_error: 173.2546
# Epoch 00073: mean_absolute_error did not improve from 0.55763
#
# Epoch 00073: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9204 - mean_squared_error: 0.5160 - mean_absolute_error: 0.5592 - mean_absolute_percentage_error: 173.2546 - val_loss: -0.7050 - val_mean_squared_error: 0.5186 - val_mean_absolute_error: 0.5681 - val_mean_absolute_percentage_error: 168.1439 - lr: 1.0000e-03
# Epoch 74/200
# ...
#
# Epoch 00176: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9598 - mean_squared_error: 0.4564 - mean_absolute_error: 0.5330 - mean_absolute_percentage_error: 140.8178 - val_loss: -0.8012 - val_mean_squared_error: 0.4758 - val_mean_absolute_error: 0.5408 - val_mean_absolute_percentage_error: 134.3052 - lr: 1.0000e-04
# Epoch 177/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9680 - mean_squared_error: 0.4555 - mean_absolute_error: 0.5302 - mean_absolute_percentage_error: 136.4364
# Epoch 00177: mean_absolute_error did not improve from 0.52380
#
# Epoch 00177: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9680 - mean_squared_error: 0.4555 - mean_absolute_error: 0.5302 - mean_absolute_percentage_error: 136.4364 - val_loss: -0.7960 - val_mean_squared_error: 0.4759 - val_mean_absolute_error: 0.5417 - val_mean_absolute_percentage_error: 136.7493 - lr: 1.0000e-04
# Epoch 178/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9724 - mean_squared_error: 0.4467 - mean_absolute_error: 0.5251 - mean_absolute_percentage_error: 133.7259
# Epoch 00178: mean_absolute_error did not improve from 0.52380
#
# Epoch 00178: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9724 - mean_squared_error: 0.4467 - mean_absolute_error: 0.5251 - mean_absolute_percentage_error: 133.7259 - val_loss: -0.7951 - val_mean_squared_error: 0.4759 - val_mean_absolute_error: 0.5418 - val_mean_absolute_percentage_error: 137.4431 - lr: 1.0000e-04
# Epoch 179/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9638 - mean_squared_error: 0.4506 - mean_absolute_error: 0.5255 - mean_absolute_percentage_error: 134.8363
# Epoch 00179: mean_absolute_error did not improve from 0.52380
#
# Epoch 00179: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 68s 10s/step - loss: -0.9638 - mean_squared_error: 0.4506 - mean_absolute_error: 0.5255 - mean_absolute_percentage_error: 134.8363 - val_loss: -0.7988 - val_mean_squared_error: 0.4747 - val_mean_absolute_error: 0.5411 - val_mean_absolute_percentage_error: 136.3721 - lr: 1.0000e-04
# Epoch 180/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9725 - mean_squared_error: 0.4508 - mean_absolute_error: 0.5265 - mean_absolute_percentage_error: 136.7748
# Epoch 00180: mean_absolute_error did not improve from 0.52380
#
# Epoch 00180: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9725 - mean_squared_error: 0.4508 - mean_absolute_error: 0.5265 - mean_absolute_percentage_error: 136.7748 - val_loss: -0.8004 - val_mean_squared_error: 0.4742 - val_mean_absolute_error: 0.5408 - val_mean_absolute_percentage_error: 135.9823 - lr: 1.0000e-04
# Epoch 181/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9568 - mean_squared_error: 0.4474 - mean_absolute_error: 0.5238 - mean_absolute_percentage_error: 151.6442
# Epoch 00181: mean_absolute_error improved from 0.52380 to 0.52380, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00181: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.9568 - mean_squared_error: 0.4474 - mean_absolute_error: 0.5238 - mean_absolute_percentage_error: 151.6442 - val_loss: -0.8014 - val_mean_squared_error: 0.4737 - val_mean_absolute_error: 0.5405 - val_mean_absolute_percentage_error: 135.9484 - lr: 1.0000e-04
# Epoch 182/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9585 - mean_squared_error: 0.4563 - mean_absolute_error: 0.5313 - mean_absolute_percentage_error: 141.8885
# Epoch 00182: mean_absolute_error did not improve from 0.52380
#
# Epoch 00182: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.9585 - mean_squared_error: 0.4563 - mean_absolute_error: 0.5313 - mean_absolute_percentage_error: 141.8885 - val_loss: -0.7973 - val_mean_squared_error: 0.4738 - val_mean_absolute_error: 0.5408 - val_mean_absolute_percentage_error: 136.6876 - lr: 1.0000e-04
# Epoch 183/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9674 - mean_squared_error: 0.4510 - mean_absolute_error: 0.5273 - mean_absolute_percentage_error: 150.3627
# Epoch 00183: mean_absolute_error did not improve from 0.52380
#
# Epoch 00183: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.9674 - mean_squared_error: 0.4510 - mean_absolute_error: 0.5273 - mean_absolute_percentage_error: 150.3627 - val_loss: -0.8078 - val_mean_squared_error: 0.4735 - val_mean_absolute_error: 0.5393 - val_mean_absolute_percentage_error: 132.6816 - lr: 1.0000e-04
# Epoch 184/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9681 - mean_squared_error: 0.4460 - mean_absolute_error: 0.5238 - mean_absolute_percentage_error: 143.6166
# Epoch 00184: mean_absolute_error did not improve from 0.52380
#
# Epoch 00184: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.9681 - mean_squared_error: 0.4460 - mean_absolute_error: 0.5238 - mean_absolute_percentage_error: 143.6166 - val_loss: -0.8124 - val_mean_squared_error: 0.4733 - val_mean_absolute_error: 0.5389 - val_mean_absolute_percentage_error: 132.8890 - lr: 1.0000e-04
# Epoch 185/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9720 - mean_squared_error: 0.4536 - mean_absolute_error: 0.5244 - mean_absolute_percentage_error: 130.1342
# Epoch 00185: mean_absolute_error did not improve from 0.52380
#
# Epoch 00185: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.9720 - mean_squared_error: 0.4536 - mean_absolute_error: 0.5244 - mean_absolute_percentage_error: 130.1342 - val_loss: -0.8136 - val_mean_squared_error: 0.4722 - val_mean_absolute_error: 0.5384 - val_mean_absolute_percentage_error: 132.7762 - lr: 1.0000e-04
# Epoch 186/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9596 - mean_squared_error: 0.4564 - mean_absolute_error: 0.5360 - mean_absolute_percentage_error: 141.4439
# Epoch 00186: mean_absolute_error did not improve from 0.52380
#
# Epoch 00186: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.9596 - mean_squared_error: 0.4564 - mean_absolute_error: 0.5360 - mean_absolute_percentage_error: 141.4439 - val_loss: -0.8118 - val_mean_squared_error: 0.4710 - val_mean_absolute_error: 0.5382 - val_mean_absolute_percentage_error: 132.4625 - lr: 1.0000e-04
# Epoch 187/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9655 - mean_squared_error: 0.4515 - mean_absolute_error: 0.5281 - mean_absolute_percentage_error: 144.2325
# Epoch 00187: mean_absolute_error did not improve from 0.52380
#
# Epoch 00187: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.9655 - mean_squared_error: 0.4515 - mean_absolute_error: 0.5281 - mean_absolute_percentage_error: 144.2325 - val_loss: -0.8131 - val_mean_squared_error: 0.4706 - val_mean_absolute_error: 0.5379 - val_mean_absolute_percentage_error: 132.0563 - lr: 1.0000e-04
# Epoch 188/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9658 - mean_squared_error: 0.4484 - mean_absolute_error: 0.5227 - mean_absolute_percentage_error: 132.0708
# Epoch 00188: mean_absolute_error improved from 0.52380 to 0.52274, saving model to models/best_weights_xy_SGD_filter_steped_lr.hdf5
#
# Epoch 00188: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.9658 - mean_squared_error: 0.4484 - mean_absolute_error: 0.5227 - mean_absolute_percentage_error: 132.0708 - val_loss: -0.8092 - val_mean_squared_error: 0.4709 - val_mean_absolute_error: 0.5382 - val_mean_absolute_percentage_error: 133.0028 - lr: 1.0000e-04
# Epoch 189/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9633 - mean_squared_error: 0.4505 - mean_absolute_error: 0.5267 - mean_absolute_percentage_error: 149.7375
# Epoch 00189: mean_absolute_error did not improve from 0.52274
#
# Epoch 00189: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.9633 - mean_squared_error: 0.4505 - mean_absolute_error: 0.5267 - mean_absolute_percentage_error: 149.7375 - val_loss: -0.8150 - val_mean_squared_error: 0.4703 - val_mean_absolute_error: 0.5370 - val_mean_absolute_percentage_error: 132.6229 - lr: 1.0000e-04
# Epoch 190/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9665 - mean_squared_error: 0.4495 - mean_absolute_error: 0.5268 - mean_absolute_percentage_error: 144.0536
# Epoch 00190: mean_absolute_error did not improve from 0.52274
#
# Epoch 00190: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.9665 - mean_squared_error: 0.4495 - mean_absolute_error: 0.5268 - mean_absolute_percentage_error: 144.0536 - val_loss: -0.8185 - val_mean_squared_error: 0.4697 - val_mean_absolute_error: 0.5365 - val_mean_absolute_percentage_error: 130.5967 - lr: 1.0000e-04
# Epoch 191/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9654 - mean_squared_error: 0.4460 - mean_absolute_error: 0.5259 - mean_absolute_percentage_error: 140.2035
# Epoch 00191: mean_absolute_error did not improve from 0.52274
#
# Epoch 00191: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.9654 - mean_squared_error: 0.4460 - mean_absolute_error: 0.5259 - mean_absolute_percentage_error: 140.2035 - val_loss: -0.8158 - val_mean_squared_error: 0.4723 - val_mean_absolute_error: 0.5383 - val_mean_absolute_percentage_error: 133.3917 - lr: 1.0000e-04
# Epoch 192/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9564 - mean_squared_error: 0.4485 - mean_absolute_error: 0.5276 - mean_absolute_percentage_error: 148.9898
# Epoch 00192: mean_absolute_error did not improve from 0.52274
#
# Epoch 00192: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.9564 - mean_squared_error: 0.4485 - mean_absolute_error: 0.5276 - mean_absolute_percentage_error: 148.9898 - val_loss: -0.8207 - val_mean_squared_error: 0.4700 - val_mean_absolute_error: 0.5364 - val_mean_absolute_percentage_error: 129.1801 - lr: 1.0000e-04
# Epoch 193/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9725 - mean_squared_error: 0.4464 - mean_absolute_error: 0.5239 - mean_absolute_percentage_error: 130.3578
# Epoch 00193: mean_absolute_error did not improve from 0.52274
#
# Epoch 00193: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9725 - mean_squared_error: 0.4464 - mean_absolute_error: 0.5239 - mean_absolute_percentage_error: 130.3578 - val_loss: -0.8169 - val_mean_squared_error: 0.4697 - val_mean_absolute_error: 0.5365 - val_mean_absolute_percentage_error: 129.2489 - lr: 1.0000e-04
# Epoch 194/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9708 - mean_squared_error: 0.4516 - mean_absolute_error: 0.5263 - mean_absolute_percentage_error: 136.7977
# Epoch 00194: mean_absolute_error did not improve from 0.52274
#
# Epoch 00194: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 69s 10s/step - loss: -0.9708 - mean_squared_error: 0.4516 - mean_absolute_error: 0.5263 - mean_absolute_percentage_error: 136.7977 - val_loss: -0.8129 - val_mean_squared_error: 0.4705 - val_mean_absolute_error: 0.5366 - val_mean_absolute_percentage_error: 129.1741 - lr: 1.0000e-04
# Epoch 195/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9654 - mean_squared_error: 0.4523 - mean_absolute_error: 0.5276 - mean_absolute_percentage_error: 139.4561
# Epoch 00195: mean_absolute_error did not improve from 0.52274
#
# Epoch 00195: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.9654 - mean_squared_error: 0.4523 - mean_absolute_error: 0.5276 - mean_absolute_percentage_error: 139.4561 - val_loss: -0.8082 - val_mean_squared_error: 0.4709 - val_mean_absolute_error: 0.5379 - val_mean_absolute_percentage_error: 130.8665 - lr: 1.0000e-04
# Epoch 196/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9743 - mean_squared_error: 0.4524 - mean_absolute_error: 0.5249 - mean_absolute_percentage_error: 129.9942
# Epoch 00196: mean_absolute_error did not improve from 0.52274
#
# Epoch 00196: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.9743 - mean_squared_error: 0.4524 - mean_absolute_error: 0.5249 - mean_absolute_percentage_error: 129.9942 - val_loss: -0.7886 - val_mean_squared_error: 0.4675 - val_mean_absolute_error: 0.5397 - val_mean_absolute_percentage_error: 135.3639 - lr: 1.0000e-04
# Epoch 197/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9654 - mean_squared_error: 0.4483 - mean_absolute_error: 0.5253 - mean_absolute_percentage_error: 138.8223
# Epoch 00197: mean_absolute_error did not improve from 0.52274
#
# Epoch 00197: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.9654 - mean_squared_error: 0.4483 - mean_absolute_error: 0.5253 - mean_absolute_percentage_error: 138.8223 - val_loss: -0.7913 - val_mean_squared_error: 0.4672 - val_mean_absolute_error: 0.5391 - val_mean_absolute_percentage_error: 135.0811 - lr: 1.0000e-04
# Epoch 198/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9685 - mean_squared_error: 0.4504 - mean_absolute_error: 0.5232 - mean_absolute_percentage_error: 139.2581
# Epoch 00198: mean_absolute_error did not improve from 0.52274
#
# Epoch 00198: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.9685 - mean_squared_error: 0.4504 - mean_absolute_error: 0.5232 - mean_absolute_percentage_error: 139.2581 - val_loss: -0.7933 - val_mean_squared_error: 0.4671 - val_mean_absolute_error: 0.5381 - val_mean_absolute_percentage_error: 134.5249 - lr: 1.0000e-04
# Epoch 199/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9679 - mean_squared_error: 0.4500 - mean_absolute_error: 0.5250 - mean_absolute_percentage_error: 136.0598
# Epoch 00199: mean_absolute_error did not improve from 0.52274
#
# Epoch 00199: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.9679 - mean_squared_error: 0.4500 - mean_absolute_error: 0.5250 - mean_absolute_percentage_error: 136.0598 - val_loss: -0.7940 - val_mean_squared_error: 0.4678 - val_mean_absolute_error: 0.5390 - val_mean_absolute_percentage_error: 135.3687 - lr: 1.0000e-04
# Epoch 200/200
# 7/7 [==============================] - ETA: 0s - loss: -0.9689 - mean_squared_error: 0.4607 - mean_absolute_error: 0.5340 - mean_absolute_percentage_error: 142.4936
# Epoch 00200: mean_absolute_error did not improve from 0.52274
#
# Epoch 00200: saving model to models/last_weights_xy_SGD_filter_steped_lr.hdf5
# 7/7 [==============================] - 70s 10s/step - loss: -0.9689 - mean_squared_error: 0.4607 - mean_absolute_error: 0.5340 - mean_absolute_percentage_error: 142.4936 - val_loss: -0.7937 - val_mean_squared_error: 0.4687 - val_mean_absolute_error: 0.5392 - val_mean_absolute_percentage_error: 135.2182 - lr: 1.0000e-04

# %%
model.save('models/trained_xy_SGD_filter_steped_lr.h5')

# %%
# taking samples from the validation dataset and evaluating the model
val_ex, = validation_ds.take(1)
images, labels = val_ex[0], val_ex[1]
outputs = model.predict(images)

# %%
#print(labels)
print(outputs[:20])
# Out:
# [[-0.18475091 -0.13758847]
#  [-0.3971124   0.03076621]
#  [-0.02062931  0.2583957 ]
#  [-0.28902146  0.40343887]
#  [-0.20445615 -0.12610278]
#  [-0.09972861  0.1576195 ]
#  [-0.45113885 -0.12274478]
#  [-0.5006209   0.03263068]
#  [-0.25176767  0.10515235]
#  [-0.3434742  -0.3526522 ]
#  [-0.32808223  0.3187345 ]
#  [-0.3246201  -0.00267679]
#  [-0.15998891 -0.00152429]
#  [-0.06702946  0.22846806]
#  [-0.38863733 -0.01787622]
#  [-0.36423287  0.08803786]
#  [-0.22466266  0.16343656]
#  [-0.23764668  0.06252979]
#  [-0.06126085  0.0839898 ]
#  [-0.0845544  -0.03229883]]

# %%
# visualicing the results
for img,label,pred,i in zip(images, labels, outputs,range(15)):
    viz(img, label, pred)
# Out:
# #### **cartesian label:** [-0.6349558 -0.7693941]
# #### **cartesian prediction (x_y):** [-0.18475091 -0.13758847]
# #### **cartesian label:** [-0.9220268  0.0066615]
# #### **cartesian prediction (x_y):** [-0.3971124   0.03076621]
# #### **cartesian label:** [-0.18631142 -0.93576944]
# #### **cartesian prediction (x_y):** [-0.02062931  0.2583957 ]
# #### **cartesian label:** [-0.7779883   0.62356985]
# #### **cartesian prediction (x_y):** [-0.28902146  0.40343887]
# #### **cartesian label:** [-0.09215847 -0.9903909 ]
# #### **cartesian prediction (x_y):** [-0.20445615 -0.12610278]
# #### **cartesian label:** [0.06662744 0.643938  ]
# #### **cartesian prediction (x_y):** [-0.09972861  0.1576195 ]
# #### **cartesian label:** [ 0.9544602  -0.04354519]
# #### **cartesian prediction (x_y):** [-0.45113885 -0.12274478]
# #### **cartesian label:** [ 0.9895168  -0.14151087]
# #### **cartesian prediction (x_y):** [-0.5006209   0.03263068]
# #### **cartesian label:** [-0.86674064  0.02315868]
# #### **cartesian prediction (x_y):** [-0.25176767  0.10515235]
# #### **cartesian label:** [-0.6371739  0.5229839]
# #### **cartesian prediction (x_y):** [-0.3434742 -0.3526522]
# #### **cartesian label:** [0.47179195 0.18125378]
# #### **cartesian prediction (x_y):** [-0.32808223  0.3187345 ]
# #### **cartesian label:** [ 0.4930079  -0.04662171]
# #### **cartesian prediction (x_y):** [-0.3246201  -0.00267679]
# #### **cartesian label:** [0.31511977 0.3610425 ]
# #### **cartesian prediction (x_y):** [-0.15998891 -0.00152429]
# #### **cartesian label:** [ 0.5522041 -0.7947307]
# #### **cartesian prediction (x_y):** [-0.06702946  0.22846806]
# #### **cartesian label:** [0.9125912  0.15694979]
# #### **cartesian prediction (x_y):** [-0.38863733 -0.01787622]

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TF Lite model.
with tf.io.gfile.GFile('tflite_model.tflite', 'wb') as f:
    f.write(tflite_model)
