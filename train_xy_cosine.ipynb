# %%
import os
from classification_models.tfkeras import Classifiers

# Import the ResNet34 model
ResNet34, preprocess_input = Classifiers.get('resnet34')

# %%
# Run only for training!
import glob
import math
import datetime
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
from sklearn.preprocessing import normalize

tfd = tfp.distributions
tfpl = tfp.layers
tfk = tf.keras
tfkl = tf.keras.layers

# Change parameters here...
log_dir = "logs/"
os.makedirs(log_dir, exist_ok=True)
data_dir = 'data/' 
sizex = 500
sizey = 500
sizez = 3
rand_seed = 666
num_datasets = -1
batch_size = 32
buf_size = 895
nb_epochs = 100
validation_ratio = 0.1

# %%
# Collect all the .npz files
numpy_datasets = glob.glob(data_dir+'dataset*')

# %%
# load the data into a dictionary from npz files
data_dict = {}
for dataset in numpy_datasets[:num_datasets]:
    with np.load(dataset) as data:
        if 'y' in data_dict.keys():
            #data_dict['x_dust']   = np.append( data_dict['x_dust'], data['x_dust'],axis=0)
            data_dict['x_nodust'] = np.append( data_dict['x_nodust'], data['x_nodust'],axis=0)
            data_dict['y']        = np.append( data_dict['y'], data['y'],axis=0)
            data_dict['ids']      = np.append( data_dict['ids'], data['id'],axis=0)
        else:
            #data_dict['x_dust']   = data['x_dust']
            data_dict['x_nodust'] = data['x_nodust']
            data_dict['y']        = data['y']
            data_dict['ids']      = data['id']

# %%
# check the shape of the dictionary (100 images of 500x500x3 = 4 files of 25 images)
data_dict['x_nodust'].shape
# Out:
# (895, 500, 500, 3)

# %%
# Compute the angles from the x,y,z labels
# theta = np.arctan(np.sqrt(x**2 + y**2)/z)
# phi = np.arctan(y/x)
def cart_to_esf(xyz):
    angles = np.empty( (len(xyz),2) )
    angles[:,0] = np.arctan2(np.sqrt(xyz[:,0]**2 + xyz[:,1]**2),xyz[:,2]) *180/np.pi #theta angle in degrees
    angles[:,1] = np.arctan2(xyz[:,1],xyz[:,0]) * 180/np.pi #phi angle in degrees
    return angles

# Define the function to go back to cartisian cordinates
def esf_to_cart(angles):
    xyz = np.empty( (len(angles),3) )
    ang_rad = angles*np.pi/180
    xyz[:,0] = np.sin(ang_rad[:,0])*np.cos(ang_rad[:,1])
    xyz[:,1] = np.sin(ang_rad[:,0])*np.sin(ang_rad[:,1])
    xyz[:,2] = np.cos(ang_rad[:,0])
    return xyz

#break the degeneracy of the solutions restricting the solution to 1 sector
def break_degeneracy(angles):
    ang_norm = angles
    for i in range(len(angles)):
        if ang_norm[:,1][i] < 0:
            ang_norm[:,1][i] = (ang_norm[:,1][i] + 180)
    return ang_norm

#map the solution to be between [0,1]
def map_to_1(angles, max = 180 ):
    ang_norm = angles/max
    return ang_norm

#coming back the mapping from 1 to 180
def map_to_180(ang_norm):
  angle = ang_norm*180
  return angle

# computing the normaliced vectors in 3D
data_dict['y_norm'] = normalize(data_dict['y'], axis=1)
data_dict['y_ang'] = map_to_1(break_degeneracy(cart_to_esf(normalize(data_dict['y'], axis=1))))
data_dict['y_revs'] = esf_to_cart(map_to_180(data_dict['y_ang']))

# %%
# check the shape of our dictionary in te labels entry
print(data_dict['y_norm'].shape)
# Out:
# (895, 3)

# %%
# separate in batches and shuffle the data with a fixed seed
#dataset = dataset.batch(batch_size)
#dataset = dataset.shuffle(10, seed=123)
AUTO = tf.data.experimental.AUTOTUNE

# %%
# functions to visualice the data 
def viz(img, label, pred=np.array([0,0,0]), id=None):
    fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(img, cmap='gray', vmin=0, vmax=255,origin='lower')
    ax.arrow(250,250,100*label[0],100*label[1], head_width=7, head_length=10, fc='g', ec='g')
    if np.sum(np.abs(pred)) > 0: ax.arrow(250,250,100*pred[0],100*pred[1], head_width=7, head_length=10, fc='r', ec='r')
        
    display(Markdown("#### **cartesian label:** {}".format(label)))
    if np.sum(np.abs(pred)) > 0: display(Markdown("#### **cartesian prediction (x_y):** {}".format(pred)))
    if id: display(Markdown("#### **ID:** {}".format(id)))
    plt.show()

# create the dataset from the dictionary and see the size and type
dataset = tf.data.Dataset.from_tensor_slices(data_dict)
print(dataset)
# Out:
# <TensorSliceDataset shapes: {x_nodust: (500, 500, 3), y: (3,), ids: (), y_norm: (3,), y_ang: (2,), y_revs: (3,)}, types: {x_nodust: tf.float64, y: tf.float64, ids: tf.string, y_norm: tf.float64, y_ang: tf.float64, y_revs: tf.float64}>

# %%
# visualice the data
real_dataset = dataset.batch(batch_size).shuffle(10, seed=rand_seed)
for idx in range(1,5):
    elements = real_dataset.take(idx)
    for elem in elements:
        viz(elem['x_nodust'][idx], elem['y_norm'][idx], elem['y_revs'][idx], id=elem['ids'][idx])
# Out:
# #### **cartesian label:** [ 0.32824791 -0.93567687  0.12946857]
# #### **cartesian prediction (x_y):** [-0.32824791  0.93567687  0.12946857]
# #### **ID:** b'g1.92e12_x191_y196_z346'
# #### **cartesian label:** [ 0.69888396 -0.48242208  0.5280437 ]
# #### **cartesian prediction (x_y):** [-0.69888396  0.48242208  0.5280437 ]
# #### **ID:** b'g4.94e10_x95_y40_z353'
# #### **cartesian label:** [ 0.32748777 -0.90499277  0.27155083]
# #### **cartesian prediction (x_y):** [-0.32748777  0.90499277  0.27155083]
# #### **ID:** b'g2.57e11_x169_y353_z23'
# #### **cartesian label:** [ 0.529758   -0.33886048  0.7775153 ]
# #### **cartesian prediction (x_y):** [-0.529758    0.33886048  0.7775153 ]
# #### **ID:** b'g1.50e10_x295_y296_z33'
# #### **cartesian label:** [ 0.93311959 -0.07987218 -0.35058276]
# #### **cartesian prediction (x_y):** [-0.93311959  0.07987218 -0.35058276]
# #### **ID:** b'g4.99e09_x292_y197_z332'
# #### **cartesian label:** [ 0.7952049  -0.15544084  0.5860779 ]
# #### **cartesian prediction (x_y):** [-0.7952049   0.15544084  0.5860779 ]
# #### **ID:** b'g1.12e12_x324_y109_z175'
# #### **cartesian label:** [-0.23745501 -0.33004524 -0.91361111]
# #### **cartesian prediction (x_y):** [ 0.23745501  0.33004524 -0.91361111]
# #### **ID:** b'g3.67e09_x320_y258_z122'
# #### **cartesian label:** [-0.46789934 -0.02189159  0.88351059]
# #### **cartesian prediction (x_y):** [0.46789934 0.02189159 0.88351059]
# #### **ID:** b'g1.50e10_x158_y72_z172'
# #### **cartesian label:** [0.66018449 0.69187025 0.29235593]
# #### **cartesian prediction (x_y):** [0.66018449 0.69187025 0.29235593]
# #### **ID:** b'g1.95e10_x123_y47_z338'
# #### **cartesian label:** [-0.36234559 -0.68405446  0.63306806]
# #### **cartesian prediction (x_y):** [0.36234559 0.68405446 0.63306806]
# #### **ID:** b'g4.99e09_x62_y80_z230'

# %%
# defining the train and validation dataset from the existing dictionary, shufling and batching
ds_size = len(data_dict['y_revs'])

input_ds = (
    tf.data.Dataset.from_tensor_slices((data_dict['x_nodust'].astype(np.float32), data_dict['y_norm'][:,:2].astype(np.float32)))
                    # Use seed to ensure we always have the same validation data set!
                   .shuffle(ds_size, seed = rand_seed, reshuffle_each_iteration = False)
)

val_size = math.floor(ds_size * validation_ratio)
validation_ds = ( input_ds.take(val_size).batch(batch_size) )
train_ds = ( input_ds.skip(val_size).shuffle(buffer_size=buf_size, reshuffle_each_iteration=True).batch(batch_size) )

print(train_ds)
print(validation_ds)
# Out:
# <BatchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>

# %%
# %reload_ext tensorboard
# %tensorboard --logdir {log_dir} --reload_multifile True --host 0.0.0.0 --port 6006
# Out:
#       <iframe id="tensorboard-frame-69e44c057f056b62" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-69e44c057f056b62");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
# Build model
base_model = ResNet34(input_shape=(sizey,sizex,3), include_top=False)

# redefine the output to be 2 parameters from the last dense layer
x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tf.keras.layers.Dense(2, activation=None)(x)
model = tf.keras.models.Model(inputs=[base_model.input], outputs=[output])

# Use existing best weights if available...
snapshot_weights = 'models/best_weights_xy_custom_cosine.hdf5'
last_snapshot_weights = 'models/last_weights_xy_custom_cosine.hdf5'
if os.path.isfile(last_snapshot_weights):
    print('loaded weights')
    model.load_weights(last_snapshot_weights)
    
cossim = lambda y, p_y: -1*tf.keras.backend.abs(tf.keras.losses.cosine_similarity(y, p_y))
model.compile(optimizer='SGD', loss=cossim, metrics=[
                        tf.keras.metrics.mean_squared_error, 
                        tf.keras.metrics.mean_absolute_error, 
                        tf.keras.metrics.mean_absolute_percentage_error])
# Out:
# loaded weights

# %%
# model.summary()

# For tensorboard
log_dir_s = log_dir + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
os.makedirs(log_dir_s, exist_ok=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir_s, histogram_freq=1, update_freq='batch', profile_batch=0)

# Checkpointing
checkpointer_1 = tf.keras.callbacks.ModelCheckpoint(filepath=snapshot_weights,
                               monitor='mean_absolute_error',
                               verbose=1,
                               save_best_only=True)
checkpointer_2 = tf.keras.callbacks.ModelCheckpoint(filepath=last_snapshot_weights,
                               monitor='mean_absolute_error',
                               verbose=1,
                               save_best_only=False)

callbacks = [
    tensorboard_callback,
    checkpointer_1,
    checkpointer_2
]


model.fit(
    train_ds,
    validation_data = validation_ds,
    epochs = nb_epochs,
    callbacks = callbacks,)
    # class_weight=class_weight)
# Out:
# Epoch 1/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6749 - mean_squared_error: 0.6850 - mean_absolute_error: 0.6685 - mean_absolute_percentage_error: 471.9256
# Epoch 00001: mean_absolute_error improved from inf to 0.66852, saving model to models/best_weights_xy_custom_cosine.hdf5
#
# Epoch 00001: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 214s 8s/step - loss: -0.6749 - mean_squared_error: 0.6850 - mean_absolute_error: 0.6685 - mean_absolute_percentage_error: 471.9256 - val_loss: -0.7306 - val_mean_squared_error: 0.3260 - val_mean_absolute_error: 0.4733 - val_mean_absolute_percentage_error: 147.4046
# Epoch 2/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6713 - mean_squared_error: 0.7176 - mean_absolute_error: 0.6814 - mean_absolute_percentage_error: 485.7009
# Epoch 00002: mean_absolute_error did not improve from 0.66852
#
# Epoch 00002: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.6713 - mean_squared_error: 0.7176 - mean_absolute_error: 0.6814 - mean_absolute_percentage_error: 485.7009 - val_loss: -0.7024 - val_mean_squared_error: 0.3573 - val_mean_absolute_error: 0.4631 - val_mean_absolute_percentage_error: 159.6521
# Epoch 3/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6806 - mean_squared_error: 0.8252 - mean_absolute_error: 0.7229 - mean_absolute_percentage_error: 532.7166
# Epoch 00003: mean_absolute_error did not improve from 0.66852
#
# Epoch 00003: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.6806 - mean_squared_error: 0.8252 - mean_absolute_error: 0.7229 - mean_absolute_percentage_error: 532.7166 - val_loss: -0.7533 - val_mean_squared_error: 0.3736 - val_mean_absolute_error: 0.4666 - val_mean_absolute_percentage_error: 146.2465
# Epoch 4/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6988 - mean_squared_error: 0.6734 - mean_absolute_error: 0.6565 - mean_absolute_percentage_error: 450.5194
# Epoch 00004: mean_absolute_error improved from 0.66852 to 0.65653, saving model to models/best_weights_xy_custom_cosine.hdf5
#
# Epoch 00004: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.6988 - mean_squared_error: 0.6734 - mean_absolute_error: 0.6565 - mean_absolute_percentage_error: 450.5194 - val_loss: -0.7331 - val_mean_squared_error: 0.4548 - val_mean_absolute_error: 0.5032 - val_mean_absolute_percentage_error: 184.9604
# Epoch 5/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6844 - mean_squared_error: 0.7066 - mean_absolute_error: 0.6679 - mean_absolute_percentage_error: 381.0200
# Epoch 00005: mean_absolute_error did not improve from 0.65653
#
# Epoch 00005: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 210s 8s/step - loss: -0.6844 - mean_squared_error: 0.7066 - mean_absolute_error: 0.6679 - mean_absolute_percentage_error: 381.0200 - val_loss: -0.7531 - val_mean_squared_error: 0.3738 - val_mean_absolute_error: 0.4692 - val_mean_absolute_percentage_error: 143.7473
# Epoch 6/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7278 - mean_squared_error: 0.6451 - mean_absolute_error: 0.6386 - mean_absolute_percentage_error: 393.9430
# Epoch 00006: mean_absolute_error improved from 0.65653 to 0.63856, saving model to models/best_weights_xy_custom_cosine.hdf5
#
# Epoch 00006: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.7278 - mean_squared_error: 0.6451 - mean_absolute_error: 0.6386 - mean_absolute_percentage_error: 393.9430 - val_loss: -0.6782 - val_mean_squared_error: 0.3889 - val_mean_absolute_error: 0.5076 - val_mean_absolute_percentage_error: 163.0313
# Epoch 7/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7091 - mean_squared_error: 0.9933 - mean_absolute_error: 0.7531 - mean_absolute_percentage_error: 425.2967
# Epoch 00007: mean_absolute_error did not improve from 0.63856
#
# Epoch 00007: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 213s 8s/step - loss: -0.7091 - mean_squared_error: 0.9933 - mean_absolute_error: 0.7531 - mean_absolute_percentage_error: 425.2967 - val_loss: -0.7213 - val_mean_squared_error: 0.8016 - val_mean_absolute_error: 0.7129 - val_mean_absolute_percentage_error: 336.6117
# Epoch 8/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6918 - mean_squared_error: 1.3855 - mean_absolute_error: 0.8755 - mean_absolute_percentage_error: 555.0178
# Epoch 00008: mean_absolute_error did not improve from 0.63856
#
# Epoch 00008: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.6918 - mean_squared_error: 1.3855 - mean_absolute_error: 0.8755 - mean_absolute_percentage_error: 555.0178 - val_loss: -0.7593 - val_mean_squared_error: 1.1253 - val_mean_absolute_error: 0.8290 - val_mean_absolute_percentage_error: 311.7584
# Epoch 9/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6705 - mean_squared_error: 1.6553 - mean_absolute_error: 0.9624 - mean_absolute_percentage_error: 642.2009
# Epoch 00009: mean_absolute_error did not improve from 0.63856
#
# Epoch 00009: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.6705 - mean_squared_error: 1.6553 - mean_absolute_error: 0.9624 - mean_absolute_percentage_error: 642.2009 - val_loss: -0.7128 - val_mean_squared_error: 1.4083 - val_mean_absolute_error: 0.9650 - val_mean_absolute_percentage_error: 428.6454
# Epoch 10/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6839 - mean_squared_error: 2.0729 - mean_absolute_error: 1.0775 - mean_absolute_percentage_error: 698.8305
# Epoch 00010: mean_absolute_error did not improve from 0.63856
#
# Epoch 00010: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.6839 - mean_squared_error: 2.0729 - mean_absolute_error: 1.0775 - mean_absolute_percentage_error: 698.8305 - val_loss: -0.7552 - val_mean_squared_error: 1.7796 - val_mean_absolute_error: 1.0592 - val_mean_absolute_percentage_error: 383.0522
# Epoch 11/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6991 - mean_squared_error: 1.6442 - mean_absolute_error: 0.9607 - mean_absolute_percentage_error: 619.4353
# Epoch 00011: mean_absolute_error did not improve from 0.63856
#
# Epoch 00011: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.6991 - mean_squared_error: 1.6442 - mean_absolute_error: 0.9607 - mean_absolute_percentage_error: 619.4353 - val_loss: -0.6403 - val_mean_squared_error: 0.6983 - val_mean_absolute_error: 0.6482 - val_mean_absolute_percentage_error: 331.4459
# Epoch 12/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7195 - mean_squared_error: 1.0312 - mean_absolute_error: 0.7954 - mean_absolute_percentage_error: 522.1526
# Epoch 00012: mean_absolute_error did not improve from 0.63856
#
# Epoch 00012: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7195 - mean_squared_error: 1.0312 - mean_absolute_error: 0.7954 - mean_absolute_percentage_error: 522.1526 - val_loss: -0.6946 - val_mean_squared_error: 0.5819 - val_mean_absolute_error: 0.5627 - val_mean_absolute_percentage_error: 218.5024
# Epoch 13/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7274 - mean_squared_error: 1.1046 - mean_absolute_error: 0.8172 - mean_absolute_percentage_error: 440.6835
# Epoch 00013: mean_absolute_error did not improve from 0.63856
#
# Epoch 00013: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.7274 - mean_squared_error: 1.1046 - mean_absolute_error: 0.8172 - mean_absolute_percentage_error: 440.6835 - val_loss: -0.5951 - val_mean_squared_error: 0.7890 - val_mean_absolute_error: 0.7268 - val_mean_absolute_percentage_error: 381.6831
# Epoch 14/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7293 - mean_squared_error: 1.2737 - mean_absolute_error: 0.8726 - mean_absolute_percentage_error: 495.4135
# Epoch 00014: mean_absolute_error did not improve from 0.63856
#
# Epoch 00014: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7293 - mean_squared_error: 1.2737 - mean_absolute_error: 0.8726 - mean_absolute_percentage_error: 495.4135 - val_loss: -0.7323 - val_mean_squared_error: 0.6184 - val_mean_absolute_error: 0.5641 - val_mean_absolute_percentage_error: 230.2348
# Epoch 15/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7362 - mean_squared_error: 1.2961 - mean_absolute_error: 0.8784 - mean_absolute_percentage_error: 562.1244
# Epoch 00015: mean_absolute_error did not improve from 0.63856
#
# Epoch 00015: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7362 - mean_squared_error: 1.2961 - mean_absolute_error: 0.8784 - mean_absolute_percentage_error: 562.1244 - val_loss: -0.6973 - val_mean_squared_error: 1.1653 - val_mean_absolute_error: 0.8251 - val_mean_absolute_percentage_error: 433.5143
# Epoch 16/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7105 - mean_squared_error: 1.6262 - mean_absolute_error: 0.9795 - mean_absolute_percentage_error: 673.8205
# Epoch 00016: mean_absolute_error did not improve from 0.63856
#
# Epoch 00016: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 213s 8s/step - loss: -0.7105 - mean_squared_error: 1.6262 - mean_absolute_error: 0.9795 - mean_absolute_percentage_error: 673.8205 - val_loss: -0.7592 - val_mean_squared_error: 2.5159 - val_mean_absolute_error: 1.1582 - val_mean_absolute_percentage_error: 443.2276
# Epoch 17/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7107 - mean_squared_error: 2.0666 - mean_absolute_error: 1.0929 - mean_absolute_percentage_error: 865.3334
# Epoch 00017: mean_absolute_error did not improve from 0.63856
#
# Epoch 00017: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.7107 - mean_squared_error: 2.0666 - mean_absolute_error: 1.0929 - mean_absolute_percentage_error: 865.3334 - val_loss: -0.7238 - val_mean_squared_error: 1.9739 - val_mean_absolute_error: 1.0709 - val_mean_absolute_percentage_error: 458.3469
# Epoch 18/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7490 - mean_squared_error: 1.5886 - mean_absolute_error: 0.9582 - mean_absolute_percentage_error: 672.4865
# Epoch 00018: mean_absolute_error did not improve from 0.63856
#
# Epoch 00018: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.7490 - mean_squared_error: 1.5886 - mean_absolute_error: 0.9582 - mean_absolute_percentage_error: 672.4865 - val_loss: -0.5974 - val_mean_squared_error: 5.1826 - val_mean_absolute_error: 1.2724 - val_mean_absolute_percentage_error: 678.4091
# Epoch 19/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7518 - mean_squared_error: 1.5339 - mean_absolute_error: 0.9372 - mean_absolute_percentage_error: 579.1834
# Epoch 00019: mean_absolute_error did not improve from 0.63856
#
# Epoch 00019: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 213s 8s/step - loss: -0.7518 - mean_squared_error: 1.5339 - mean_absolute_error: 0.9372 - mean_absolute_percentage_error: 579.1834 - val_loss: -0.6956 - val_mean_squared_error: 3.5446 - val_mean_absolute_error: 1.1195 - val_mean_absolute_percentage_error: 517.7190
# Epoch 20/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7649 - mean_squared_error: 1.4004 - mean_absolute_error: 0.9062 - mean_absolute_percentage_error: 536.4226
# Epoch 00020: mean_absolute_error did not improve from 0.63856
#
# Epoch 00020: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 213s 8s/step - loss: -0.7649 - mean_squared_error: 1.4004 - mean_absolute_error: 0.9062 - mean_absolute_percentage_error: 536.4226 - val_loss: -0.7448 - val_mean_squared_error: 1.9990 - val_mean_absolute_error: 1.0480 - val_mean_absolute_percentage_error: 460.0266
# Epoch 21/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7465 - mean_squared_error: 1.2563 - mean_absolute_error: 0.8704 - mean_absolute_percentage_error: 482.5770
# Epoch 00021: mean_absolute_error did not improve from 0.63856
#
# Epoch 00021: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7465 - mean_squared_error: 1.2563 - mean_absolute_error: 0.8704 - mean_absolute_percentage_error: 482.5770 - val_loss: -0.7030 - val_mean_squared_error: 1.4232 - val_mean_absolute_error: 0.9717 - val_mean_absolute_percentage_error: 464.9445
# Epoch 22/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7435 - mean_squared_error: 1.2977 - mean_absolute_error: 0.8923 - mean_absolute_percentage_error: 582.6134
# Epoch 00022: mean_absolute_error did not improve from 0.63856
#
# Epoch 00022: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7435 - mean_squared_error: 1.2977 - mean_absolute_error: 0.8923 - mean_absolute_percentage_error: 582.6134 - val_loss: -0.7283 - val_mean_squared_error: 1.2840 - val_mean_absolute_error: 0.8069 - val_mean_absolute_percentage_error: 356.7821
# Epoch 23/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7618 - mean_squared_error: 1.1579 - mean_absolute_error: 0.8335 - mean_absolute_percentage_error: 436.7659
# Epoch 00023: mean_absolute_error did not improve from 0.63856
#
# Epoch 00023: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 233s 9s/step - loss: -0.7618 - mean_squared_error: 1.1579 - mean_absolute_error: 0.8335 - mean_absolute_percentage_error: 436.7659 - val_loss: -0.7316 - val_mean_squared_error: 1.5660 - val_mean_absolute_error: 0.8529 - val_mean_absolute_percentage_error: 334.4111
# Epoch 24/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7698 - mean_squared_error: 1.2082 - mean_absolute_error: 0.8560 - mean_absolute_percentage_error: 532.1773
# Epoch 00024: mean_absolute_error did not improve from 0.63856
#
# Epoch 00024: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7698 - mean_squared_error: 1.2082 - mean_absolute_error: 0.8560 - mean_absolute_percentage_error: 532.1773 - val_loss: -0.7525 - val_mean_squared_error: 1.2816 - val_mean_absolute_error: 0.7887 - val_mean_absolute_percentage_error: 306.3828
# Epoch 25/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6897 - mean_squared_error: 1.7907 - mean_absolute_error: 1.0729 - mean_absolute_percentage_error: 794.2650
# Epoch 00025: mean_absolute_error did not improve from 0.63856
#
# Epoch 00025: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.6897 - mean_squared_error: 1.7907 - mean_absolute_error: 1.0729 - mean_absolute_percentage_error: 794.2650 - val_loss: -0.5518 - val_mean_squared_error: 27.6548 - val_mean_absolute_error: 2.4558 - val_mean_absolute_percentage_error: 1405.1995
# Epoch 26/100
# 26/26 [==============================] - ETA: 0s - loss: -0.6842 - mean_squared_error: 2.6460 - mean_absolute_error: 1.3051 - mean_absolute_percentage_error: 1006.7843
# Epoch 00026: mean_absolute_error did not improve from 0.63856
#
# Epoch 00026: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 213s 8s/step - loss: -0.6842 - mean_squared_error: 2.6460 - mean_absolute_error: 1.3051 - mean_absolute_percentage_error: 1006.7843 - val_loss: -0.6581 - val_mean_squared_error: 5.5145 - val_mean_absolute_error: 1.4013 - val_mean_absolute_percentage_error: 666.3749
# Epoch 27/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7148 - mean_squared_error: 2.1228 - mean_absolute_error: 1.1743 - mean_absolute_percentage_error: 873.3552
# Epoch 00027: mean_absolute_error did not improve from 0.63856
#
# Epoch 00027: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7148 - mean_squared_error: 2.1228 - mean_absolute_error: 1.1743 - mean_absolute_percentage_error: 873.3552 - val_loss: -0.6433 - val_mean_squared_error: 3.2963 - val_mean_absolute_error: 1.1670 - val_mean_absolute_percentage_error: 570.7042
# Epoch 28/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7490 - mean_squared_error: 1.7460 - mean_absolute_error: 1.0393 - mean_absolute_percentage_error: 642.8110
# Epoch 00028: mean_absolute_error did not improve from 0.63856
#
# Epoch 00028: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.7490 - mean_squared_error: 1.7460 - mean_absolute_error: 1.0393 - mean_absolute_percentage_error: 642.8110 - val_loss: -0.6784 - val_mean_squared_error: 2.5208 - val_mean_absolute_error: 1.2223 - val_mean_absolute_percentage_error: 511.3139
# Epoch 29/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7687 - mean_squared_error: 1.6377 - mean_absolute_error: 0.9896 - mean_absolute_percentage_error: 591.2104
# Epoch 00029: mean_absolute_error did not improve from 0.63856
#
# Epoch 00029: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7687 - mean_squared_error: 1.6377 - mean_absolute_error: 0.9896 - mean_absolute_percentage_error: 591.2104 - val_loss: -0.6492 - val_mean_squared_error: 1.5942 - val_mean_absolute_error: 1.0580 - val_mean_absolute_percentage_error: 508.4485
# Epoch 30/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7776 - mean_squared_error: 1.5557 - mean_absolute_error: 0.9461 - mean_absolute_percentage_error: 538.2751
# Epoch 00030: mean_absolute_error did not improve from 0.63856
#
# Epoch 00030: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7776 - mean_squared_error: 1.5557 - mean_absolute_error: 0.9461 - mean_absolute_percentage_error: 538.2751 - val_loss: -0.6611 - val_mean_squared_error: 85.6293 - val_mean_absolute_error: 5.5155 - val_mean_absolute_percentage_error: 2176.4490
# Epoch 31/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7338 - mean_squared_error: 1.4624 - mean_absolute_error: 0.9400 - mean_absolute_percentage_error: 694.9365
# Epoch 00031: mean_absolute_error did not improve from 0.63856
#
# Epoch 00031: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7338 - mean_squared_error: 1.4624 - mean_absolute_error: 0.9400 - mean_absolute_percentage_error: 694.9365 - val_loss: -0.6226 - val_mean_squared_error: 23.9637 - val_mean_absolute_error: 3.0615 - val_mean_absolute_percentage_error: 1496.9667
# Epoch 32/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7454 - mean_squared_error: 2.0852 - mean_absolute_error: 1.0669 - mean_absolute_percentage_error: 720.9283
# Epoch 00032: mean_absolute_error did not improve from 0.63856
#
# Epoch 00032: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7454 - mean_squared_error: 2.0852 - mean_absolute_error: 1.0669 - mean_absolute_percentage_error: 720.9283 - val_loss: -0.6501 - val_mean_squared_error: 9.8454 - val_mean_absolute_error: 2.0935 - val_mean_absolute_percentage_error: 879.5256
# Epoch 33/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7729 - mean_squared_error: 1.9697 - mean_absolute_error: 1.0400 - mean_absolute_percentage_error: 636.6979
# Epoch 00033: mean_absolute_error did not improve from 0.63856
#
# Epoch 00033: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7729 - mean_squared_error: 1.9697 - mean_absolute_error: 1.0400 - mean_absolute_percentage_error: 636.6979 - val_loss: -0.5827 - val_mean_squared_error: 18.2979 - val_mean_absolute_error: 2.5626 - val_mean_absolute_percentage_error: 1365.9884
# Epoch 34/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7731 - mean_squared_error: 1.7431 - mean_absolute_error: 1.0143 - mean_absolute_percentage_error: 610.5936
# Epoch 00034: mean_absolute_error did not improve from 0.63856
#
# Epoch 00034: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.7731 - mean_squared_error: 1.7431 - mean_absolute_error: 1.0143 - mean_absolute_percentage_error: 610.5936 - val_loss: -0.6429 - val_mean_squared_error: 1.4672 - val_mean_absolute_error: 0.8971 - val_mean_absolute_percentage_error: 408.0990
# Epoch 35/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7649 - mean_squared_error: 1.8404 - mean_absolute_error: 1.0253 - mean_absolute_percentage_error: 685.2009
# Epoch 00035: mean_absolute_error did not improve from 0.63856
#
# Epoch 00035: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7649 - mean_squared_error: 1.8404 - mean_absolute_error: 1.0253 - mean_absolute_percentage_error: 685.2009 - val_loss: -0.7517 - val_mean_squared_error: 28.5167 - val_mean_absolute_error: 2.9371 - val_mean_absolute_percentage_error: 883.0054
# Epoch 36/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7738 - mean_squared_error: 2.1561 - mean_absolute_error: 1.1047 - mean_absolute_percentage_error: 710.0379
# Epoch 00036: mean_absolute_error did not improve from 0.63856
#
# Epoch 00036: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 212s 8s/step - loss: -0.7738 - mean_squared_error: 2.1561 - mean_absolute_error: 1.1047 - mean_absolute_percentage_error: 710.0379 - val_loss: -0.7668 - val_mean_squared_error: 0.7278 - val_mean_absolute_error: 0.6325 - val_mean_absolute_percentage_error: 216.3950
# Epoch 37/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7864 - mean_squared_error: 1.9161 - mean_absolute_error: 1.0417 - mean_absolute_percentage_error: 691.4268
# Epoch 00037: mean_absolute_error did not improve from 0.63856
#
# Epoch 00037: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7864 - mean_squared_error: 1.9161 - mean_absolute_error: 1.0417 - mean_absolute_percentage_error: 691.4268 - val_loss: -0.7045 - val_mean_squared_error: 13.2162 - val_mean_absolute_error: 2.3717 - val_mean_absolute_percentage_error: 1012.4624
# Epoch 38/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7849 - mean_squared_error: 1.9119 - mean_absolute_error: 1.0451 - mean_absolute_percentage_error: 490.4299
# Epoch 00038: mean_absolute_error did not improve from 0.63856
#
# Epoch 00038: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7849 - mean_squared_error: 1.9119 - mean_absolute_error: 1.0451 - mean_absolute_percentage_error: 490.4299 - val_loss: -0.6676 - val_mean_squared_error: 5.3581 - val_mean_absolute_error: 1.5176 - val_mean_absolute_percentage_error: 735.2911
# Epoch 39/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7861 - mean_squared_error: 1.8310 - mean_absolute_error: 1.0225 - mean_absolute_percentage_error: 591.2023
# Epoch 00039: mean_absolute_error did not improve from 0.63856
#
# Epoch 00039: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 211s 8s/step - loss: -0.7861 - mean_squared_error: 1.8310 - mean_absolute_error: 1.0225 - mean_absolute_percentage_error: 591.2023 - val_loss: -0.6923 - val_mean_squared_error: 3.0950 - val_mean_absolute_error: 1.1590 - val_mean_absolute_percentage_error: 500.7606
# Epoch 40/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7916 - mean_squared_error: 1.8344 - mean_absolute_error: 1.0114 - mean_absolute_percentage_error: 537.4426
# Epoch 00040: mean_absolute_error did not improve from 0.63856
#
# Epoch 00040: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 210s 8s/step - loss: -0.7916 - mean_squared_error: 1.8344 - mean_absolute_error: 1.0114 - mean_absolute_percentage_error: 537.4426 - val_loss: -0.6724 - val_mean_squared_error: 2.8976 - val_mean_absolute_error: 1.1736 - val_mean_absolute_percentage_error: 523.5584
# Epoch 41/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7918 - mean_squared_error: 1.8413 - mean_absolute_error: 0.9994 - mean_absolute_percentage_error: 482.6140
# Epoch 00041: mean_absolute_error did not improve from 0.63856
#
# Epoch 00041: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 210s 8s/step - loss: -0.7918 - mean_squared_error: 1.8413 - mean_absolute_error: 0.9994 - mean_absolute_percentage_error: 482.6140 - val_loss: -0.6922 - val_mean_squared_error: 2.8535 - val_mean_absolute_error: 1.1653 - val_mean_absolute_percentage_error: 524.0696
# Epoch 42/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8061 - mean_squared_error: 1.8125 - mean_absolute_error: 0.9943 - mean_absolute_percentage_error: 528.7839
# Epoch 00042: mean_absolute_error did not improve from 0.63856
#
# Epoch 00042: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 210s 8s/step - loss: -0.8061 - mean_squared_error: 1.8125 - mean_absolute_error: 0.9943 - mean_absolute_percentage_error: 528.7839 - val_loss: -0.6925 - val_mean_squared_error: 2.3998 - val_mean_absolute_error: 1.0800 - val_mean_absolute_percentage_error: 467.1196
# Epoch 43/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8081 - mean_squared_error: 1.9499 - mean_absolute_error: 1.0198 - mean_absolute_percentage_error: 536.5840
# Epoch 00043: mean_absolute_error did not improve from 0.63856
#
# Epoch 00043: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8081 - mean_squared_error: 1.9499 - mean_absolute_error: 1.0198 - mean_absolute_percentage_error: 536.5840 - val_loss: -0.7278 - val_mean_squared_error: 2.2851 - val_mean_absolute_error: 1.0705 - val_mean_absolute_percentage_error: 399.7013
# Epoch 44/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8002 - mean_squared_error: 1.9743 - mean_absolute_error: 1.0299 - mean_absolute_percentage_error: 534.5662
# Epoch 00044: mean_absolute_error did not improve from 0.63856
#
# Epoch 00044: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8002 - mean_squared_error: 1.9743 - mean_absolute_error: 1.0299 - mean_absolute_percentage_error: 534.5662 - val_loss: -0.7068 - val_mean_squared_error: 2.3891 - val_mean_absolute_error: 1.1117 - val_mean_absolute_percentage_error: 445.5406
# Epoch 45/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7769 - mean_squared_error: 2.1242 - mean_absolute_error: 1.1083 - mean_absolute_percentage_error: 692.9102
# Epoch 00045: mean_absolute_error did not improve from 0.63856
#
# Epoch 00045: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7769 - mean_squared_error: 2.1242 - mean_absolute_error: 1.1083 - mean_absolute_percentage_error: 692.9102 - val_loss: -0.6501 - val_mean_squared_error: 885.2410 - val_mean_absolute_error: 21.4595 - val_mean_absolute_percentage_error: 10011.9912
# Epoch 46/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7587 - mean_squared_error: 2.6021 - mean_absolute_error: 1.2625 - mean_absolute_percentage_error: 810.0997
# Epoch 00046: mean_absolute_error did not improve from 0.63856
#
# Epoch 00046: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7587 - mean_squared_error: 2.6021 - mean_absolute_error: 1.2625 - mean_absolute_percentage_error: 810.0997 - val_loss: -0.7442 - val_mean_squared_error: 28.9212 - val_mean_absolute_error: 3.3563 - val_mean_absolute_percentage_error: 1198.9299
# Epoch 47/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7864 - mean_squared_error: 2.5803 - mean_absolute_error: 1.2025 - mean_absolute_percentage_error: 742.1981
# Epoch 00047: mean_absolute_error did not improve from 0.63856
#
# Epoch 00047: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7864 - mean_squared_error: 2.5803 - mean_absolute_error: 1.2025 - mean_absolute_percentage_error: 742.1981 - val_loss: -0.7221 - val_mean_squared_error: 14.1101 - val_mean_absolute_error: 2.3764 - val_mean_absolute_percentage_error: 826.8046
# Epoch 48/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7902 - mean_squared_error: 2.6814 - mean_absolute_error: 1.2042 - mean_absolute_percentage_error: 654.9625
# Epoch 00048: mean_absolute_error did not improve from 0.63856
#
# Epoch 00048: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7902 - mean_squared_error: 2.6814 - mean_absolute_error: 1.2042 - mean_absolute_percentage_error: 654.9625 - val_loss: -0.7055 - val_mean_squared_error: 5.1049 - val_mean_absolute_error: 1.5601 - val_mean_absolute_percentage_error: 610.3678
# Epoch 49/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7874 - mean_squared_error: 2.7134 - mean_absolute_error: 1.1851 - mean_absolute_percentage_error: 636.4885
# Epoch 00049: mean_absolute_error did not improve from 0.63856
#
# Epoch 00049: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7874 - mean_squared_error: 2.7134 - mean_absolute_error: 1.1851 - mean_absolute_percentage_error: 636.4885 - val_loss: -0.6393 - val_mean_squared_error: 21.1850 - val_mean_absolute_error: 2.8362 - val_mean_absolute_percentage_error: 1314.6792
# Epoch 50/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7898 - mean_squared_error: 3.0725 - mean_absolute_error: 1.2610 - mean_absolute_percentage_error: 591.2291
# Epoch 00050: mean_absolute_error did not improve from 0.63856
#
# Epoch 00050: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 210s 8s/step - loss: -0.7898 - mean_squared_error: 3.0725 - mean_absolute_error: 1.2610 - mean_absolute_percentage_error: 591.2291 - val_loss: -0.7078 - val_mean_squared_error: 11.4395 - val_mean_absolute_error: 1.7969 - val_mean_absolute_percentage_error: 800.7684
# Epoch 51/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7866 - mean_squared_error: 2.8605 - mean_absolute_error: 1.2066 - mean_absolute_percentage_error: 645.7748
# Epoch 00051: mean_absolute_error did not improve from 0.63856
#
# Epoch 00051: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 210s 8s/step - loss: -0.7866 - mean_squared_error: 2.8605 - mean_absolute_error: 1.2066 - mean_absolute_percentage_error: 645.7748 - val_loss: -0.7661 - val_mean_squared_error: 2.2380 - val_mean_absolute_error: 0.9885 - val_mean_absolute_percentage_error: 341.5197
# Epoch 52/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7892 - mean_squared_error: 2.9485 - mean_absolute_error: 1.2220 - mean_absolute_percentage_error: 602.5281
# Epoch 00052: mean_absolute_error did not improve from 0.63856
#
# Epoch 00052: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7892 - mean_squared_error: 2.9485 - mean_absolute_error: 1.2220 - mean_absolute_percentage_error: 602.5281 - val_loss: -0.6013 - val_mean_squared_error: 14.0587 - val_mean_absolute_error: 2.3200 - val_mean_absolute_percentage_error: 1060.0724
# Epoch 53/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7770 - mean_squared_error: 2.5865 - mean_absolute_error: 1.1730 - mean_absolute_percentage_error: 677.2585
# Epoch 00053: mean_absolute_error did not improve from 0.63856
#
# Epoch 00053: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 210s 8s/step - loss: -0.7770 - mean_squared_error: 2.5865 - mean_absolute_error: 1.1730 - mean_absolute_percentage_error: 677.2585 - val_loss: -0.7300 - val_mean_squared_error: 5.0778 - val_mean_absolute_error: 1.4458 - val_mean_absolute_percentage_error: 542.1273
# Epoch 54/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7892 - mean_squared_error: 2.5733 - mean_absolute_error: 1.1502 - mean_absolute_percentage_error: 638.2692
# Epoch 00054: mean_absolute_error did not improve from 0.63856
#
# Epoch 00054: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7892 - mean_squared_error: 2.5733 - mean_absolute_error: 1.1502 - mean_absolute_percentage_error: 638.2692 - val_loss: -0.7173 - val_mean_squared_error: 1.7923 - val_mean_absolute_error: 0.9455 - val_mean_absolute_percentage_error: 396.1722
# Epoch 55/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7939 - mean_squared_error: 2.9393 - mean_absolute_error: 1.2233 - mean_absolute_percentage_error: 588.0021
# Epoch 00055: mean_absolute_error did not improve from 0.63856
#
# Epoch 00055: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7939 - mean_squared_error: 2.9393 - mean_absolute_error: 1.2233 - mean_absolute_percentage_error: 588.0021 - val_loss: -0.7202 - val_mean_squared_error: 1.0717 - val_mean_absolute_error: 0.7356 - val_mean_absolute_percentage_error: 265.1238
# Epoch 56/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8042 - mean_squared_error: 2.8550 - mean_absolute_error: 1.1921 - mean_absolute_percentage_error: 611.6724
# Epoch 00056: mean_absolute_error did not improve from 0.63856
#
# Epoch 00056: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8042 - mean_squared_error: 2.8550 - mean_absolute_error: 1.1921 - mean_absolute_percentage_error: 611.6724 - val_loss: -0.7405 - val_mean_squared_error: 4.7740 - val_mean_absolute_error: 1.4658 - val_mean_absolute_percentage_error: 542.3692
# Epoch 57/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7869 - mean_squared_error: 3.0624 - mean_absolute_error: 1.2350 - mean_absolute_percentage_error: 607.3203
# Epoch 00057: mean_absolute_error did not improve from 0.63856
#
# Epoch 00057: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7869 - mean_squared_error: 3.0624 - mean_absolute_error: 1.2350 - mean_absolute_percentage_error: 607.3203 - val_loss: -0.6998 - val_mean_squared_error: 3.5422 - val_mean_absolute_error: 1.2607 - val_mean_absolute_percentage_error: 519.1559
# Epoch 58/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7874 - mean_squared_error: 2.7417 - mean_absolute_error: 1.1830 - mean_absolute_percentage_error: 608.7480
# Epoch 00058: mean_absolute_error did not improve from 0.63856
#
# Epoch 00058: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7874 - mean_squared_error: 2.7417 - mean_absolute_error: 1.1830 - mean_absolute_percentage_error: 608.7480 - val_loss: -0.5507 - val_mean_squared_error: 5.9585 - val_mean_absolute_error: 1.4290 - val_mean_absolute_percentage_error: 723.4573
# Epoch 59/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7722 - mean_squared_error: 2.5244 - mean_absolute_error: 1.1758 - mean_absolute_percentage_error: 718.6144
# Epoch 00059: mean_absolute_error did not improve from 0.63856
#
# Epoch 00059: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7722 - mean_squared_error: 2.5244 - mean_absolute_error: 1.1758 - mean_absolute_percentage_error: 718.6144 - val_loss: -0.6435 - val_mean_squared_error: 1.2721 - val_mean_absolute_error: 0.8449 - val_mean_absolute_percentage_error: 368.5625
# Epoch 60/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7885 - mean_squared_error: 2.2675 - mean_absolute_error: 1.0911 - mean_absolute_percentage_error: 595.5317
# Epoch 00060: mean_absolute_error did not improve from 0.63856
#
# Epoch 00060: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.7885 - mean_squared_error: 2.2675 - mean_absolute_error: 1.0911 - mean_absolute_percentage_error: 595.5317 - val_loss: -0.7141 - val_mean_squared_error: 1.4949 - val_mean_absolute_error: 0.8742 - val_mean_absolute_percentage_error: 388.9327
# Epoch 61/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7876 - mean_squared_error: 2.5650 - mean_absolute_error: 1.1320 - mean_absolute_percentage_error: 611.6806
# Epoch 00061: mean_absolute_error did not improve from 0.63856
#
# Epoch 00061: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7876 - mean_squared_error: 2.5650 - mean_absolute_error: 1.1320 - mean_absolute_percentage_error: 611.6806 - val_loss: -0.6977 - val_mean_squared_error: 1.3676 - val_mean_absolute_error: 0.8288 - val_mean_absolute_percentage_error: 370.8769
# Epoch 62/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7837 - mean_squared_error: 2.7786 - mean_absolute_error: 1.1952 - mean_absolute_percentage_error: 652.0917
# Epoch 00062: mean_absolute_error did not improve from 0.63856
#
# Epoch 00062: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.7837 - mean_squared_error: 2.7786 - mean_absolute_error: 1.1952 - mean_absolute_percentage_error: 652.0917 - val_loss: -0.6792 - val_mean_squared_error: 4.6429 - val_mean_absolute_error: 1.3320 - val_mean_absolute_percentage_error: 614.2052
# Epoch 63/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8014 - mean_squared_error: 2.6339 - mean_absolute_error: 1.1417 - mean_absolute_percentage_error: 536.8961
# Epoch 00063: mean_absolute_error did not improve from 0.63856
#
# Epoch 00063: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.8014 - mean_squared_error: 2.6339 - mean_absolute_error: 1.1417 - mean_absolute_percentage_error: 536.8961 - val_loss: -0.7141 - val_mean_squared_error: 9.0386 - val_mean_absolute_error: 1.8197 - val_mean_absolute_percentage_error: 639.4298
# Epoch 64/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7996 - mean_squared_error: 2.5653 - mean_absolute_error: 1.1444 - mean_absolute_percentage_error: 579.2984
# Epoch 00064: mean_absolute_error did not improve from 0.63856
#
# Epoch 00064: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.7996 - mean_squared_error: 2.5653 - mean_absolute_error: 1.1444 - mean_absolute_percentage_error: 579.2984 - val_loss: -0.7181 - val_mean_squared_error: 4.6025 - val_mean_absolute_error: 1.4775 - val_mean_absolute_percentage_error: 539.6729
# Epoch 65/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7931 - mean_squared_error: 2.7377 - mean_absolute_error: 1.1940 - mean_absolute_percentage_error: 572.7065
# Epoch 00065: mean_absolute_error did not improve from 0.63856
#
# Epoch 00065: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7931 - mean_squared_error: 2.7377 - mean_absolute_error: 1.1940 - mean_absolute_percentage_error: 572.7065 - val_loss: -0.6533 - val_mean_squared_error: 6.2177 - val_mean_absolute_error: 1.6847 - val_mean_absolute_percentage_error: 783.6901
# Epoch 66/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8092 - mean_squared_error: 2.8307 - mean_absolute_error: 1.1981 - mean_absolute_percentage_error: 609.8823
# Epoch 00066: mean_absolute_error did not improve from 0.63856
#
# Epoch 00066: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8092 - mean_squared_error: 2.8307 - mean_absolute_error: 1.1981 - mean_absolute_percentage_error: 609.8823 - val_loss: -0.6928 - val_mean_squared_error: 4.7810 - val_mean_absolute_error: 1.5238 - val_mean_absolute_percentage_error: 627.7935
# Epoch 67/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8087 - mean_squared_error: 2.7440 - mean_absolute_error: 1.1964 - mean_absolute_percentage_error: 586.1577
# Epoch 00067: mean_absolute_error did not improve from 0.63856
#
# Epoch 00067: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8087 - mean_squared_error: 2.7440 - mean_absolute_error: 1.1964 - mean_absolute_percentage_error: 586.1577 - val_loss: -0.7357 - val_mean_squared_error: 3.7217 - val_mean_absolute_error: 1.2731 - val_mean_absolute_percentage_error: 436.4265
# Epoch 68/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8107 - mean_squared_error: 2.4686 - mean_absolute_error: 1.1541 - mean_absolute_percentage_error: 620.3915
# Epoch 00068: mean_absolute_error did not improve from 0.63856
#
# Epoch 00068: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8107 - mean_squared_error: 2.4686 - mean_absolute_error: 1.1541 - mean_absolute_percentage_error: 620.3915 - val_loss: -0.7047 - val_mean_squared_error: 0.6059 - val_mean_absolute_error: 0.6141 - val_mean_absolute_percentage_error: 249.9013
# Epoch 69/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8151 - mean_squared_error: 2.6805 - mean_absolute_error: 1.2128 - mean_absolute_percentage_error: 580.4869
# Epoch 00069: mean_absolute_error did not improve from 0.63856
#
# Epoch 00069: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8151 - mean_squared_error: 2.6805 - mean_absolute_error: 1.2128 - mean_absolute_percentage_error: 580.4869 - val_loss: -0.7217 - val_mean_squared_error: 2.1136 - val_mean_absolute_error: 1.0331 - val_mean_absolute_percentage_error: 403.0454
# Epoch 70/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8059 - mean_squared_error: 2.8756 - mean_absolute_error: 1.2786 - mean_absolute_percentage_error: 722.0398
# Epoch 00070: mean_absolute_error did not improve from 0.63856
#
# Epoch 00070: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8059 - mean_squared_error: 2.8756 - mean_absolute_error: 1.2786 - mean_absolute_percentage_error: 722.0398 - val_loss: -0.7456 - val_mean_squared_error: 4.1053 - val_mean_absolute_error: 1.3485 - val_mean_absolute_percentage_error: 424.4371
# Epoch 71/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8159 - mean_squared_error: 2.7134 - mean_absolute_error: 1.2345 - mean_absolute_percentage_error: 630.8675
# Epoch 00071: mean_absolute_error did not improve from 0.63856
#
# Epoch 00071: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8159 - mean_squared_error: 2.7134 - mean_absolute_error: 1.2345 - mean_absolute_percentage_error: 630.8675 - val_loss: -0.7199 - val_mean_squared_error: 1.3586 - val_mean_absolute_error: 0.8848 - val_mean_absolute_percentage_error: 341.0952
# Epoch 72/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8111 - mean_squared_error: 2.7107 - mean_absolute_error: 1.2280 - mean_absolute_percentage_error: 628.2939
# Epoch 00072: mean_absolute_error did not improve from 0.63856
#
# Epoch 00072: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.8111 - mean_squared_error: 2.7107 - mean_absolute_error: 1.2280 - mean_absolute_percentage_error: 628.2939 - val_loss: -0.6815 - val_mean_squared_error: 0.5949 - val_mean_absolute_error: 0.6191 - val_mean_absolute_percentage_error: 264.4409
# Epoch 73/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8106 - mean_squared_error: 2.6154 - mean_absolute_error: 1.1972 - mean_absolute_percentage_error: 637.0165
# Epoch 00073: mean_absolute_error did not improve from 0.63856
#
# Epoch 00073: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.8106 - mean_squared_error: 2.6154 - mean_absolute_error: 1.1972 - mean_absolute_percentage_error: 637.0165 - val_loss: -0.6885 - val_mean_squared_error: 0.6726 - val_mean_absolute_error: 0.6541 - val_mean_absolute_percentage_error: 270.9207
# Epoch 74/100
# 26/26 [==============================] - ETA: 0s - loss: -0.8024 - mean_squared_error: 2.6803 - mean_absolute_error: 1.2079 - mean_absolute_percentage_error: 633.8594
# Epoch 00074: mean_absolute_error did not improve from 0.63856
#
# Epoch 00074: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.8024 - mean_squared_error: 2.6803 - mean_absolute_error: 1.2079 - mean_absolute_percentage_error: 633.8594 - val_loss: -0.7299 - val_mean_squared_error: 0.8461 - val_mean_absolute_error: 0.6971 - val_mean_absolute_percentage_error: 267.1203
# Epoch 75/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7783 - mean_squared_error: 3.2191 - mean_absolute_error: 1.3193 - mean_absolute_percentage_error: 756.9982
# Epoch 00075: mean_absolute_error did not improve from 0.63856
#
# Epoch 00075: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.7783 - mean_squared_error: 3.2191 - mean_absolute_error: 1.3193 - mean_absolute_percentage_error: 756.9982 - val_loss: -0.6888 - val_mean_squared_error: 878.6358 - val_mean_absolute_error: 15.7429 - val_mean_absolute_percentage_error: 5896.8271
# Epoch 76/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7630 - mean_squared_error: 3.0016 - mean_absolute_error: 1.3086 - mean_absolute_percentage_error: 699.3760
# Epoch 00076: mean_absolute_error did not improve from 0.63856
#
# Epoch 00076: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.7630 - mean_squared_error: 3.0016 - mean_absolute_error: 1.3086 - mean_absolute_percentage_error: 699.3760 - val_loss: -0.6063 - val_mean_squared_error: 103.3270 - val_mean_absolute_error: 6.0644 - val_mean_absolute_percentage_error: 2764.8423
# Epoch 77/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7550 - mean_squared_error: 2.9697 - mean_absolute_error: 1.2871 - mean_absolute_percentage_error: 723.6718
# Epoch 00077: mean_absolute_error did not improve from 0.63856
#
# Epoch 00077: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7550 - mean_squared_error: 2.9697 - mean_absolute_error: 1.2871 - mean_absolute_percentage_error: 723.6718 - val_loss: -0.6477 - val_mean_squared_error: 3.3985 - val_mean_absolute_error: 1.1638 - val_mean_absolute_percentage_error: 591.7820
# Epoch 78/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7802 - mean_squared_error: 3.4992 - mean_absolute_error: 1.3526 - mean_absolute_percentage_error: 724.7408
# Epoch 00078: mean_absolute_error did not improve from 0.63856
#
# Epoch 00078: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 209s 8s/step - loss: -0.7802 - mean_squared_error: 3.4992 - mean_absolute_error: 1.3526 - mean_absolute_percentage_error: 724.7408 - val_loss: -0.7174 - val_mean_squared_error: 8.7848 - val_mean_absolute_error: 2.0883 - val_mean_absolute_percentage_error: 729.2720
# Epoch 79/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7856 - mean_squared_error: 3.3301 - mean_absolute_error: 1.3223 - mean_absolute_percentage_error: 732.6785
# Epoch 00079: mean_absolute_error did not improve from 0.63856
#
# Epoch 00079: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.7856 - mean_squared_error: 3.3301 - mean_absolute_error: 1.3223 - mean_absolute_percentage_error: 732.6785 - val_loss: -0.7209 - val_mean_squared_error: 5.6087 - val_mean_absolute_error: 1.6033 - val_mean_absolute_percentage_error: 569.4872
# Epoch 80/100
# 26/26 [==============================] - ETA: 0s - loss: -0.7794 - mean_squared_error: 3.0542 - mean_absolute_error: 1.2690 - mean_absolute_percentage_error: 722.9352
# Epoch 00080: mean_absolute_error did not improve from 0.63856
#
# Epoch 00080: saving model to models/last_weights_xy_custom_cosine.hdf5
# 26/26 [==============================] - 208s 8s/step - loss: -0.7794 - mean_squared_error: 3.0542 - mean_absolute_error: 1.2690 - mean_absolute_percentage_error: 722.9352 - val_loss: -0.7185 - val_mean_squared_error: 3.3077 - val_mean_absolute_error: 1.2478 - val_mean_absolute_percentage_error: 486.6303
# Epoch 81/100
#  1/26 [>.............................] - ETA: 0s - loss: -0.7737 - mean_squared_error: 4.1234 - mean_absolute_error: 1.3825 - mean_absolute_percentage_error: 436.5608
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-e898613913cf> in <module>
#      23
#      24
# ---> 25 model.fit(
#      26     train_ds,
#      27     validation_data = validation_ds,
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# /opt/conda/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.save('models/trained_xy_fullsol_cosine.h5')

# %%
# taking samples from the validation dataset and evaluating the model
val_ex, = train_ds.take(1)
images, labels = val_ex[0], val_ex[1]
outputs = model.predict(images)

# %%
#print(labels)
print(outputs[:20])
# Out:
# [[ 1.7037135e-01 -7.6557922e-01]
#  [-4.6663000e-03  9.9857509e-02]
#  [-2.2877557e+00  2.3253655e+00]
#  [-1.1401024e+01  5.4049292e+00]
#  [-1.2389671e+00  3.8024426e-01]
#  [ 2.2306053e-02 -8.4183383e-01]
#  [-1.8025746e+00  1.6076996e+00]
#  [-6.9907349e-01 -2.0042220e-01]
#  [-8.7765980e-01  6.3710159e-01]
#  [-1.4915806e+00  1.3393327e+00]
#  [-6.1703224e+00  2.5095973e+00]
#  [-2.9497161e-03 -5.6701326e-01]
#  [-1.9259033e+00  7.0485884e-01]
#  [ 1.5269712e-01 -8.0429918e-01]
#  [-2.3292539e+00  2.5325713e+00]
#  [-1.3735721e+00  1.7359723e+00]
#  [-2.8986540e+00  8.6298454e-01]
#  [ 1.6119617e-01 -7.7835459e-01]
#  [ 5.4619551e-02 -5.3324312e-01]
#  [-1.0017060e+01  4.4952130e+00]]

# %%
# visualicing the results
for img,label,pred,i in zip(images, labels, outputs,range(15)):
    viz(img, label, pred)
# Out:
# #### **cartesian label:** [0.39347598 0.3382438 ]
# #### **cartesian prediction (x_y):** [ 0.17037135 -0.7655792 ]
# #### **cartesian label:** [-0.5678054  -0.16969964]
# #### **cartesian prediction (x_y):** [-0.0046663   0.09985751]
# #### **cartesian label:** [-0.9139126   0.37955904]
# #### **cartesian prediction (x_y):** [-2.2877557  2.3253655]
# #### **cartesian label:** [ 0.03252629 -0.03517763]
# #### **cartesian prediction (x_y):** [-11.401024   5.404929]
# #### **cartesian label:** [0.7108889 0.6972123]
# #### **cartesian prediction (x_y):** [-1.2389671   0.38024426]
# #### **cartesian label:** [-0.44013566 -0.80184656]
# #### **cartesian prediction (x_y):** [ 0.02230605 -0.84183383]
# #### **cartesian label:** [ 0.80941296 -0.44331542]
# #### **cartesian prediction (x_y):** [-1.8025746  1.6076996]
# #### **cartesian label:** [-0.724119  -0.5842369]
# #### **cartesian prediction (x_y):** [-0.6990735 -0.2004222]
# #### **cartesian label:** [-0.785242   0.4409895]
# #### **cartesian prediction (x_y):** [-0.8776598  0.6371016]
# #### **cartesian label:** [-0.4518544   0.06030474]
# #### **cartesian prediction (x_y):** [-1.4915806  1.3393327]
# #### **cartesian label:** [0.3565967 0.0202833]
# #### **cartesian prediction (x_y):** [-6.1703224  2.5095973]
# #### **cartesian label:** [-0.4492266 -0.1691026]
# #### **cartesian prediction (x_y):** [-0.00294972 -0.56701326]
# #### **cartesian label:** [ 0.7996358  -0.08060153]
# #### **cartesian prediction (x_y):** [-1.9259033   0.70485884]
# #### **cartesian label:** [ 0.18767297 -0.4757469 ]
# #### **cartesian prediction (x_y):** [ 0.15269712 -0.8042992 ]
# #### **cartesian label:** [-0.18886448 -0.13921359]
# #### **cartesian prediction (x_y):** [-2.329254   2.5325713]
