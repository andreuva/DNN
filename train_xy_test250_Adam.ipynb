# %%
import os
from classification_models.tfkeras import Classifiers

# Import the ResNet34 model
ResNet34, preprocess_input = Classifiers.get('resnet34')

# %%
# Run only for training!
import glob
import math
import datetime
import numpy as np
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
from sklearn.preprocessing import normalize

tfd = tfp.distributions
tfpl = tfp.layers
tfk = tf.keras
tfkl = tf.keras.layers

# Change parameters here...
log_dir = "logs/"
os.makedirs(log_dir, exist_ok=True)
data_dir = 'data/' 
snapshot_weights = 'models/best_weights_xy_test250_Adam_cosine.hdf5'
last_snapshot_weights = 'models/last_weights_xy_test250_Adam_cosine.hdf5'

sizex = 500
sizey = 500
sizez = 3
rand_seed = 666
num_datasets = -1
batch_size = 32
nb_epochs = 200
validation_ratio = 0.2
#ds_size = len(data_dict['y_revs'])
ds_size = 250
buf_size = ds_size

# %%
# Collect all the .npz files
numpy_datasets = glob.glob(data_dir+'dataset*')

# %%
# load the data into a dictionary from npz files
data_dict = {}
for dataset in numpy_datasets[:num_datasets]:
    with np.load(dataset) as data:
        if 'y' in data_dict.keys():
            #data_dict['x_dust']   = np.append( data_dict['x_dust'], data['x_dust'],axis=0)
            data_dict['x_nodust'] = np.append( data_dict['x_nodust'], data['x_nodust'],axis=0)
            data_dict['y']        = np.append( data_dict['y'], data['y'],axis=0)
            data_dict['ids']      = np.append( data_dict['ids'], data['id'],axis=0)
        else:
            #data_dict['x_dust']   = data['x_dust']
            data_dict['x_nodust'] = data['x_nodust']
            data_dict['y']        = data['y']
            data_dict['ids']      = data['id']

# %%
# check the shape of the dictionary (100 images of 500x500x3 = 4 files of 25 images)
data_dict['x_nodust'].shape
# Out:
# (895, 500, 500, 3)

# %%
# Compute the angles from the x,y,z labels
# theta = np.arctan(np.sqrt(x**2 + y**2)/z)
# phi = np.arctan(y/x)
def cart_to_esf(xyz):
    angles = np.empty( (len(xyz),2) )
    angles[:,0] = np.arctan2(np.sqrt(xyz[:,0]**2 + xyz[:,1]**2),xyz[:,2]) *180/np.pi #theta angle in degrees
    angles[:,1] = np.arctan2(xyz[:,1],xyz[:,0]) * 180/np.pi #phi angle in degrees
    return angles

# Define the function to go back to cartisian cordinates
def esf_to_cart(angles):
    xyz = np.empty( (len(angles),3) )
    ang_rad = angles*np.pi/180
    xyz[:,0] = np.sin(ang_rad[:,0])*np.cos(ang_rad[:,1])
    xyz[:,1] = np.sin(ang_rad[:,0])*np.sin(ang_rad[:,1])
    xyz[:,2] = np.cos(ang_rad[:,0])
    return xyz

#break the degeneracy of the solutions restricting the solution to 1 sector
def break_degeneracy(angles):
    ang_norm = angles
    for i in range(len(angles)):
        if ang_norm[:,1][i] < 0:
            ang_norm[:,1][i] = (ang_norm[:,1][i] + 180)
    return ang_norm

#map the solution to be between [0,1]
def map_to_1(angles, max = 180 ):
    ang_norm = angles/max
    return ang_norm

#coming back the mapping from 1 to 180
def map_to_180(ang_norm):
  angle = ang_norm*180
  return angle

# computing the normaliced vectors in 3D
data_dict['y_norm'] = normalize(data_dict['y'], axis=1)
data_dict['y_ang'] = map_to_1(break_degeneracy(cart_to_esf(normalize(data_dict['y'], axis=1))))
data_dict['y_revs'] = esf_to_cart(map_to_180(data_dict['y_ang']))

# %%
# check the shape of our dictionary in te labels entry
print(data_dict['y_norm'].shape)
# Out:
# (895, 3)

# %%
# separate in batches and shuffle the data with a fixed seed
#dataset = dataset.batch(batch_size)
#dataset = dataset.shuffle(10, seed=123)
AUTO = tf.data.experimental.AUTOTUNE

# %%
# functions to visualice the data 
def viz(img, label, pred=np.array([0,0,0]), id=None):
    fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(img, cmap='gray', vmin=0, vmax=255,origin='lower')
    ax.arrow(250,250,100*label[0],100*label[1], head_width=7, head_length=10, fc='g', ec='g')
    if np.sum(np.abs(pred)) > 0: ax.arrow(250,250,100*pred[0],100*pred[1], head_width=7, head_length=10, fc='r', ec='r')
        
    display(Markdown("#### **cartesian label:** {}".format(label)))
    if np.sum(np.abs(pred)) > 0: display(Markdown("#### **cartesian prediction (x_y):** {}".format(pred)))
    if id: display(Markdown("#### **ID:** {}".format(id)))
    plt.show()

# create the dataset from the dictionary and see the size and type
dataset = tf.data.Dataset.from_tensor_slices(data_dict)
print(dataset)
# Out:
# <TensorSliceDataset shapes: {x_nodust: (500, 500, 3), y: (3,), ids: (), y_norm: (3,), y_ang: (2,), y_revs: (3,)}, types: {x_nodust: tf.float64, y: tf.float64, ids: tf.string, y_norm: tf.float64, y_ang: tf.float64, y_revs: tf.float64}>

# %%
# visualice the data
real_dataset = dataset.batch(batch_size).shuffle(10, seed=rand_seed)
for idx in range(1,5):
    elements = real_dataset.take(idx)
    for elem in elements:
        viz(elem['x_nodust'][idx], elem['y_norm'][idx], elem['y_revs'][idx], id=elem['ids'][idx])
# Out:
# #### **cartesian label:** [ 0.32824791 -0.93567687  0.12946857]
# #### **cartesian prediction (x_y):** [-0.32824791  0.93567687  0.12946857]
# #### **ID:** b'g1.92e12_x191_y196_z346'
# #### **cartesian label:** [ 0.69888396 -0.48242208  0.5280437 ]
# #### **cartesian prediction (x_y):** [-0.69888396  0.48242208  0.5280437 ]
# #### **ID:** b'g4.94e10_x95_y40_z353'
# #### **cartesian label:** [ 0.32748777 -0.90499277  0.27155083]
# #### **cartesian prediction (x_y):** [-0.32748777  0.90499277  0.27155083]
# #### **ID:** b'g2.57e11_x169_y353_z23'
# #### **cartesian label:** [ 0.529758   -0.33886048  0.7775153 ]
# #### **cartesian prediction (x_y):** [-0.529758    0.33886048  0.7775153 ]
# #### **ID:** b'g1.50e10_x295_y296_z33'
# #### **cartesian label:** [ 0.93311959 -0.07987218 -0.35058276]
# #### **cartesian prediction (x_y):** [-0.93311959  0.07987218 -0.35058276]
# #### **ID:** b'g4.99e09_x292_y197_z332'
# #### **cartesian label:** [ 0.7952049  -0.15544084  0.5860779 ]
# #### **cartesian prediction (x_y):** [-0.7952049   0.15544084  0.5860779 ]
# #### **ID:** b'g1.12e12_x324_y109_z175'
# #### **cartesian label:** [-0.23745501 -0.33004524 -0.91361111]
# #### **cartesian prediction (x_y):** [ 0.23745501  0.33004524 -0.91361111]
# #### **ID:** b'g3.67e09_x320_y258_z122'
# #### **cartesian label:** [-0.46789934 -0.02189159  0.88351059]
# #### **cartesian prediction (x_y):** [0.46789934 0.02189159 0.88351059]
# #### **ID:** b'g1.50e10_x158_y72_z172'
# #### **cartesian label:** [0.66018449 0.69187025 0.29235593]
# #### **cartesian prediction (x_y):** [0.66018449 0.69187025 0.29235593]
# #### **ID:** b'g1.95e10_x123_y47_z338'
# #### **cartesian label:** [-0.36234559 -0.68405446  0.63306806]
# #### **cartesian prediction (x_y):** [0.36234559 0.68405446 0.63306806]
# #### **ID:** b'g4.99e09_x62_y80_z230'

# %%
# defining the train and validation dataset from the existing dictionary, shufling and batching
input_ds = (
    tf.data.Dataset.from_tensor_slices((data_dict['x_nodust'].astype(np.float32), data_dict['y_norm'][:,:2].astype(np.float32)))
                    # Use seed to ensure we always have the same validation data set!
                   .shuffle(ds_size, seed = rand_seed, reshuffle_each_iteration = False)
)

input_ds = input_ds.take(ds_size)
val_size = math.floor(ds_size * validation_ratio)

validation_ds = ( input_ds.take(val_size).batch(batch_size) )
train_ds = ( input_ds.skip(val_size).shuffle(buffer_size=buf_size, reshuffle_each_iteration=True).batch(batch_size) )

print(train_ds)
print(validation_ds)
# Out:
# <BatchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 500, 500, 3), (None, 2)), types: (tf.float32, tf.float32)>

# %%
# %reload_ext tensorboard
# %tensorboard --logdir {log_dir} --reload_multifile True --host 0.0.0.0 --port 6006
# Out:
#       <iframe id="tensorboard-frame-b22b41b7f6c7b060" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b22b41b7f6c7b060");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
# Build model
base_model = ResNet34(input_shape=(sizey,sizex,3), include_top=False)

# redefine the output to be 2 parameters from the last dense layer
x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tf.keras.layers.Dense(2, activation=None)(x)
model = tf.keras.models.Model(inputs=[base_model.input], outputs=[output])

# Use existing best weights if available...
if os.path.isfile(last_snapshot_weights):
    print('loaded weights')
    model.load_weights(last_snapshot_weights)
    
cossim = lambda y, p_y: -1*tf.keras.backend.abs(tf.keras.losses.cosine_similarity(y, p_y))
model.compile(optimizer= 'Adam', loss=cossim, metrics=[
                        tf.keras.metrics.mean_squared_error, 
                        tf.keras.metrics.mean_absolute_error, 
                        tf.keras.metrics.mean_absolute_percentage_error])

# %%
# model.summary()

# For tensorboard
log_dir_s = log_dir + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
os.makedirs(log_dir_s, exist_ok=True)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir_s, histogram_freq=1, update_freq='batch', profile_batch=0)

# Checkpointing
checkpointer_1 = tf.keras.callbacks.ModelCheckpoint(filepath=snapshot_weights,
                               monitor='mean_absolute_error',
                               verbose=1,
                               save_best_only=True)
checkpointer_2 = tf.keras.callbacks.ModelCheckpoint(filepath=last_snapshot_weights,
                               monitor='mean_absolute_error',
                               verbose=1,
                               save_best_only=False)

callbacks = [
    tensorboard_callback,
    checkpointer_1,
    checkpointer_2
]


model.fit(
    train_ds,
    validation_data = validation_ds,
    epochs = nb_epochs,
    callbacks = callbacks,)
    # class_weight=class_weight)
# Out:
# Epoch 1/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6565 - mean_squared_error: 23.6214 - mean_absolute_error: 2.8660 - mean_absolute_percentage_error: 1337.1322
# Epoch 00001: mean_absolute_error improved from inf to 2.86601, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00001: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 54s 8s/step - loss: -0.6565 - mean_squared_error: 23.6214 - mean_absolute_error: 2.8660 - mean_absolute_percentage_error: 1337.1322 - val_loss: -0.7386 - val_mean_squared_error: 23416350441472.0000 - val_mean_absolute_error: 2550280.0000 - val_mean_absolute_percentage_error: 1617187328.0000
# Epoch 2/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6811 - mean_squared_error: 16.4317 - mean_absolute_error: 2.5384 - mean_absolute_percentage_error: 1024.0944
# Epoch 00002: mean_absolute_error improved from 2.86601 to 2.53842, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00002: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 55s 8s/step - loss: -0.6811 - mean_squared_error: 16.4317 - mean_absolute_error: 2.5384 - mean_absolute_percentage_error: 1024.0944 - val_loss: -0.7286 - val_mean_squared_error: 1088745017180160.0000 - val_mean_absolute_error: 20414020.0000 - val_mean_absolute_percentage_error: 16675346432.0000
# Epoch 3/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6880 - mean_squared_error: 13.5051 - mean_absolute_error: 2.5099 - mean_absolute_percentage_error: 1231.0509
# Epoch 00003: mean_absolute_error improved from 2.53842 to 2.50995, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00003: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.6880 - mean_squared_error: 13.5051 - mean_absolute_error: 2.5099 - mean_absolute_percentage_error: 1231.0509 - val_loss: -0.7248 - val_mean_squared_error: 6650505199616.0000 - val_mean_absolute_error: 1853372.7500 - val_mean_absolute_percentage_error: 1472863488.0000
# Epoch 4/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6902 - mean_squared_error: 25.3340 - mean_absolute_error: 3.3386 - mean_absolute_percentage_error: 1644.4723
# Epoch 00004: mean_absolute_error did not improve from 2.50995
#
# Epoch 00004: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.6902 - mean_squared_error: 25.3340 - mean_absolute_error: 3.3386 - mean_absolute_percentage_error: 1644.4723 - val_loss: -0.7317 - val_mean_squared_error: 740658053120.0000 - val_mean_absolute_error: 551477.8125 - val_mean_absolute_percentage_error: 423130720.0000
# Epoch 5/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7053 - mean_squared_error: 23.0358 - mean_absolute_error: 3.1534 - mean_absolute_percentage_error: 1524.2583
# Epoch 00005: mean_absolute_error did not improve from 2.50995
#
# Epoch 00005: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7053 - mean_squared_error: 23.0358 - mean_absolute_error: 3.1534 - mean_absolute_percentage_error: 1524.2583 - val_loss: -0.7356 - val_mean_squared_error: 76465561600.0000 - val_mean_absolute_error: 172845.0625 - val_mean_absolute_percentage_error: 126238720.0000
# Epoch 6/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6929 - mean_squared_error: 15.9334 - mean_absolute_error: 2.6656 - mean_absolute_percentage_error: 1320.2622
# Epoch 00006: mean_absolute_error did not improve from 2.50995
#
# Epoch 00006: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.6929 - mean_squared_error: 15.9334 - mean_absolute_error: 2.6656 - mean_absolute_percentage_error: 1320.2622 - val_loss: -0.7374 - val_mean_squared_error: 2328637696.0000 - val_mean_absolute_error: 34194.4609 - val_mean_absolute_percentage_error: 21961154.0000
# Epoch 7/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7153 - mean_squared_error: 11.0677 - mean_absolute_error: 2.4157 - mean_absolute_percentage_error: 1246.1799
# Epoch 00007: mean_absolute_error improved from 2.50995 to 2.41570, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00007: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7153 - mean_squared_error: 11.0677 - mean_absolute_error: 2.4157 - mean_absolute_percentage_error: 1246.1799 - val_loss: -0.7381 - val_mean_squared_error: 486097824.0000 - val_mean_absolute_error: 14758.9502 - val_mean_absolute_percentage_error: 9905718.0000
# Epoch 8/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7131 - mean_squared_error: 11.6856 - mean_absolute_error: 2.4619 - mean_absolute_percentage_error: 1289.2119
# Epoch 00008: mean_absolute_error did not improve from 2.41570
#
# Epoch 00008: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7131 - mean_squared_error: 11.6856 - mean_absolute_error: 2.4619 - mean_absolute_percentage_error: 1289.2119 - val_loss: -0.7392 - val_mean_squared_error: 82158928.0000 - val_mean_absolute_error: 5515.1504 - val_mean_absolute_percentage_error: 3613487.0000
# Epoch 9/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6959 - mean_squared_error: 10.9108 - mean_absolute_error: 2.4638 - mean_absolute_percentage_error: 1329.5922
# Epoch 00009: mean_absolute_error did not improve from 2.41570
#
# Epoch 00009: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.6959 - mean_squared_error: 10.9108 - mean_absolute_error: 2.4638 - mean_absolute_percentage_error: 1329.5922 - val_loss: -0.7382 - val_mean_squared_error: 2539929.5000 - val_mean_absolute_error: 930.3329 - val_mean_absolute_percentage_error: 595481.1875
# Epoch 10/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7278 - mean_squared_error: 9.6800 - mean_absolute_error: 2.4902 - mean_absolute_percentage_error: 1407.5748
# Epoch 00010: mean_absolute_error did not improve from 2.41570
#
# Epoch 00010: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7278 - mean_squared_error: 9.6800 - mean_absolute_error: 2.4902 - mean_absolute_percentage_error: 1407.5748 - val_loss: -0.7353 - val_mean_squared_error: 223370.9219 - val_mean_absolute_error: 251.7580 - val_mean_absolute_percentage_error: 159177.7188
# Epoch 11/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7233 - mean_squared_error: 9.7747 - mean_absolute_error: 2.4929 - mean_absolute_percentage_error: 1420.9163
# Epoch 00011: mean_absolute_error did not improve from 2.41570
#
# Epoch 00011: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7233 - mean_squared_error: 9.7747 - mean_absolute_error: 2.4929 - mean_absolute_percentage_error: 1420.9163 - val_loss: -0.6128 - val_mean_squared_error: 34.5041 - val_mean_absolute_error: 2.8277 - val_mean_absolute_percentage_error: 2051.2957
# Epoch 12/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7070 - mean_squared_error: 8.2324 - mean_absolute_error: 2.2668 - mean_absolute_percentage_error: 1323.5486
# Epoch 00012: mean_absolute_error improved from 2.41570 to 2.26678, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00012: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7070 - mean_squared_error: 8.2324 - mean_absolute_error: 2.2668 - mean_absolute_percentage_error: 1323.5486 - val_loss: -0.5963 - val_mean_squared_error: 4.0089 - val_mean_absolute_error: 1.4336 - val_mean_absolute_percentage_error: 1095.6316
# Epoch 13/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7333 - mean_squared_error: 8.7882 - mean_absolute_error: 2.3605 - mean_absolute_percentage_error: 1309.6688
# Epoch 00013: mean_absolute_error did not improve from 2.26678
#
# Epoch 00013: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7333 - mean_squared_error: 8.7882 - mean_absolute_error: 2.3605 - mean_absolute_percentage_error: 1309.6688 - val_loss: -0.6440 - val_mean_squared_error: 325.8492 - val_mean_absolute_error: 8.1596 - val_mean_absolute_percentage_error: 5412.8569
# Epoch 14/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7260 - mean_squared_error: 9.9868 - mean_absolute_error: 2.4259 - mean_absolute_percentage_error: 1344.1021
# Epoch 00014: mean_absolute_error did not improve from 2.26678
#
# Epoch 00014: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7260 - mean_squared_error: 9.9868 - mean_absolute_error: 2.4259 - mean_absolute_percentage_error: 1344.1021 - val_loss: -0.6193 - val_mean_squared_error: 152.6608 - val_mean_absolute_error: 5.8033 - val_mean_absolute_percentage_error: 3627.5115
# Epoch 15/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7383 - mean_squared_error: 9.2520 - mean_absolute_error: 2.3567 - mean_absolute_percentage_error: 1291.0004
# Epoch 00015: mean_absolute_error did not improve from 2.26678
#
# Epoch 00015: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7383 - mean_squared_error: 9.2520 - mean_absolute_error: 2.3567 - mean_absolute_percentage_error: 1291.0004 - val_loss: -0.5610 - val_mean_squared_error: 4.6419 - val_mean_absolute_error: 1.7667 - val_mean_absolute_percentage_error: 1442.3584
# Epoch 16/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7229 - mean_squared_error: 8.2798 - mean_absolute_error: 2.2531 - mean_absolute_percentage_error: 1349.0930
# Epoch 00016: mean_absolute_error improved from 2.26678 to 2.25311, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00016: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7229 - mean_squared_error: 8.2798 - mean_absolute_error: 2.2531 - mean_absolute_percentage_error: 1349.0930 - val_loss: -0.5664 - val_mean_squared_error: 6.2781 - val_mean_absolute_error: 1.9699 - val_mean_absolute_percentage_error: 1581.9611
# Epoch 17/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7272 - mean_squared_error: 8.1493 - mean_absolute_error: 2.2038 - mean_absolute_percentage_error: 1181.6733
# Epoch 00017: mean_absolute_error improved from 2.25311 to 2.20385, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00017: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7272 - mean_squared_error: 8.1493 - mean_absolute_error: 2.2038 - mean_absolute_percentage_error: 1181.6733 - val_loss: -0.6264 - val_mean_squared_error: 701.7913 - val_mean_absolute_error: 12.1411 - val_mean_absolute_percentage_error: 9065.6582
# Epoch 18/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7114 - mean_squared_error: 8.2939 - mean_absolute_error: 2.1959 - mean_absolute_percentage_error: 1185.5785
# Epoch 00018: mean_absolute_error improved from 2.20385 to 2.19594, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00018: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7114 - mean_squared_error: 8.2939 - mean_absolute_error: 2.1959 - mean_absolute_percentage_error: 1185.5785 - val_loss: -0.6056 - val_mean_squared_error: 60.7538 - val_mean_absolute_error: 4.2514 - val_mean_absolute_percentage_error: 2817.1975
# Epoch 19/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7389 - mean_squared_error: 8.7766 - mean_absolute_error: 2.2115 - mean_absolute_percentage_error: 1062.5045
# Epoch 00019: mean_absolute_error did not improve from 2.19594
#
# Epoch 00019: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7389 - mean_squared_error: 8.7766 - mean_absolute_error: 2.2115 - mean_absolute_percentage_error: 1062.5045 - val_loss: -0.6026 - val_mean_squared_error: 7.4497 - val_mean_absolute_error: 1.9637 - val_mean_absolute_percentage_error: 1302.6635
# Epoch 20/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7259 - mean_squared_error: 9.7271 - mean_absolute_error: 2.3770 - mean_absolute_percentage_error: 1126.3936
# Epoch 00020: mean_absolute_error did not improve from 2.19594
#
# Epoch 00020: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7259 - mean_squared_error: 9.7271 - mean_absolute_error: 2.3770 - mean_absolute_percentage_error: 1126.3936 - val_loss: -0.6063 - val_mean_squared_error: 15.4155 - val_mean_absolute_error: 2.5926 - val_mean_absolute_percentage_error: 1649.3019
# Epoch 21/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7221 - mean_squared_error: 11.3207 - mean_absolute_error: 2.4454 - mean_absolute_percentage_error: 1192.3564
# Epoch 00021: mean_absolute_error did not improve from 2.19594
#
# Epoch 00021: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7221 - mean_squared_error: 11.3207 - mean_absolute_error: 2.4454 - mean_absolute_percentage_error: 1192.3564 - val_loss: -0.6420 - val_mean_squared_error: 1809.0875 - val_mean_absolute_error: 19.6930 - val_mean_absolute_percentage_error: 14859.0176
# Epoch 22/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7047 - mean_squared_error: 9.8523 - mean_absolute_error: 2.1724 - mean_absolute_percentage_error: 1004.3809
# Epoch 00022: mean_absolute_error improved from 2.19594 to 2.17240, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00022: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7047 - mean_squared_error: 9.8523 - mean_absolute_error: 2.1724 - mean_absolute_percentage_error: 1004.3809 - val_loss: -0.6567 - val_mean_squared_error: 2267.3647 - val_mean_absolute_error: 21.1166 - val_mean_absolute_percentage_error: 18141.4570
# Epoch 23/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7049 - mean_squared_error: 9.3149 - mean_absolute_error: 2.0721 - mean_absolute_percentage_error: 1042.7957
# Epoch 00023: mean_absolute_error improved from 2.17240 to 2.07210, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00023: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7049 - mean_squared_error: 9.3149 - mean_absolute_error: 2.0721 - mean_absolute_percentage_error: 1042.7957 - val_loss: -0.6271 - val_mean_squared_error: 1098.3102 - val_mean_absolute_error: 14.8123 - val_mean_absolute_percentage_error: 13570.3838
# Epoch 24/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7182 - mean_squared_error: 8.9007 - mean_absolute_error: 2.1939 - mean_absolute_percentage_error: 1260.3186
# Epoch 00024: mean_absolute_error did not improve from 2.07210
#
# Epoch 00024: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7182 - mean_squared_error: 8.9007 - mean_absolute_error: 2.1939 - mean_absolute_percentage_error: 1260.3186 - val_loss: -0.6366 - val_mean_squared_error: 19.6299 - val_mean_absolute_error: 2.5035 - val_mean_absolute_percentage_error: 1743.2996
# Epoch 25/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7308 - mean_squared_error: 7.3946 - mean_absolute_error: 2.1678 - mean_absolute_percentage_error: 1241.9642
# Epoch 00025: mean_absolute_error did not improve from 2.07210
#
# Epoch 00025: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7308 - mean_squared_error: 7.3946 - mean_absolute_error: 2.1678 - mean_absolute_percentage_error: 1241.9642 - val_loss: -0.5784 - val_mean_squared_error: 3.0461 - val_mean_absolute_error: 1.5662 - val_mean_absolute_percentage_error: 1221.1877
# Epoch 26/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7443 - mean_squared_error: 7.1326 - mean_absolute_error: 2.2016 - mean_absolute_percentage_error: 1249.1467
# Epoch 00026: mean_absolute_error did not improve from 2.07210
#
# Epoch 00026: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7443 - mean_squared_error: 7.1326 - mean_absolute_error: 2.2016 - mean_absolute_percentage_error: 1249.1467 - val_loss: -0.5633 - val_mean_squared_error: 3.5243 - val_mean_absolute_error: 1.6185 - val_mean_absolute_percentage_error: 1376.5291
# Epoch 27/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7391 - mean_squared_error: 7.0308 - mean_absolute_error: 2.1313 - mean_absolute_percentage_error: 1170.4485
# Epoch 00027: mean_absolute_error did not improve from 2.07210
#
# Epoch 00027: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7391 - mean_squared_error: 7.0308 - mean_absolute_error: 2.1313 - mean_absolute_percentage_error: 1170.4485 - val_loss: -0.5371 - val_mean_squared_error: 3.5944 - val_mean_absolute_error: 1.5627 - val_mean_absolute_percentage_error: 1353.3291
# Epoch 28/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7267 - mean_squared_error: 8.2014 - mean_absolute_error: 1.9796 - mean_absolute_percentage_error: 1111.3505
# Epoch 00028: mean_absolute_error improved from 2.07210 to 1.97962, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00028: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7267 - mean_squared_error: 8.2014 - mean_absolute_error: 1.9796 - mean_absolute_percentage_error: 1111.3505 - val_loss: -0.5316 - val_mean_squared_error: 3.4906 - val_mean_absolute_error: 1.5288 - val_mean_absolute_percentage_error: 1350.3074
# Epoch 29/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6752 - mean_squared_error: 7.4758 - mean_absolute_error: 2.1741 - mean_absolute_percentage_error: 1347.9666
# Epoch 00029: mean_absolute_error did not improve from 1.97962
#
# Epoch 00029: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.6752 - mean_squared_error: 7.4758 - mean_absolute_error: 2.1741 - mean_absolute_percentage_error: 1347.9666 - val_loss: -0.6121 - val_mean_squared_error: 80885.5938 - val_mean_absolute_error: 146.5400 - val_mean_absolute_percentage_error: 150877.2031
# Epoch 30/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6714 - mean_squared_error: 11.5030 - mean_absolute_error: 2.4873 - mean_absolute_percentage_error: 1500.0964
# Epoch 00030: mean_absolute_error did not improve from 1.97962
#
# Epoch 00030: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.6714 - mean_squared_error: 11.5030 - mean_absolute_error: 2.4873 - mean_absolute_percentage_error: 1500.0964 - val_loss: -0.6793 - val_mean_squared_error: 3806785.5000 - val_mean_absolute_error: 1002.1833 - val_mean_absolute_percentage_error: 1010246.5000
# Epoch 31/200
# 7/7 [==============================] - ETA: 0s - loss: -0.6888 - mean_squared_error: 10.3548 - mean_absolute_error: 2.5077 - mean_absolute_percentage_error: 1475.9240
# Epoch 00031: mean_absolute_error did not improve from 1.97962
#
# Epoch 00031: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.6888 - mean_squared_error: 10.3548 - mean_absolute_error: 2.5077 - mean_absolute_percentage_error: 1475.9240 - val_loss: -0.6940 - val_mean_squared_error: 985824.9375 - val_mean_absolute_error: 504.1748 - val_mean_absolute_percentage_error: 484485.8125
# Epoch 32/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7225 - mean_squared_error: 10.5836 - mean_absolute_error: 2.5522 - mean_absolute_percentage_error: 1579.0012
# Epoch 00032: mean_absolute_error did not improve from 1.97962
#
# Epoch 00032: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7225 - mean_squared_error: 10.5836 - mean_absolute_error: 2.5522 - mean_absolute_percentage_error: 1579.0012 - val_loss: -0.6780 - val_mean_squared_error: 101248.3984 - val_mean_absolute_error: 160.9915 - val_mean_absolute_percentage_error: 146044.8594
# Epoch 33/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7127 - mean_squared_error: 10.7583 - mean_absolute_error: 2.5916 - mean_absolute_percentage_error: 1383.3237
# Epoch 00033: mean_absolute_error did not improve from 1.97962
#
# Epoch 00033: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7127 - mean_squared_error: 10.7583 - mean_absolute_error: 2.5916 - mean_absolute_percentage_error: 1383.3237 - val_loss: -0.6885 - val_mean_squared_error: 8929.8213 - val_mean_absolute_error: 48.5613 - val_mean_absolute_percentage_error: 42342.7617
# Epoch 34/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7409 - mean_squared_error: 10.4587 - mean_absolute_error: 2.5499 - mean_absolute_percentage_error: 1378.8558
# Epoch 00034: mean_absolute_error did not improve from 1.97962
#
# Epoch 00034: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7409 - mean_squared_error: 10.4587 - mean_absolute_error: 2.5499 - mean_absolute_percentage_error: 1378.8558 - val_loss: -0.6426 - val_mean_squared_error: 1571.5397 - val_mean_absolute_error: 20.1906 - val_mean_absolute_percentage_error: 16992.7070
# Epoch 35/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7517 - mean_squared_error: 10.3486 - mean_absolute_error: 2.4469 - mean_absolute_percentage_error: 1342.0057
# Epoch 00035: mean_absolute_error did not improve from 1.97962
#
# Epoch 00035: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7517 - mean_squared_error: 10.3486 - mean_absolute_error: 2.4469 - mean_absolute_percentage_error: 1342.0057 - val_loss: -0.6867 - val_mean_squared_error: 480.5056 - val_mean_absolute_error: 9.5880 - val_mean_absolute_percentage_error: 6764.9014
# Epoch 36/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7373 - mean_squared_error: 7.6410 - mean_absolute_error: 2.2638 - mean_absolute_percentage_error: 1228.0292
# Epoch 00036: mean_absolute_error did not improve from 1.97962
#
# Epoch 00036: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7373 - mean_squared_error: 7.6410 - mean_absolute_error: 2.2638 - mean_absolute_percentage_error: 1228.0292 - val_loss: -0.7039 - val_mean_squared_error: 85.5082 - val_mean_absolute_error: 4.5011 - val_mean_absolute_percentage_error: 3539.9495
# Epoch 37/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7618 - mean_squared_error: 7.0792 - mean_absolute_error: 2.1631 - mean_absolute_percentage_error: 1175.2009
# Epoch 00037: mean_absolute_error did not improve from 1.97962
#
# Epoch 00037: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7618 - mean_squared_error: 7.0792 - mean_absolute_error: 2.1631 - mean_absolute_percentage_error: 1175.2009 - val_loss: -0.6819 - val_mean_squared_error: 70.1121 - val_mean_absolute_error: 4.3720 - val_mean_absolute_percentage_error: 3867.9968
# Epoch 38/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7551 - mean_squared_error: 7.1238 - mean_absolute_error: 2.1439 - mean_absolute_percentage_error: 1189.8004
# Epoch 00038: mean_absolute_error did not improve from 1.97962
#
# Epoch 00038: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7551 - mean_squared_error: 7.1238 - mean_absolute_error: 2.1439 - mean_absolute_percentage_error: 1189.8004 - val_loss: -0.6066 - val_mean_squared_error: 4.0575 - val_mean_absolute_error: 1.7823 - val_mean_absolute_percentage_error: 1229.3285
# Epoch 39/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7423 - mean_squared_error: 6.7386 - mean_absolute_error: 2.1026 - mean_absolute_percentage_error: 1049.7433
# Epoch 00039: mean_absolute_error did not improve from 1.97962
#
# Epoch 00039: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7423 - mean_squared_error: 6.7386 - mean_absolute_error: 2.1026 - mean_absolute_percentage_error: 1049.7433 - val_loss: -0.5770 - val_mean_squared_error: 5.0112 - val_mean_absolute_error: 1.9704 - val_mean_absolute_percentage_error: 1469.3899
# Epoch 40/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7402 - mean_squared_error: 9.3100 - mean_absolute_error: 2.2242 - mean_absolute_percentage_error: 1281.4290
# Epoch 00040: mean_absolute_error did not improve from 1.97962
#
# Epoch 00040: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7402 - mean_squared_error: 9.3100 - mean_absolute_error: 2.2242 - mean_absolute_percentage_error: 1281.4290 - val_loss: -0.6599 - val_mean_squared_error: 12.9488 - val_mean_absolute_error: 2.6332 - val_mean_absolute_percentage_error: 1914.0881
# Epoch 41/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7331 - mean_squared_error: 9.3898 - mean_absolute_error: 2.2279 - mean_absolute_percentage_error: 1121.9951
# Epoch 00041: mean_absolute_error did not improve from 1.97962
#
# Epoch 00041: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7331 - mean_squared_error: 9.3898 - mean_absolute_error: 2.2279 - mean_absolute_percentage_error: 1121.9951 - val_loss: -0.6299 - val_mean_squared_error: 8.0404 - val_mean_absolute_error: 2.4899 - val_mean_absolute_percentage_error: 1931.5347
# Epoch 42/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7446 - mean_squared_error: 8.1467 - mean_absolute_error: 2.2033 - mean_absolute_percentage_error: 1122.4274
# Epoch 00042: mean_absolute_error did not improve from 1.97962
#
# Epoch 00042: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7446 - mean_squared_error: 8.1467 - mean_absolute_error: 2.2033 - mean_absolute_percentage_error: 1122.4274 - val_loss: -0.6081 - val_mean_squared_error: 6.0692 - val_mean_absolute_error: 2.2839 - val_mean_absolute_percentage_error: 1729.5941
# Epoch 43/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7514 - mean_squared_error: 7.6235 - mean_absolute_error: 2.1613 - mean_absolute_percentage_error: 1124.2339
# Epoch 00043: mean_absolute_error did not improve from 1.97962
#
# Epoch 00043: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7514 - mean_squared_error: 7.6235 - mean_absolute_error: 2.1613 - mean_absolute_percentage_error: 1124.2339 - val_loss: -0.6088 - val_mean_squared_error: 5.2759 - val_mean_absolute_error: 2.1132 - val_mean_absolute_percentage_error: 1404.3522
# Epoch 44/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7574 - mean_squared_error: 8.4496 - mean_absolute_error: 2.2572 - mean_absolute_percentage_error: 1095.2903
# Epoch 00044: mean_absolute_error did not improve from 1.97962
#
# Epoch 00044: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7574 - mean_squared_error: 8.4496 - mean_absolute_error: 2.2572 - mean_absolute_percentage_error: 1095.2903 - val_loss: -0.6604 - val_mean_squared_error: 4.7125 - val_mean_absolute_error: 2.0530 - val_mean_absolute_percentage_error: 1264.5278
# Epoch 45/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7508 - mean_squared_error: 7.5256 - mean_absolute_error: 2.1473 - mean_absolute_percentage_error: 1176.1508
# Epoch 00045: mean_absolute_error did not improve from 1.97962
#
# Epoch 00045: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7508 - mean_squared_error: 7.5256 - mean_absolute_error: 2.1473 - mean_absolute_percentage_error: 1176.1508 - val_loss: -0.6565 - val_mean_squared_error: 3.5907 - val_mean_absolute_error: 1.7588 - val_mean_absolute_percentage_error: 1084.6282
# Epoch 46/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7521 - mean_squared_error: 7.7140 - mean_absolute_error: 2.1737 - mean_absolute_percentage_error: 1135.2345
# Epoch 00046: mean_absolute_error did not improve from 1.97962
#
# Epoch 00046: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7521 - mean_squared_error: 7.7140 - mean_absolute_error: 2.1737 - mean_absolute_percentage_error: 1135.2345 - val_loss: -0.6066 - val_mean_squared_error: 5.7403 - val_mean_absolute_error: 2.2604 - val_mean_absolute_percentage_error: 1705.5426
# Epoch 47/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7726 - mean_squared_error: 6.0541 - mean_absolute_error: 1.9749 - mean_absolute_percentage_error: 1183.1754
# Epoch 00047: mean_absolute_error improved from 1.97962 to 1.97486, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00047: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7726 - mean_squared_error: 6.0541 - mean_absolute_error: 1.9749 - mean_absolute_percentage_error: 1183.1754 - val_loss: -0.7189 - val_mean_squared_error: 4.5101 - val_mean_absolute_error: 1.9211 - val_mean_absolute_percentage_error: 1139.0956
# Epoch 48/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7344 - mean_squared_error: 5.9562 - mean_absolute_error: 1.9670 - mean_absolute_percentage_error: 1160.4198
# Epoch 00048: mean_absolute_error improved from 1.97486 to 1.96699, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00048: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7344 - mean_squared_error: 5.9562 - mean_absolute_error: 1.9670 - mean_absolute_percentage_error: 1160.4198 - val_loss: -0.7274 - val_mean_squared_error: 6.2637 - val_mean_absolute_error: 2.2050 - val_mean_absolute_percentage_error: 1250.9191
# Epoch 49/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7290 - mean_squared_error: 6.4343 - mean_absolute_error: 2.0850 - mean_absolute_percentage_error: 1190.1902
# Epoch 00049: mean_absolute_error did not improve from 1.96699
#
# Epoch 00049: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7290 - mean_squared_error: 6.4343 - mean_absolute_error: 2.0850 - mean_absolute_percentage_error: 1190.1902 - val_loss: -0.7134 - val_mean_squared_error: 11.0484 - val_mean_absolute_error: 3.1312 - val_mean_absolute_percentage_error: 1883.5737
# Epoch 50/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7557 - mean_squared_error: 6.9392 - mean_absolute_error: 2.0820 - mean_absolute_percentage_error: 983.1200
# Epoch 00050: mean_absolute_error did not improve from 1.96699
#
# Epoch 00050: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7557 - mean_squared_error: 6.9392 - mean_absolute_error: 2.0820 - mean_absolute_percentage_error: 983.1200 - val_loss: -0.7042 - val_mean_squared_error: 11.3408 - val_mean_absolute_error: 3.2069 - val_mean_absolute_percentage_error: 1919.4091
# Epoch 51/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7449 - mean_squared_error: 6.2058 - mean_absolute_error: 2.0006 - mean_absolute_percentage_error: 997.6304
# Epoch 00051: mean_absolute_error did not improve from 1.96699
#
# Epoch 00051: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7449 - mean_squared_error: 6.2058 - mean_absolute_error: 2.0006 - mean_absolute_percentage_error: 997.6304 - val_loss: -0.6889 - val_mean_squared_error: 7.5334 - val_mean_absolute_error: 2.6443 - val_mean_absolute_percentage_error: 1662.0643
# Epoch 52/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7515 - mean_squared_error: 6.2194 - mean_absolute_error: 1.9070 - mean_absolute_percentage_error: 990.2452
# Epoch 00052: mean_absolute_error improved from 1.96699 to 1.90695, saving model to models/best_weights_xy_test250_Adam_cosine.hdf5
#
# Epoch 00052: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7515 - mean_squared_error: 6.2194 - mean_absolute_error: 1.9070 - mean_absolute_percentage_error: 990.2452 - val_loss: -0.6872 - val_mean_squared_error: 9.3039 - val_mean_absolute_error: 2.9669 - val_mean_absolute_percentage_error: 1955.7433
# Epoch 53/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7628 - mean_squared_error: 6.0073 - mean_absolute_error: 1.9353 - mean_absolute_percentage_error: 979.4001
# Epoch 00053: mean_absolute_error did not improve from 1.90695
#
# Epoch 00053: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7628 - mean_squared_error: 6.0073 - mean_absolute_error: 1.9353 - mean_absolute_percentage_error: 979.4001 - val_loss: -0.6792 - val_mean_squared_error: 7.8574 - val_mean_absolute_error: 2.7304 - val_mean_absolute_percentage_error: 1835.4453
# Epoch 54/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7454 - mean_squared_error: 6.7231 - mean_absolute_error: 1.9897 - mean_absolute_percentage_error: 1135.5903
# Epoch 00054: mean_absolute_error did not improve from 1.90695
#
# Epoch 00054: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 71s 10s/step - loss: -0.7454 - mean_squared_error: 6.7231 - mean_absolute_error: 1.9897 - mean_absolute_percentage_error: 1135.5903 - val_loss: -0.6953 - val_mean_squared_error: 7.1942 - val_mean_absolute_error: 2.2118 - val_mean_absolute_percentage_error: 1787.3988
# Epoch 55/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7454 - mean_squared_error: 8.8535 - mean_absolute_error: 2.1670 - mean_absolute_percentage_error: 1096.4761
# Epoch 00055: mean_absolute_error did not improve from 1.90695
#
# Epoch 00055: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7454 - mean_squared_error: 8.8535 - mean_absolute_error: 2.1670 - mean_absolute_percentage_error: 1096.4761 - val_loss: -0.6758 - val_mean_squared_error: 1411.1300 - val_mean_absolute_error: 18.5003 - val_mean_absolute_percentage_error: 13809.1729
# Epoch 56/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7405 - mean_squared_error: 9.9083 - mean_absolute_error: 2.1984 - mean_absolute_percentage_error: 1005.1812
# Epoch 00056: mean_absolute_error did not improve from 1.90695
#
# Epoch 00056: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 72s 10s/step - loss: -0.7405 - mean_squared_error: 9.9083 - mean_absolute_error: 2.1984 - mean_absolute_percentage_error: 1005.1812 - val_loss: -0.6750 - val_mean_squared_error: 2943.6699 - val_mean_absolute_error: 27.1787 - val_mean_absolute_percentage_error: 22123.3145
# Epoch 57/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7564 - mean_squared_error: 8.9525 - mean_absolute_error: 2.1430 - mean_absolute_percentage_error: 1053.0994
# Epoch 00057: mean_absolute_error did not improve from 1.90695
#
# Epoch 00057: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.7564 - mean_squared_error: 8.9525 - mean_absolute_error: 2.1430 - mean_absolute_percentage_error: 1053.0994 - val_loss: -0.6657 - val_mean_squared_error: 248.4960 - val_mean_absolute_error: 9.1171 - val_mean_absolute_percentage_error: 6870.0562
# Epoch 58/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7531 - mean_squared_error: 7.1053 - mean_absolute_error: 2.0962 - mean_absolute_percentage_error: 1089.8383
# Epoch 00058: mean_absolute_error did not improve from 1.90695
#
# Epoch 00058: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7531 - mean_squared_error: 7.1053 - mean_absolute_error: 2.0962 - mean_absolute_percentage_error: 1089.8383 - val_loss: -0.6964 - val_mean_squared_error: 10.8678 - val_mean_absolute_error: 3.1228 - val_mean_absolute_percentage_error: 2363.2107
# Epoch 59/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7404 - mean_squared_error: 6.5087 - mean_absolute_error: 1.9523 - mean_absolute_percentage_error: 1074.1266
# Epoch 00059: mean_absolute_error did not improve from 1.90695
#
# Epoch 00059: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7404 - mean_squared_error: 6.5087 - mean_absolute_error: 1.9523 - mean_absolute_percentage_error: 1074.1266 - val_loss: -0.7039 - val_mean_squared_error: 9.2384 - val_mean_absolute_error: 2.8938 - val_mean_absolute_percentage_error: 1936.1562
# Epoch 60/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7490 - mean_squared_error: 6.4413 - mean_absolute_error: 2.0205 - mean_absolute_percentage_error: 975.6753
# Epoch 00060: mean_absolute_error did not improve from 1.90695
#
# Epoch 00060: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7490 - mean_squared_error: 6.4413 - mean_absolute_error: 2.0205 - mean_absolute_percentage_error: 975.6753 - val_loss: -0.7248 - val_mean_squared_error: 6.4135 - val_mean_absolute_error: 2.2831 - val_mean_absolute_percentage_error: 1356.2251
# Epoch 61/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7462 - mean_squared_error: 9.0851 - mean_absolute_error: 2.3830 - mean_absolute_percentage_error: 1234.4841
# Epoch 00061: mean_absolute_error did not improve from 1.90695
#
# Epoch 00061: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7462 - mean_squared_error: 9.0851 - mean_absolute_error: 2.3830 - mean_absolute_percentage_error: 1234.4841 - val_loss: -0.7247 - val_mean_squared_error: 7.3228 - val_mean_absolute_error: 2.4757 - val_mean_absolute_percentage_error: 1400.9622
# Epoch 62/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7362 - mean_squared_error: 10.9246 - mean_absolute_error: 2.5127 - mean_absolute_percentage_error: 1241.5818
# Epoch 00062: mean_absolute_error did not improve from 1.90695
#
# Epoch 00062: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7362 - mean_squared_error: 10.9246 - mean_absolute_error: 2.5127 - mean_absolute_percentage_error: 1241.5818 - val_loss: -0.7152 - val_mean_squared_error: 6.6364 - val_mean_absolute_error: 2.4073 - val_mean_absolute_percentage_error: 1454.9528
# Epoch 63/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7471 - mean_squared_error: 9.4298 - mean_absolute_error: 2.4585 - mean_absolute_percentage_error: 1128.1450
# Epoch 00063: mean_absolute_error did not improve from 1.90695
#
# Epoch 00063: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7471 - mean_squared_error: 9.4298 - mean_absolute_error: 2.4585 - mean_absolute_percentage_error: 1128.1450 - val_loss: -0.6989 - val_mean_squared_error: 5.2630 - val_mean_absolute_error: 2.1783 - val_mean_absolute_percentage_error: 1393.7532
# Epoch 64/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7395 - mean_squared_error: 7.6797 - mean_absolute_error: 2.2648 - mean_absolute_percentage_error: 1095.1606
# Epoch 00064: mean_absolute_error did not improve from 1.90695
#
# Epoch 00064: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7395 - mean_squared_error: 7.6797 - mean_absolute_error: 2.2648 - mean_absolute_percentage_error: 1095.1606 - val_loss: -0.6645 - val_mean_squared_error: 4.4966 - val_mean_absolute_error: 2.0445 - val_mean_absolute_percentage_error: 1413.0847
# Epoch 65/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7483 - mean_squared_error: 9.1725 - mean_absolute_error: 2.3784 - mean_absolute_percentage_error: 1265.2186
# Epoch 00065: mean_absolute_error did not improve from 1.90695
#
# Epoch 00065: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7483 - mean_squared_error: 9.1725 - mean_absolute_error: 2.3784 - mean_absolute_percentage_error: 1265.2186 - val_loss: -0.7099 - val_mean_squared_error: 4.5216 - val_mean_absolute_error: 1.9714 - val_mean_absolute_percentage_error: 1225.3654
# Epoch 66/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7533 - mean_squared_error: 9.4504 - mean_absolute_error: 2.3438 - mean_absolute_percentage_error: 1169.1464
# Epoch 00066: mean_absolute_error did not improve from 1.90695
#
# Epoch 00066: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7533 - mean_squared_error: 9.4504 - mean_absolute_error: 2.3438 - mean_absolute_percentage_error: 1169.1464 - val_loss: -0.7178 - val_mean_squared_error: 173.9223 - val_mean_absolute_error: 6.3097 - val_mean_absolute_percentage_error: 4980.0811
# Epoch 67/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7121 - mean_squared_error: 9.1260 - mean_absolute_error: 2.1378 - mean_absolute_percentage_error: 1029.8022
# Epoch 00067: mean_absolute_error did not improve from 1.90695
#
# Epoch 00067: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7121 - mean_squared_error: 9.1260 - mean_absolute_error: 2.1378 - mean_absolute_percentage_error: 1029.8022 - val_loss: -0.7208 - val_mean_squared_error: 276.7354 - val_mean_absolute_error: 7.4417 - val_mean_absolute_percentage_error: 5483.2515
# Epoch 68/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7011 - mean_squared_error: 8.4644 - mean_absolute_error: 2.1041 - mean_absolute_percentage_error: 1279.6262
# Epoch 00068: mean_absolute_error did not improve from 1.90695
#
# Epoch 00068: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7011 - mean_squared_error: 8.4644 - mean_absolute_error: 2.1041 - mean_absolute_percentage_error: 1279.6262 - val_loss: -0.7133 - val_mean_squared_error: 185.8249 - val_mean_absolute_error: 6.0845 - val_mean_absolute_percentage_error: 4600.0625
# Epoch 69/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7160 - mean_squared_error: 7.8366 - mean_absolute_error: 2.2231 - mean_absolute_percentage_error: 1309.2295
# Epoch 00069: mean_absolute_error did not improve from 1.90695
#
# Epoch 00069: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7160 - mean_squared_error: 7.8366 - mean_absolute_error: 2.2231 - mean_absolute_percentage_error: 1309.2295 - val_loss: -0.7178 - val_mean_squared_error: 188.6892 - val_mean_absolute_error: 6.0448 - val_mean_absolute_percentage_error: 5226.2881
# Epoch 70/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7123 - mean_squared_error: 8.3642 - mean_absolute_error: 2.3248 - mean_absolute_percentage_error: 1339.7468
# Epoch 00070: mean_absolute_error did not improve from 1.90695
#
# Epoch 00070: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7123 - mean_squared_error: 8.3642 - mean_absolute_error: 2.3248 - mean_absolute_percentage_error: 1339.7468 - val_loss: -0.7097 - val_mean_squared_error: 26.1425 - val_mean_absolute_error: 3.0072 - val_mean_absolute_percentage_error: 2724.0640
# Epoch 71/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7391 - mean_squared_error: 9.3243 - mean_absolute_error: 2.5141 - mean_absolute_percentage_error: 1369.2450
# Epoch 00071: mean_absolute_error did not improve from 1.90695
#
# Epoch 00071: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7391 - mean_squared_error: 9.3243 - mean_absolute_error: 2.5141 - mean_absolute_percentage_error: 1369.2450 - val_loss: -0.7320 - val_mean_squared_error: 3.9776 - val_mean_absolute_error: 1.6611 - val_mean_absolute_percentage_error: 808.8546
# Epoch 72/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7378 - mean_squared_error: 10.0935 - mean_absolute_error: 2.5972 - mean_absolute_percentage_error: 1340.5557
# Epoch 00072: mean_absolute_error did not improve from 1.90695
#
# Epoch 00072: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7378 - mean_squared_error: 10.0935 - mean_absolute_error: 2.5972 - mean_absolute_percentage_error: 1340.5557 - val_loss: -0.7063 - val_mean_squared_error: 4.8904 - val_mean_absolute_error: 1.9601 - val_mean_absolute_percentage_error: 999.6577
# Epoch 73/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7640 - mean_squared_error: 10.0552 - mean_absolute_error: 2.5684 - mean_absolute_percentage_error: 1330.3885
# Epoch 00073: mean_absolute_error did not improve from 1.90695
#
# Epoch 00073: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7640 - mean_squared_error: 10.0552 - mean_absolute_error: 2.5684 - mean_absolute_percentage_error: 1330.3885 - val_loss: -0.7180 - val_mean_squared_error: 5.5417 - val_mean_absolute_error: 2.1544 - val_mean_absolute_percentage_error: 1179.0902
# Epoch 74/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7704 - mean_squared_error: 10.0083 - mean_absolute_error: 2.4845 - mean_absolute_percentage_error: 1344.2234
# Epoch 00074: mean_absolute_error did not improve from 1.90695
#
# Epoch 00074: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7704 - mean_squared_error: 10.0083 - mean_absolute_error: 2.4845 - mean_absolute_percentage_error: 1344.2234 - val_loss: -0.6978 - val_mean_squared_error: 7.1574 - val_mean_absolute_error: 2.5807 - val_mean_absolute_percentage_error: 1648.9148
# Epoch 75/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7611 - mean_squared_error: 9.0184 - mean_absolute_error: 2.3930 - mean_absolute_percentage_error: 1051.1229
# Epoch 00075: mean_absolute_error did not improve from 1.90695
#
# Epoch 00075: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# ...
# Epoch 176/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7808 - mean_squared_error: 16.6271 - mean_absolute_error: 3.1313 - mean_absolute_percentage_error: 1587.5934
# Epoch 00176: mean_absolute_error did not improve from 1.90695
#
# Epoch 00176: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7808 - mean_squared_error: 16.6271 - mean_absolute_error: 3.1313 - mean_absolute_percentage_error: 1587.5934 - val_loss: -0.6459 - val_mean_squared_error: 950.7245 - val_mean_absolute_error: 25.8549 - val_mean_absolute_percentage_error: 18645.0508
# Epoch 177/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7875 - mean_squared_error: 16.2891 - mean_absolute_error: 3.1560 - mean_absolute_percentage_error: 1574.2571
# Epoch 00177: mean_absolute_error did not improve from 1.90695
#
# Epoch 00177: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7875 - mean_squared_error: 16.2891 - mean_absolute_error: 3.1560 - mean_absolute_percentage_error: 1574.2571 - val_loss: -0.6519 - val_mean_squared_error: 572.9556 - val_mean_absolute_error: 20.4216 - val_mean_absolute_percentage_error: 14413.7500
# Epoch 178/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7908 - mean_squared_error: 15.2072 - mean_absolute_error: 3.0675 - mean_absolute_percentage_error: 1566.1925
# Epoch 00178: mean_absolute_error did not improve from 1.90695
#
# Epoch 00178: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7908 - mean_squared_error: 15.2072 - mean_absolute_error: 3.0675 - mean_absolute_percentage_error: 1566.1925 - val_loss: -0.7060 - val_mean_squared_error: 611.0329 - val_mean_absolute_error: 20.0787 - val_mean_absolute_percentage_error: 12419.2246
# Epoch 179/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7899 - mean_squared_error: 16.0629 - mean_absolute_error: 3.0433 - mean_absolute_percentage_error: 1459.7666
# Epoch 00179: mean_absolute_error did not improve from 1.90695
#
# Epoch 00179: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7899 - mean_squared_error: 16.0629 - mean_absolute_error: 3.0433 - mean_absolute_percentage_error: 1459.7666 - val_loss: -0.7577 - val_mean_squared_error: 398.8571 - val_mean_absolute_error: 15.0627 - val_mean_absolute_percentage_error: 7414.4980
# Epoch 180/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8063 - mean_squared_error: 16.8456 - mean_absolute_error: 3.0611 - mean_absolute_percentage_error: 1385.8082
# Epoch 00180: mean_absolute_error did not improve from 1.90695
#
# Epoch 00180: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.8063 - mean_squared_error: 16.8456 - mean_absolute_error: 3.0611 - mean_absolute_percentage_error: 1385.8082 - val_loss: -0.7564 - val_mean_squared_error: 283.8765 - val_mean_absolute_error: 12.3060 - val_mean_absolute_percentage_error: 4806.0649
# Epoch 181/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7936 - mean_squared_error: 16.9097 - mean_absolute_error: 2.9759 - mean_absolute_percentage_error: 1281.8251
# Epoch 00181: mean_absolute_error did not improve from 1.90695
#
# Epoch 00181: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7936 - mean_squared_error: 16.9097 - mean_absolute_error: 2.9759 - mean_absolute_percentage_error: 1281.8251 - val_loss: -0.7551 - val_mean_squared_error: 576.7098 - val_mean_absolute_error: 17.4650 - val_mean_absolute_percentage_error: 6526.8398
# Epoch 182/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7903 - mean_squared_error: 15.6816 - mean_absolute_error: 2.8969 - mean_absolute_percentage_error: 1265.9565
# Epoch 00182: mean_absolute_error did not improve from 1.90695
#
# Epoch 00182: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7903 - mean_squared_error: 15.6816 - mean_absolute_error: 2.8969 - mean_absolute_percentage_error: 1265.9565 - val_loss: -0.7567 - val_mean_squared_error: 691.3603 - val_mean_absolute_error: 18.8995 - val_mean_absolute_percentage_error: 6843.3735
# Epoch 183/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8102 - mean_squared_error: 16.1177 - mean_absolute_error: 2.9152 - mean_absolute_percentage_error: 1255.8354
# Epoch 00183: mean_absolute_error did not improve from 1.90695
#
# Epoch 00183: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.8102 - mean_squared_error: 16.1177 - mean_absolute_error: 2.9152 - mean_absolute_percentage_error: 1255.8354 - val_loss: -0.7489 - val_mean_squared_error: 406.1729 - val_mean_absolute_error: 14.4200 - val_mean_absolute_percentage_error: 5386.9517
# Epoch 184/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7975 - mean_squared_error: 16.1252 - mean_absolute_error: 2.9319 - mean_absolute_percentage_error: 1409.6531
# Epoch 00184: mean_absolute_error did not improve from 1.90695
#
# Epoch 00184: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7975 - mean_squared_error: 16.1252 - mean_absolute_error: 2.9319 - mean_absolute_percentage_error: 1409.6531 - val_loss: -0.7410 - val_mean_squared_error: 173.4594 - val_mean_absolute_error: 9.6456 - val_mean_absolute_percentage_error: 3649.0713
# Epoch 185/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8042 - mean_squared_error: 16.5026 - mean_absolute_error: 2.9934 - mean_absolute_percentage_error: 1405.1195
# Epoch 00185: mean_absolute_error did not improve from 1.90695
#
# Epoch 00185: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.8042 - mean_squared_error: 16.5026 - mean_absolute_error: 2.9934 - mean_absolute_percentage_error: 1405.1195 - val_loss: -0.7600 - val_mean_squared_error: 54.6149 - val_mean_absolute_error: 5.4741 - val_mean_absolute_percentage_error: 1809.3961
# Epoch 186/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7980 - mean_squared_error: 18.8058 - mean_absolute_error: 3.3184 - mean_absolute_percentage_error: 1730.6597
# Epoch 00186: mean_absolute_error did not improve from 1.90695
#
# Epoch 00186: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7980 - mean_squared_error: 18.8058 - mean_absolute_error: 3.3184 - mean_absolute_percentage_error: 1730.6597 - val_loss: -0.6721 - val_mean_squared_error: 145.2943 - val_mean_absolute_error: 9.5863 - val_mean_absolute_percentage_error: 5349.7817
# Epoch 187/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8118 - mean_squared_error: 20.5987 - mean_absolute_error: 3.4321 - mean_absolute_percentage_error: 1785.5199
# Epoch 00187: mean_absolute_error did not improve from 1.90695
#
# Epoch 00187: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.8118 - mean_squared_error: 20.5987 - mean_absolute_error: 3.4321 - mean_absolute_percentage_error: 1785.5199 - val_loss: -0.6672 - val_mean_squared_error: 167.9909 - val_mean_absolute_error: 10.5646 - val_mean_absolute_percentage_error: 6127.6733
# Epoch 188/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8186 - mean_squared_error: 19.4745 - mean_absolute_error: 3.3558 - mean_absolute_percentage_error: 1552.2142
# Epoch 00188: mean_absolute_error did not improve from 1.90695
#
# Epoch 00188: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.8186 - mean_squared_error: 19.4745 - mean_absolute_error: 3.3558 - mean_absolute_percentage_error: 1552.2142 - val_loss: -0.6490 - val_mean_squared_error: 118.7318 - val_mean_absolute_error: 8.3786 - val_mean_absolute_percentage_error: 5169.5830
# Epoch 189/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7966 - mean_squared_error: 17.8934 - mean_absolute_error: 3.2280 - mean_absolute_percentage_error: 1758.6282
# Epoch 00189: mean_absolute_error did not improve from 1.90695
#
# Epoch 00189: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7966 - mean_squared_error: 17.8934 - mean_absolute_error: 3.2280 - mean_absolute_percentage_error: 1758.6282 - val_loss: -0.6359 - val_mean_squared_error: 124.3024 - val_mean_absolute_error: 8.1909 - val_mean_absolute_percentage_error: 5240.1587
# Epoch 190/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8017 - mean_squared_error: 16.0629 - mean_absolute_error: 3.0821 - mean_absolute_percentage_error: 1617.9742
# Epoch 00190: mean_absolute_error did not improve from 1.90695
#
# Epoch 00190: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.8017 - mean_squared_error: 16.0629 - mean_absolute_error: 3.0821 - mean_absolute_percentage_error: 1617.9742 - val_loss: -0.7286 - val_mean_squared_error: 42.8964 - val_mean_absolute_error: 5.5612 - val_mean_absolute_percentage_error: 2310.1689
# Epoch 191/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7929 - mean_squared_error: 16.7891 - mean_absolute_error: 3.1886 - mean_absolute_percentage_error: 1666.3754
# Epoch 00191: mean_absolute_error did not improve from 1.90695
#
# Epoch 00191: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7929 - mean_squared_error: 16.7891 - mean_absolute_error: 3.1886 - mean_absolute_percentage_error: 1666.3754 - val_loss: -0.7687 - val_mean_squared_error: 122.2913 - val_mean_absolute_error: 8.8962 - val_mean_absolute_percentage_error: 3972.7715
# Epoch 192/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7895 - mean_squared_error: 17.0112 - mean_absolute_error: 3.1273 - mean_absolute_percentage_error: 1565.4482
# Epoch 00192: mean_absolute_error did not improve from 1.90695
#
# Epoch 00192: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7895 - mean_squared_error: 17.0112 - mean_absolute_error: 3.1273 - mean_absolute_percentage_error: 1565.4482 - val_loss: -0.7639 - val_mean_squared_error: 128.0075 - val_mean_absolute_error: 9.0651 - val_mean_absolute_percentage_error: 4461.8687
# Epoch 193/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7808 - mean_squared_error: 16.6424 - mean_absolute_error: 3.0766 - mean_absolute_percentage_error: 1455.3306
# Epoch 00193: mean_absolute_error did not improve from 1.90695
#
# Epoch 00193: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.7808 - mean_squared_error: 16.6424 - mean_absolute_error: 3.0766 - mean_absolute_percentage_error: 1455.3306 - val_loss: -0.7564 - val_mean_squared_error: 46.3097 - val_mean_absolute_error: 4.9385 - val_mean_absolute_percentage_error: 3775.0020
# Epoch 194/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7856 - mean_squared_error: 16.0442 - mean_absolute_error: 3.1890 - mean_absolute_percentage_error: 1694.0155
# Epoch 00194: mean_absolute_error did not improve from 1.90695
#
# Epoch 00194: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7856 - mean_squared_error: 16.0442 - mean_absolute_error: 3.1890 - mean_absolute_percentage_error: 1694.0155 - val_loss: -0.6916 - val_mean_squared_error: 114.9762 - val_mean_absolute_error: 8.2241 - val_mean_absolute_percentage_error: 6886.0688
# Epoch 195/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8032 - mean_squared_error: 16.8079 - mean_absolute_error: 3.3252 - mean_absolute_percentage_error: 1745.8330
# Epoch 00195: mean_absolute_error did not improve from 1.90695
#
# Epoch 00195: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.8032 - mean_squared_error: 16.8079 - mean_absolute_error: 3.3252 - mean_absolute_percentage_error: 1745.8330 - val_loss: -0.6540 - val_mean_squared_error: 121.8520 - val_mean_absolute_error: 8.6156 - val_mean_absolute_percentage_error: 7165.4346
# Epoch 196/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8110 - mean_squared_error: 17.1357 - mean_absolute_error: 3.2966 - mean_absolute_percentage_error: 1783.4728
# Epoch 00196: mean_absolute_error did not improve from 1.90695
#
# Epoch 00196: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.8110 - mean_squared_error: 17.1357 - mean_absolute_error: 3.2966 - mean_absolute_percentage_error: 1783.4728 - val_loss: -0.7037 - val_mean_squared_error: 133.8513 - val_mean_absolute_error: 9.2729 - val_mean_absolute_percentage_error: 6687.2061
# Epoch 197/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8041 - mean_squared_error: 16.6338 - mean_absolute_error: 3.2891 - mean_absolute_percentage_error: 1711.2834
# Epoch 00197: mean_absolute_error did not improve from 1.90695
#
# Epoch 00197: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 73s 10s/step - loss: -0.8041 - mean_squared_error: 16.6338 - mean_absolute_error: 3.2891 - mean_absolute_percentage_error: 1711.2834 - val_loss: -0.6999 - val_mean_squared_error: 47.5134 - val_mean_absolute_error: 5.3490 - val_mean_absolute_percentage_error: 3833.3369
# Epoch 198/200
# 7/7 [==============================] - ETA: 0s - loss: -0.7957 - mean_squared_error: 18.2304 - mean_absolute_error: 3.4326 - mean_absolute_percentage_error: 1605.0575
# Epoch 00198: mean_absolute_error did not improve from 1.90695
#
# Epoch 00198: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 75s 11s/step - loss: -0.7957 - mean_squared_error: 18.2304 - mean_absolute_error: 3.4326 - mean_absolute_percentage_error: 1605.0575 - val_loss: -0.6652 - val_mean_squared_error: 29.4740 - val_mean_absolute_error: 3.9044 - val_mean_absolute_percentage_error: 2751.8662
# Epoch 199/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8025 - mean_squared_error: 18.6591 - mean_absolute_error: 3.5016 - mean_absolute_percentage_error: 1461.8547
# Epoch 00199: mean_absolute_error did not improve from 1.90695
#
# Epoch 00199: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.8025 - mean_squared_error: 18.6591 - mean_absolute_error: 3.5016 - mean_absolute_percentage_error: 1461.8547 - val_loss: -0.6924 - val_mean_squared_error: 23.1050 - val_mean_absolute_error: 3.6289 - val_mean_absolute_percentage_error: 2355.2195
# Epoch 200/200
# 7/7 [==============================] - ETA: 0s - loss: -0.8055 - mean_squared_error: 17.1358 - mean_absolute_error: 3.3381 - mean_absolute_percentage_error: 1605.9609
# Epoch 00200: mean_absolute_error did not improve from 1.90695
#
# Epoch 00200: saving model to models/last_weights_xy_test250_Adam_cosine.hdf5
# 7/7 [==============================] - 74s 11s/step - loss: -0.8055 - mean_squared_error: 17.1358 - mean_absolute_error: 3.3381 - mean_absolute_percentage_error: 1605.9609 - val_loss: -0.7009 - val_mean_squared_error: 20.8062 - val_mean_absolute_error: 3.6361 - val_mean_absolute_percentage_error: 1919.3391

# %%
model.save('models/trained_xy_test250_Adam_cosine.h5')

# %%
# taking samples from the validation dataset and evaluating the model
val_ex, = validation_ds.take(1)
images, labels = val_ex[0], val_ex[1]
outputs = model.predict(images)

# %%
#print(labels)
print(outputs[:20])
# Out:
# [[-4.3172226   7.267375  ]
#  [-0.56550455 -1.6180037 ]
#  [-1.5680813   6.152943  ]
#  [-2.860368   -0.65238804]
#  [-4.0351353   0.604696  ]
#  [-6.3931007   2.6165793 ]
#  [-0.39760515 -2.5384045 ]
#  [-7.902691   -2.8033402 ]
#  [-0.6408318  -1.399646  ]
#  [-5.083953    4.7264533 ]
#  [-3.5363226  -2.610997  ]
#  [-6.510363   -0.19779688]
#  [-4.830699    3.8557763 ]
#  [-5.622068    2.0952895 ]
#  [-7.853214   -0.7616084 ]
#  [-0.9619535  -1.5826341 ]
#  [-1.0343636   5.5847273 ]
#  [-2.0130157   3.3480933 ]
#  [-0.9789721   5.051555  ]
#  [-0.0472666   5.350229  ]]

# %%
# visualicing the results
for img,label,pred,i in zip(images, labels, outputs,range(15)):
    viz(img, label, pred)
# Out:
# #### **cartesian label:** [-0.79476786 -0.02821311]
# #### **cartesian prediction (x_y):** [-4.3172226  7.267375 ]
# #### **cartesian label:** [0.16465198 0.43273833]
# #### **cartesian prediction (x_y):** [-0.56550455 -1.6180037 ]
# #### **cartesian label:** [-0.28957403 -0.83786666]
# #### **cartesian prediction (x_y):** [-1.5680813  6.152943 ]
# #### **cartesian label:** [-0.44929716 -0.14011286]
# #### **cartesian prediction (x_y):** [-2.860368   -0.65238804]
# #### **cartesian label:** [-0.65529716 -0.01885475]
# #### **cartesian prediction (x_y):** [-4.0351353  0.604696 ]
# #### **cartesian label:** [ 0.8984316  -0.02597428]
# #### **cartesian prediction (x_y):** [-6.3931007  2.6165793]
# #### **cartesian label:** [-0.5323512  0.3204348]
# #### **cartesian prediction (x_y):** [-0.39760515 -2.5384045 ]
# #### **cartesian label:** [0.912262   0.07897478]
# #### **cartesian prediction (x_y):** [-7.902691  -2.8033402]
# #### **cartesian label:** [-0.582031  -0.7110629]
# #### **cartesian prediction (x_y):** [-0.6408318 -1.399646 ]
# #### **cartesian label:** [-0.994252   -0.01286145]
# #### **cartesian prediction (x_y):** [-5.083953   4.7264533]
# #### **cartesian label:** [-0.6349558 -0.7693941]
# #### **cartesian prediction (x_y):** [-3.5363226 -2.610997 ]
# #### **cartesian label:** [0.50448936 0.49755648]
# #### **cartesian prediction (x_y):** [-6.510363   -0.19779688]
# #### **cartesian label:** [ 0.70934874 -0.4818626 ]
# #### **cartesian prediction (x_y):** [-4.830699   3.8557763]
# #### **cartesian label:** [ 0.6877297  -0.16112445]
# #### **cartesian prediction (x_y):** [-5.622068   2.0952895]
# #### **cartesian label:** [0.83467937 0.37659892]
# #### **cartesian prediction (x_y):** [-7.853214  -0.7616084]
